# %%
import pandas as pd
import numpy as np 
import os
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)


class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()

def only_the_words_in_index( list, index ):
    output = []
    for a, s in enumerate(list):
        if s in index:
            output.append(list[a])
    return output

def string_stemmer(line):
    import re
    from nltk.corpus import stopwords
    from nltk.stem.snowball import SnowballStemmer
    stemmer = SnowballStemmer("english")
    line = re.sub(r'[^a-zA-Z ]',r'',line)
    line = line.split()
    line = [word for word in line if word not in stopwords.words('english')]  # remove the stop words. 
    output = []
    for word in line:
        output.append(stemmer.stem(word))     #stem all words 
    output = ' '.join(output)           # join the list to make a string
    return output


def get_parameter_for_w2v_for_questions( question_file_path, wiki_folder_path, sizenum, minnum  ):
    sentences = MySentences(wiki_folder_path)
    result = np.zeros(sizenum*minnum).reshape(sizenum,minnum)

    for k in xrange(sizenum):
        for j in xrange(minnum):
            model = gensim.models.Word2Vec(sentences,size=300 + 4*k, window=5, min_count= 1 + j, workers=4)
            myanswer_list = []
            myanswer_distance = pd.DataFrame(np.zeros(4).reshape(1,4), columns = ['A','B','C','D'])    #initialize dataframe to store my answers distance
            train = pd.read_table(question_file_path,sep = '\t')
            for i in train.index.values:
                length = len(train)
                q = train.ix[i][1]
                a1 = train.ix[i][3]
                a2 = train.ix[i][4]
                a3 = train.ix[i][5]
                a4 = train.ix[i][6]

                q = string_stemmer(q)
                a1 = string_stemmer(a1)
                a2 = string_stemmer(a2)
                a3 = string_stemmer(a3)
                a4 = string_stemmer(a4)

                q  = q.split()
                a1 = a1.split()
                a2 = a2.split()
                a3 = a3.split()
                a4 = a4.split()

                q =  only_the_words_in_index( q, model.index2word)
                a1 = only_the_words_in_index( a1, model.index2word)
                a2 = only_the_words_in_index( a2, model.index2word)
                a3 = only_the_words_in_index( a3, model.index2word)
                a4 = only_the_words_in_index( a4, model.index2word)

                try:
                    answer_similarity = np.array([['A',model.n_similarity(q, a1)],['B',model.n_similarity(q, a2)],
                                                  ['C',model.n_similarity(q, a3)],['D',model.n_similarity(q, a4)]])
                except:
                    print 'Error on ', i, ' and set lengths at random'
                    answer_similarity = np.array([['A',np.random.rand()],['B',np.random.rand()],
                                                  ['C',np.random.rand()],['D',np.random.rand()]])

                    myanswer_distance.set_value(i, 'A', answer_similarity[0,1] )    #write down distance for each choice
                    myanswer_distance.set_value(i, 'B', answer_similarity[1,1] )
                    myanswer_distance.set_value(i, 'C', answer_similarity[2,1] )
                    myanswer_distance.set_value(i, 'D', answer_similarity[3,1] )

                    #myanswer_index = answer_similarity[:,1].argsort()[-2]        #get the second best 
                    myanswer_index = answer_similarity[:,1].argmax()         #get the maximum similarity 
                    myanswer = answer_similarity[myanswer_index][0]
                    myanswer_list.append(myanswer)
                    continue

                myanswer_distance.set_value(i, 'A', answer_similarity[0,1] )    #write down distance for each choice
                myanswer_distance.set_value(i, 'B', answer_similarity[1,1] )
                myanswer_distance.set_value(i, 'C', answer_similarity[2,1] )
                myanswer_distance.set_value(i, 'D', answer_similarity[3,1] )

                #myanswer_index = answer_similarity[:,1].argsort()[-2]
                myanswer_index = answer_similarity[:,1].argmax()          #get the maximum similarity 
                myanswer = answer_similarity[myanswer_index][0]
                myanswer_list.append(myanswer)

                print 'progress: ','k =',k, 'j = ',j ,' : ',i , '/', length 
                #for printing out the distance
                # myanswer_distance.to_csv('/Users/MK/GitHub/the_answer_is/data/answer/pure_ck12_word2vec_distance.csv', encoding='utf-8')    
            train['ck_12_word2vec_answer'] = myanswer_list
            train['ck_12_word2vec_correct'] = (train['correctAnswer'] == train['ck_12_word2vec_answer'])
            result[k,j] = train['ck_12_word2vec_correct'].sum(axis =0) / (len(train) + 0.0)
            print result
    print 'max at: ', result.argmax(axis = 0).max()+1 , ",", result.argmax(axis = 1).max()+1
    return result




def run_w2v_for_questions( question_file_path, wiki_folder_path ):
    sentences = MySentences(wiki_folder_path)

    model = gensim.models.Word2Vec(sentences,size=300 , window=5, min_count= 1 , workers=4)
    myanswer_list = []
    myanswer_distance = pd.DataFrame(np.zeros(4).reshape(1,4), columns = ['A','B','C','D'])    #initialize dataframe to store my answers distance
    train = pd.read_table(question_file_path,sep = '\t')
    for i in train.index.values:
        length = len(train)
        q = train.ix[i][1]
        a1 = train.ix[i][3]
        a2 = train.ix[i][4]
        a3 = train.ix[i][5]
        a4 = train.ix[i][6]

        q = string_stemmer(q)
        a1 = string_stemmer(a1)
        a2 = string_stemmer(a2)
        a3 = string_stemmer(a3)
        a4 = string_stemmer(a4)

        q  = q.split()
        a1 = a1.split()
        a2 = a2.split()
        a3 = a3.split()
        a4 = a4.split()

        q =  only_the_words_in_index( q, model.index2word)
        a1 = only_the_words_in_index( a1, model.index2word)
        a2 = only_the_words_in_index( a2, model.index2word)
        a3 = only_the_words_in_index( a3, model.index2word)
        a4 = only_the_words_in_index( a4, model.index2word)

        try:
            answer_similarity = np.array([['A',model.n_similarity(q, a1)],['B',model.n_similarity(q, a2)],
                                          ['C',model.n_similarity(q, a3)],['D',model.n_similarity(q, a4)]])
        except:
            print 'Error on ', i, ' and set lengths at random'
            answer_similarity = np.array([['A',np.random.rand()],['B',np.random.rand()],
                                          ['C',np.random.rand()],['D',np.random.rand()]])

            myanswer_distance.set_value(i, 'A', answer_similarity[0,1] )    #write down distance for each choice
            myanswer_distance.set_value(i, 'B', answer_similarity[1,1] )
            myanswer_distance.set_value(i, 'C', answer_similarity[2,1] )
            myanswer_distance.set_value(i, 'D', answer_similarity[3,1] )

            #myanswer_index = answer_similarity[:,1].argsort()[-2]        #get the second best 
            myanswer_index = answer_similarity[:,1].argmax()         #get the maximum similarity 
            myanswer = answer_similarity[myanswer_index][0]
            myanswer_list.append(myanswer)
            continue

        myanswer_distance.set_value(i, 'A', answer_similarity[0,1] )    #write down distance for each choice
        myanswer_distance.set_value(i, 'B', answer_similarity[1,1] )
        myanswer_distance.set_value(i, 'C', answer_similarity[2,1] )
        myanswer_distance.set_value(i, 'D', answer_similarity[3,1] )

        #myanswer_index = answer_similarity[:,1].argsort()[-2]
        myanswer_index = answer_similarity[:,1].argmax()          #get the maximum similarity 
        myanswer = answer_similarity[myanswer_index][0]
        myanswer_list.append(myanswer)

        print 'progress: ',i , '/', length 
        #for printing out the distance
                # myanswer_distance.to_csv('/Users/MK/GitHub/the_answer_is/data/answer/pure_ck12_word2vec_distance.csv', encoding='utf-8')    
    train['correctAnswer'] = myanswer_list
    return train

# %%
question_file_path = '/Users/MK/GitHub/the_answer_is/data/training_set.tsv'
wiki_folder_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_from_all_ck_words_stemmed'
sizenum = 2
minnum = 2
result = get_parameter_for_w2v_for_questions( question_file_path, wiki_folder_path, sizenum, minnum  )

# %%
question_file_path = '/Users/MK/GitHub/the_answer_is/data/training_set.tsv'
wiki_folder_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_stemmed_all_merged'
sizenum = 5
minnum = 5
result = get_parameter_for_w2v_for_questions( question_file_path, wiki_folder_path, sizenum, minnum  )
# Out:
#  k = 4 j =  0  :  1022 / 2500
# progress:  k = 4 j =  0  :  1023 / 2500
# progress:  k = 4 j =  0  :  1024 / 2500
# progress:  k = 4 j =  0  :  1025 / 2500
# progress:  k = 4 j =  0  :  1026 / 2500
# progress:  k = 4 j =  0  :  1027 / 2500
# progress:  k = 4 j =  0  :  1028 / 2500
# progress:  k = 4 j =  0  :  1029 / 2500
# progress:  k = 4 j =  0  :  1030 / 2500
# progress:  k = 4 j =  0  :  1031 / 2500
# progress:  k = 4 j =  0  :  1032 / 2500
# progress:  k = 4 j =  0  :  1033 / 2500
# progress:  k = 4 j =  0  :  1034 / 2500
# progress:  k = 4 j =  0  :  1035 / 2500
# progress:  k = 4 j =  0  :  1036 / 2500
# progress:  k = 4 j =  0  :  1037 / 2500
# progress:  k = 4 j =  0  :  1038 / 2500
# progress:  k = 4 j =  0  :  1039 / 2500
# progress:  k = 4 j =  0  :  1040 / 2500
# progress:  k = 4 j =  0  :  1041 / 2500
# progress:  k = 4 j =  0  :  1042 / 2500
# progress:  k = 4 j =  0  :  1043 / 2500
# progress:  k = 4 j =  0  :  1044 / 2500
# progress:  k = 4 j =  0  :  1045 / 2500
# progress:  k = 4 j =  0  :  1046 / 2500
# progress:  k = 4 j =  0  :  1047 / 2500
# progress:  k = 4 j =  0  :  1048 / 2500
# progress:  k = 4 j =  0  :  1049 / 2500
# progress:  k = 4 j =  0  :  1050 / 2500
# progress:  k = 4 j =  0  :  1051 / 2500
# progress:  k = 4 j =  0  :  1052 / 2500
# progress:  k = 4 j =  0  :  1053 / 2500
# progress:  k = 4 j =  0  :  1054 / 2500
# progress:  k = 4 j =  0  :  1055 / 2500
# progress:  k = 4 j =  0  :  1056 / 2500
# progress:  k = 4 j =  0  :  1057 / 2500
# progress:  k = 4 j =  0  :  1058 / 2500
# progress:  k = 4 j =  0  :  1059 / 2500
# progress:  k = 4 j =  0  :  1060 / 2500
# progress:  k = 4 j =  0  :  1061 / 2500
# progress:  k = 4 j =  0  :  1062 / 2500
# progress:  k = 4 j =  0  :  1063 / 2500
# progress:  k = 4 j =  0  :  1064 / 2500
# progress:  k = 4 j =  0  :  1065 / 2500
# progress:  k = 4 j =  0  :  1066 / 2500
# progress:  k = 4 j =  0  :  1067 / 2500
# progress:  k = 4 j =  0  :  1068 / 2500
# progress:  k = 4 j =  0  :  1069 / 2500
# progress:  k = 4 j =  0  :  1070 / 2500
# progress:  k = 4 j =  0  :  1071 / 2500
# progress:  k = 4 j =  0  :  1072 / 2500
# progress:  k = 4 j =  0  :  1073 / 2500
# progress:  k = 4 j =  0  :  1074 / 2500
# progress:  k = 4 j =  0  :  1075 / 2500
# progress:  k = 4 j =  0  :  1076 / 2500
# progress:  k = 4 j =  0  :  1077 / 2500
# progress:  k = 4 j =  0  :  1078 / 2500
# progress:  k = 4 j =  0  :  1079 / 2500
# progress:  k = 4 j =  0  :  1080 / 2500
# progress:  k = 4 j =  0  :  1081 / 2500
# progress:  k = 4 j =  0  :  1082 / 2500
# progress:  k = 4 j =  0  :  1083 / 2500
# progress:  k = 4 j =  0  :  1084 / 2500
# progress:  k = 4 j =  0  :  1085 / 2500
# progress:  k = 4 j =  0  :  1086 / 2500
# progress:  k = 4 j =  0  :  1087 / 2500
# progress:  k = 4 j =  0  :  1088 / 2500
# progress:  k = 4 j =  0  :  1089 / 2500
# progress:  k = 4 j =  0  :  1090 / 2500
# progress:  k = 4 j =  0  :  1091 / 2500
# progress:  k = 4 j =  0  :  1092 / 2500
# progress:  k = 4 j =  0  :  1093 / 2500
# progress:  k = 4 j =  0  :  1094 / 2500
# progress:  k = 4 j =  0  :  1095 / 2500
# progress:  k = 4 j =  0  :  1096 / 2500
# progress:  k = 4 j =  0  :  1097 / 2500
# progress:  k = 4 j =  0  :  1098 / 2500
# progress:  k = 4 j =  0  :  1099 / 2500
# progress:  k = 4 j =  0  :  1100 / 2500
# progress:  k = 4 j =  0  :  1101 / 2500
# progress:  k = 4 j =  0  :  1102 / 2500
# progress:  k = 4 j =  0  :  1103 / 2500
# progress:  k = 4 j =  0  :  1104 / 2500
# progress:  k = 4 j =  0  :  1105 / 2500
# progress:  k = 4 j =  0  :  1106 / 2500
# progress:  k = 4 j =  0  :  1107 / 2500
# progress:  k = 4 j =  0  :  1108 / 2500
# progress:  k = 4 j =  0  :  1109 / 2500
# progress:  k = 4 j =  0  :  1110 / 2500
# progress:  k = 4 j =  0  :  1111 / 2500
# progress:  k = 4 j =  0  :  1112 / 2500
# progress:  k = 4 j =  0  :  1113 / 2500
# progress:  k = 4 j =  0  :  1114 / 2500
# progress:  k = 4 j =  0  :  1115 / 2500
# progress:  k = 4 j =  0  :  1116 / 2500
# progress:  k = 4 j =  0  :  1117 / 2500
# progress:  k = 4 j =  0  :  1118 / 2500
# progress:  k = 4 j =  0  :  1119 / 2500
# progress:  k = 4 j =  0  :  1120 / 2500
# progress:  k = 4 j =  0  :  1121 / 2500
# progress:  k = 4 j =  0  :  1122 / 2500
# progress:  k = 4 j =  0  :  1123 / 2500
# progress:  k = 4 j =  0  :  1124 / 2500
# progress:  k = 4 j =  0  :  1125 / 2500
# progress:  k = 4 j =  0  :  1126 / 2500
# progress:  k = 4 j =  0  :  1127 / 2500
# progress:  k = 4 j =  0  :  1128 / 2500
# progress:  k = 4 j =  0  :  1129 / 2500
# progress:  k = 4 j =  0  :  1130 / 2500
# progress:  k = 4 j =  0  :  1131 / 2500
# progress:  k = 4 j =  0  :  1132 / 2500
# progress:  k = 4 j =  0  :  1133 / 2500
# progress:  k = 4 j =  0  :  1134 / 2500
# progress:  k = 4 j =  0  :  1135 / 2500
# progress:  k = 4 j =  0  :  1136 / 2500
# progress:  k = 4 j =  0  :  1137 / 2500
# progress:  k = 4 j =  0  :  1138 / 2500
# progress:  k = 4 j =  0  :  1139 / 2500
# progress:  k = 4 j =  0  :  1140 / 2500
# progress:  k = 4 j =  0  :  1141 / 2500
# progress:  k = 4 j =  0  :  1142 / 2500
# progress:  k = 4 j =  0  :  1143 / 2500
# progress:  k = 4 j =  0  :  1144 / 2500
# progress:  k = 4 j =  0  :  1145 / 2500
# progress:  k = 4 j =  0  :  1146 / 2500
# progress:  k = 4 j =  0  :  1147 / 2500
# progress:  k = 4 j =  0  :  1148 / 2500
# progress:  k = 4 j =  0  :  1149 / 2500
# progress:  k = 4 j =  0  :  1150 / 2500
# progress:  k = 4 j =  0  :  1151 / 2500
# progress:  k = 4 j =  0  :  1152 / 2500
# progress:  k = 4 j =  0  :  1153 / 2500
# progress:  k = 4 j =  0  :  1154 / 2500
# progress:  k = 4 j =  0  :  1155 / 2500
# progress:  k = 4 j =  0  :  1156 / 2500
# progress:  k = 4 j =  0  :  1157 / 2500
# progress:  k = 4 j =  0  :  1158 / 2500
# progress:  k = 4 j =  0  :  1159 / 2500
# progress:  k = 4 j =  0  :  1160 / 2500
# progress:  k = 4 j =  0  :  1161 / 2500
# progress:  k = 4 j =  0  :  1162 / 2500
# progress:  k = 4 j =  0  :  1163 / 2500
# progress:  k = 4 j =  0  :  1164 / 2500
# progress:  k = 4 j =  0  :  1165 / 2500
# progress:  k = 4 j =  0  :  1166 / 2500
# progress:  k = 4 j =  0  :  1167 / 2500
# progress:  k = 4 j =  0  :  1168 / 2500
# progress:  k = 4 j =  0  :  1169 / 2500
# progress:  k = 4 j =  0  :  1170 / 2500
# progress:  k = 4 j =  0  :  1171 / 2500
# progress:  k = 4 j =  0  :  1172 / 2500
# progress:  k = 4 j =  0  :  1173 / 2500
# progress:  k = 4 j =  0  :  1174 / 2500
# progress:  k = 4 j =  0  :  1175 / 2500
# progress:  k = 4 j =  0  :  1176 / 2500
# progress:  k = 4 j =  0  :  1177 / 2500
# progress:  k = 4 j =  0  :  1178 / 2500
# progress:  k = 4 j =  0  :  1179 / 2500
# progress:  k = 4 j =  0  :  1180 / 2500
# progress:  k = 4 j =  0  :  1181 / 2500
# progress:  k = 4 j =  0  :  1182 / 2500
# progress:  k = 4 j =  0  :  1183 / 2500
# progress:  k = 4 j =  0  :  1184 / 2500
# progress:  k = 4 j =  0  :  1185 / 2500
# progress:  k = 4 j =  0  :  1186 / 2500
# progress:  k = 4 j =  0  :  1187 / 2500
# progress:  k = 4 j =  0  :  1188 / 2500
# progress:  k = 4 j =  0  :  1189 / 2500
# progress:  k = 4 j =  0  :  1190 / 2500
# progress:  k = 4 j =  0  :  1191 / 2500
# progress:  k = 4 j =  0  :  1192 / 2500
# progress:  k = 4 j =  0  :  1193 / 2500
# progress:  k = 4 j =  0  :  1194 / 2500
# progress:  k = 4 j =  0  :  1195 / 2500
# progress:  k = 4 j =  0  :  1196 / 2500
# progress:  k = 4 j =  0  :  1197 / 2500
# progress:  k = 4 j =  0  :  1198 / 2500
# progress:  k = 4 j =  0  :  1199 / 2500
# progress:  k = 4 j =  0  :  1200 / 2500
# progress:  k = 4 j =  0  :  1201 / 2500
# progress:  k = 4 j =  0  :  1202 / 2500
# progress:  k = 4 j =  0  :  1203 / 2500
# progress:  k = 4 j =  0  :  1204 / 2500
# progress:  k = 4 j =  0  :  1205 / 2500
# progress:  k = 4 j =  0  :  1206 / 2500
# progress:  k = 4 j =  0  :  1207 / 2500
# progress:  k = 4 j =  0  :  1208 / 2500
# progress:  k = 4 j =  0  :  1209 / 2500
# progress:  k = 4 j =  0  :  1210 / 2500
# progress:  k = 4 j =  0  :  1211 / 2500
# progress:  k = 4 j =  0  :  1212 / 2500
# progress:  k = 4 j =  0  :  1213 / 2500
# progress:  k = 4 j =  0  :  1214 / 2500
# progress:  k = 4 j =  0  :  1215 / 2500
# progress:  k = 4 j =  0  :  1216 / 2500
# progress:  k = 4 j =  0  :  1217 / 2500
# progress:  k = 4 j =  0  :  1218 / 2500
# progress:  k = 4 j =  0  :  1219 / 2500
# progress:  k = 4 j =  0  :  1220 / 2500
# progress:  k = 4 j =  0  :  1221 / 2500
# progress:  k = 4 j =  0  :  1222 / 2500
# progress:  k = 4 j =  0  :  1223 / 2500
# progress:  k = 4 j =  0  :  1224 / 2500
# progress:  k = 4 j =  0  :  1225 / 2500
# progress:  k = 4 j =  0  :  1226 / 2500
# progress:  k = 4 j =  0  :  1227 / 2500
# progress:  k = 4 j =  0  :  1228 / 2500
# progress:  k = 4 j =  0  :  1229 / 2500
# progress:  k = 4 j =  0  :  1230 / 2500
# progress:  k = 4 j =  0  :  1231 / 2500
# progress:  k = 4 j =  0  :  1232 / 2500
# progress:  k = 4 j =  0  :  1233 / 2500
# progress:  k = 4 j =  0  :  1234 / 2500
# progress:  k = 4 j =  0  :  1235 / 2500
# progress:  k = 4 j =  0  :  1236 / 2500
# progress:  k = 4 j =  0  :  1237 / 2500
# progress:  k = 4 j =  0  :  1238 / 2500
# progress:  k = 4 j =  0  :  1239 / 2500
# progress:  k = 4 j =  0  :  1240 / 2500
# progress:  k = 4 j =  0  :  1241 / 2500
# progress:  k = 4 j =  0  :  1242 / 2500
# progress:  k = 4 j =  0  :  1243 / 2500
# progress:  k = 4 j =  0  :  1244 / 2500
# progress:  k = 4 j =  0  :  1245 / 2500
# progress:  k = 4 j =  0  :  1246 / 2500
# progress:  k = 4 j =  0  :  1247 / 2500
# progress:  k = 4 j =  0  :  1248 / 2500
# progress:  k = 4 j =  0  :  1249 / 2500
# progress:  k = 4 j =  0  :  1250 / 2500
# progress:  k = 4 j =  0  :  1251 / 2500
# progress:  k = 4 j =  0  :  1252 / 2500
# progress:  k = 4 j =  0  :  1253 / 2500
# progress:  k = 4 j =  0  :  1254 / 2500
# progress:  k = 4 j =  0  :  1255 / 2500
# progress:  k = 4 j =  0  :  1256 / 2500
# progress:  k = 4 j =  0  :  1257 / 2500
# progress:  k = 4 j =  0  :  1258 / 2500
# progress:  k = 4 j =  0  :  1259 / 2500
# progress:  k = 4 j =  0  :  1260 / 2500
# progress:  k = 4 j =  0  :  1261 / 2500
# progress:  k = 4 j =  0  :  1262 / 2500
# progress:  k = 4 j =  0  :  1263 / 2500
# progress:  k = 4 j =  0  :  1264 / 2500
# progress:  k = 4 j =  0  :  1265 / 2500
# progress:  k = 4 j =  0  :  1266 / 2500
# progress:  k = 4 j =  0  :  1267 / 2500
# progress:  k = 4 j =  0  :  1268 / 2500
# progress:  k = 4 j =  0  :  1269 / 2500
# progress:  k = 4 j =  0  :  1270 / 2500
# progress:  k = 4 j =  0  :  1271 / 2500
# progress:  k = 4 j =  0  :  1272 / 2500
# progress:  k = 4 j =  0  :  1273 / 2500
# progress:  k = 4 j =  0  :  1274 / 2500
# Error on  1275  and set lengths at random
# progress:  k = 4 j =  0  :  1276 / 2500
# progress:  k = 4 j =  0  :  1277 / 2500
# progress:  k = 4 j =  0  :  1278 / 2500
# progress:  k = 4 j =  0  :  1279 / 2500
# progress:  k = 4 j =  0  :  1280 / 2500
# progress:  k = 4 j =  0  :  1281 / 2500
# progress:  k = 4 j =  0  :  1282 / 2500
# progress:  k = 4 j =  0  :  1283 / 2500
# progress:  k = 4 j =  0  :  1284 / 2500
# progress:  k = 4 j =  0  :  1285 / 2500
# progress:  k = 4 j =  0  :  1286 / 2500
# progress:  k = 4 j =  0  :  1287 / 2500
# progress:  k = 4 j =  0  :  1288 / 2500
# progress:  k = 4 j =  0  :  1289 / 2500
# progress:  k = 4 j =  0  :  1290 / 2500
# progress:  k = 4 j =  0  :  1291 / 2500
# progress:  k = 4 j =  0  :  1292 / 2500
# progress:  k = 4 j =  0  :  1293 / 2500
# progress:  k = 4 j =  0  :  1294 / 2500
# progress:  k = 4 j =  0  :  1295 / 2500
# progress:  k = 4 j =  0  :  1296 / 2500
# progress:  k = 4 j =  0  :  1297 / 2500
# progress:  k = 4 j =  0  :  1298 / 2500
# progress:  k = 4 j =  0  :  1299 / 2500
# progress:  k = 4 j =  0  :  1300 / 2500
# progress:  k = 4 j =  0  :  1301 / 2500
# progress:  k = 4 j =  0  :  1302 / 2500
# progress:  k = 4 j =  0  :  1303 / 2500
# progress:  k = 4 j =  0  :  1304 / 2500
# progress:  k = 4 j =  0  :  1305 / 2500
# progress:  k = 4 j =  0  :  1306 / 2500
# progress:  k = 4 j =  0  :  1307 / 2500
# progress:  k = 4 j =  0  :  1308 / 2500
# progress:  k = 4 j =  0  :  1309 / 2500
# progress:  k = 4 j =  0  :  1310 / 2500
# progress:  k = 4 j =  0  :  1311 / 2500
# progress:  k = 4 j =  0  :  1312 / 2500
# progress:  k = 4 j =  0  :  1313 / 2500
# progress:  k = 4 j =  0  :  1314 / 2500
# progress:  k = 4 j =  0  :  1315 / 2500
# progress:  k = 4 j =  0  :  1316 / 2500
# progress:  k = 4 j =  0  :  1317 / 2500
# progress:  k = 4 j =  0  :  1318 / 2500
# progress:  k = 4 j =  0  :  1319 / 2500
# progress:  k = 4 j =  0  :  1320 / 2500
# progress:  k = 4 j =  0  :  1321 / 2500
# progress:  k = 4 j =  0  :  1322 / 2500
# progress:  k = 4 j =  0  :  1323 / 2500
# progress:  k = 4 j =  0  :  1324 / 2500
# progress:  k = 4 j =  0  :  1325 / 2500
# Error on  1326  and set lengths at random
# progress:  k = 4 j =  0  :  1327 / 2500
# progress:  k = 4 j =  0  :  1328 / 2500
# progress:  k = 4 j =  0  :  1329 / 2500
# progress:  k = 4 j =  0  :  1330 / 2500
# progress:  k = 4 j =  0  :  1331 / 2500
# progress:  k = 4 j =  0  :  1332 / 2500
# progress:  k = 4 j =  0  :  1333 / 2500
# progress:  k = 4 j =  0  :  1334 / 2500
# progress:  k = 4 j =  0  :  1335 / 2500
# progress:  k = 4 j =  0  :  1336 / 2500
# progress:  k = 4 j =  0  :  1337 / 2500
# progress:  k = 4 j =  0  :  1338 / 2500
# progress:  k = 4 j =  0  :  1339 / 2500
# progress:  k = 4 j =  0  :  1340 / 2500
# progress:  k = 4 j =  0  :  1341 / 2500
# progress:  k = 4 j =  0  :  1342 / 2500
# progress:  k = 4 j =  0  :  1343 / 2500
# progress:  k = 4 j =  0  :  1344 / 2500
# progress:  k = 4 j =  0  :  1345 / 2500
# progress:  k = 4 j =  0  :  1346 / 2500
# progress:  k = 4 j =  0  :  1347 / 2500
# progress:  k = 4 j =  0  :  1348 / 2500
# progress:  k = 4 j =  0  :  1349 / 2500
# progress:  k = 4 j =  0  :  1350 / 2500
# progress:  k = 4 j =  0  :  1351 / 2500
# progress:  k = 4 j =  0  :  1352 / 2500
# progress:  k = 4 j =  0  :  1353 / 2500
# progress:  k = 4 j =  0  :  1354 / 2500
# progress:  k = 4 j =  0  :  1355 / 2500
# progress:  k = 4 j =  0  :  1356 / 2500
# progress:  k = 4 j =  0  :  1357 / 2500
# progress:  k = 4 j =  0  :  1358 / 2500
# progress:  k = 4 j =  0  :  1359 / 2500
# progress:  k = 4 j =  0  :  1360 / 2500
# progress:  k = 4 j =  0  :  1361 / 2500
# progress:  k = 4 j =  0  :  1362 / 2500
# progress:  k = 4 j =  0  :  1363 / 2500
# progress:  k = 4 j =  0  :  1364 / 2500
# progress:  k = 4 j =  0  :  1365 / 2500
# progress:  k = 4 j =  0  :  1366 / 2500
# progress:  k = 4 j =  0  :  1367 / 2500
# progress:  k = 4 j =  0  :  1368 / 2500
# progress:  k = 4 j =  0  :  1369 / 2500
# progress:  k = 4 j =  0  :  1370 / 2500
# progress:  k = 4 j =  0  :  1371 / 2500
# progress:  k = 4 j =  0  :  1372 / 2500
# progress:  k = 4 j =  0  :  1373 / 2500
# progress:  k = 4 j =  0  :  1374 / 2500
# progress:  k = 4 j =  0  :  1375 / 2500
# progress:  k = 4 j =  0  :  1376 / 2500
# progress:  k = 4 j =  0  :  1377 / 2500
# progress:  k = 4 j =  0  :  1378 / 2500
# progress:  k = 4 j =  0  :  1379 / 2500
# progress:  k = 4 j =  0  :  1380 / 2500
# progress:  k = 4 j =  0  :  1381 / 2500
# progress:  k = 4 j =  0  :  1382 / 2500
# progress:  k = 4 j =  0  :  1383 / 2500
# progress:  k = 4 j =  0  :  1384 / 2500
# progress:  k = 4 j =  0  :  1385 / 2500
# progress:  k = 4 j =  0  :  1386 / 2500
# progress:  k = 4 j =  0  :  1387 / 2500
# progress:  k = 4 j =  0  :  1388 / 2500
# progress:  k = 4 j =  0  :  1389 / 2500
# progress:  k = 4 j =  0  :  1390 / 2500
# progress:  k = 4 j =  0  :  1391 / 2500
# progress:  k = 4 j =  0  :  1392 / 2500
# progress:  k = 4 j =  0  :  1393 / 2500
# progress:  k = 4 j =  0  :  1394 / 2500
# progress:  k = 4 j =  0  :  1395 / 2500
# progress:  k = 4 j =  0  :  1396 / 2500
# progress:  k = 4 j =  0  :  1397 / 2500
# progress:  k = 4 j =  0  :  1398 / 2500
# progress:  k = 4 j =  0  :  1399 / 2500
# progress:  k = 4 j =  0  :  1400 / 2500
# progress:  k = 4 j =  0  :  1401 / 2500
# progress:  k = 4 j =  0  :  1402 / 2500
# progress:  k = 4 j =  0  :  1403 / 2500
# progress:  k = 4 j =  0  :  1404 / 2500
# progress:  k = 4 j =  0  :  1405 / 2500
# progress:  k = 4 j =  0  :  1406 / 2500
# progress:  k = 4 j =  0  :  1407 / 2500
# progress:  k = 4 j =  0  :  1408 / 2500
# progress:  k = 4 j =  0  :  1409 / 2500
# progress:  k = 4 j =  0  :  1410 / 2500
# progress:  k = 4 j =  0  :  1411 / 2500
# progress:  k = 4 j =  0  :  1412 / 2500
# progress:  k = 4 j =  0  :  1413 / 2500
# progress:  k = 4 j =  0  :  1414 / 2500
# progress:  k = 4 j =  0  :  1415 / 2500
# progress:  k = 4 j =  0  :  1416 / 2500
# progress:  k = 4 j =  0  :  1417 / 2500
# progress:  k = 4 j =  0  :  1418 / 2500
# progress:  k = 4 j =  0  :  1419 / 2500
# progress:  k = 4 j =  0  :  1420 / 2500
# progress:  k = 4 j =  0  :  1421 / 2500
# progress:  k = 4 j =  0  :  1422 / 2500
# progress:  k = 4 j =  0  :  1423 / 2500
# progress:  k = 4 j =  0  :  1424 / 2500
# progress:  k = 4 j =  0  :  1425 / 2500
# progress:  k = 4 j =  0  :  1426 / 2500
# progress:  k = 4 j =  0  :  1427 / 2500
# progress:  k = 4 j =  0  :  1428 / 2500
# progress:  k = 4 j =  0  :  1429 / 2500
# progress:  k = 4 j =  0  :  1430 / 2500
# progress:  k = 4 j =  0  :  1431 / 2500
# progress:  k = 4 j =  0  :  1432 / 2500
# progress:  k = 4 j =  0  :  1433 / 2500
# progress:  k = 4 j =  0  :  1434 / 2500
# progress:  k = 4 j =  0  :  1435 / 2500
# progress:  k = 4 j =  0  :  1436 / 2500
# progress:  k = 4 j =  0  :  1437 / 2500
# progress:  k = 4 j =  0  :  1438 / 2500
# progress:  k = 4 j =  0  :  1439 / 2500
# progress:  k = 4 j =  0  :  1440 / 2500
# progress:  k = 4 j =  0  :  1441 / 2500
# progress:  k = 4 j =  0  :  1442 / 2500
# progress:  k = 4 j =  0  :  1443 / 2500
# progress:  k = 4 j =  0  :  1444 / 2500
# progress:  k = 4 j =  0  :  1445 / 2500
# progress:  k = 4 j =  0  :  1446 / 2500
# progress:  k = 4 j =  0  :  1447 / 2500
# progress:  k = 4 j =  0  :  1448 / 2500
# progress:  k = 4 j =  0  :  1449 / 2500
# progress:  k = 4 j =  0  :  1450 / 2500
# progress:  k = 4 j =  0  :  1451 / 2500
# progress:  k = 4 j =  0  :  1452 / 2500
# progress:  k = 4 j =  0  :  1453 / 2500
# progress:  k = 4 j =  0  :  1454 / 2500
# progress:  k = 4 j =  0  :  1455 / 2500
# progress:  k = 4 j =  0  :  1456 / 2500
# progress:  k = 4 j =  0  :  1457 / 2500
# progress:  k = 4 j =  0  :  1458 / 2500
# progress:  k = 4 j =  0  :  1459 / 2500
# progress:  k = 4 j =  0  :  1460 / 2500
# progress:  k = 4 j =  0  :  1461 / 2500
# progress:  k = 4 j =  0  :  1462 / 2500
# progress:  k = 4 j =  0  :  1463 / 2500
# progress:  k = 4 j =  0  :  1464 / 2500
# progress:  k = 4 j =  0  :  1465 / 2500
# progress:  k = 4 j =  0  :  1466 / 2500
# progress:  k = 4 j =  0  :  1467 / 2500
# progress:  k = 4 j =  0  :  1468 / 2500
# progress:  k = 4 j =  0  :  1469 / 2500
# progress:  k = 4 j =  0  :  1470 / 2500
# progress:  k = 4 j =  0  :  1471 / 2500
# progress:  k = 4 j =  0  :  1472 / 2500
# progress:  k = 4 j =  0  :  1473 / 2500
# progress:  k = 4 j =  0  :  1474 / 2500
# progress:  k = 4 j =  0  :  1475 / 2500
# progress:  k = 4 j =  0  :  1476 / 2500
# progress:  k = 4 j =  0  :  1477 / 2500
# progress:  k = 4 j =  0  :  1478 / 2500
# progress:  k = 4 j =  0  :  1479 / 2500
# progress:  k = 4 j =  0  :  1480 / 2500
# progress:  k = 4 j =  0  :  1481 / 2500
# progress:  k = 4 j =  0  :  1482 / 2500
# progress:  k = 4 j =  0  :  1483 / 2500
# progress:  k = 4 j =  0  :  1484 / 2500
# progress:  k = 4 j =  0  :  1485 / 2500
# progress:  k = 4 j =  0  :  1486 / 2500
# progress:  k = 4 j =  0  :  1487 / 2500
# progress:  k = 4 j =  0  :  1488 / 2500
# progress:  k = 4 j =  0  :  1489 / 2500
# progress:  k = 4 j =  0  :  1490 / 2500
# progress:  k = 4 j =  0  :  1491 / 2500
# progress:  k = 4 j =  0  :  1492 / 2500
# progress:  k = 4 j =  0  :  1493 / 2500
# progress:  k = 4 j =  0  :  1494 / 2500
# progress:  k = 4 j =  0  :  1495 / 2500
# progress:  k = 4 j =  0  :  1496 / 2500
# progress:  k = 4 j =  0  :  1497 / 2500
# progress:  k = 4 j =  0  :  1498 / 2500
# progress:  k = 4 j =  0  :  1499 / 2500
# progress:  k = 4 j =  0  :  1500 / 2500
# progress:  k = 4 j =  0  :  1501 / 2500
# progress:  k = 4 j =  0  :  1502 / 2500
# progress:  k = 4 j =  0  :  1503 / 2500
# progress:  k = 4 j =  0  :  1504 / 2500
# progress:  k = 4 j =  0  :  1505 / 2500
# progress:  k = 4 j =  0  :  1506 / 2500
# progress:  k = 4 j =  0  :  1507 / 2500
# progress:  k = 4 j =  0  :  1508 / 2500
# progress:  k = 4 j =  0  :  1509 / 2500
# progress:  k = 4 j =  0  :  1510 / 2500
# progress:  k = 4 j =  0  :  1511 / 2500
# progress:  k = 4 j =  0  :  1512 / 2500
# progress:  k = 4 j =  0  :  1513 / 2500
# progress:  k = 4 j =  0  :  1514 / 2500
# progress:  k = 4 j =  0  :  1515 / 2500
# progress:  k = 4 j =  0  :  1516 / 2500
# progress:  k = 4 j =  0  :  1517 / 2500
# progress:  k = 4 j =  0  :  1518 / 2500
# progress:  k = 4 j =  0  :  1519 / 2500
# progress:  k = 4 j =  0  :  1520 / 2500
# progress:  k = 4 j =  0  :  1521 / 2500
# progress:  k = 4 j =  0  :  1522 / 2500
# progress:  k = 4 j =  0  :  1523 / 2500
# progress:  k = 4 j =  0  :  1524 / 2500
# progress:  k = 4 j =  0  :  1525 / 2500
# progress:  k = 4 j =  0  :  1526 / 2500
# progress:  k = 4 j =  0  :  1527 / 2500
# progress:  k = 4 j =  0  :  1528 / 2500
# progress:  k = 4 j =  0  :  1529 / 2500
# progress:  k = 4 j =  0  :  1530 / 2500
# progress:  k = 4 j =  0  :  1531 / 2500
# progress:  k = 4 j =  0  :  1532 / 2500
# progress:  k = 4 j =  0  :  1533 / 2500
# progress:  k = 4 j =  0  :  1534 / 2500
# progress:  k = 4 j =  0  :  1535 / 2500
# progress:  k = 4 j =  0  :  1536 / 2500
# progress:  k = 4 j =  0  :  1537 / 2500
# progress:  k = 4 j =  0  :  1538 / 2500
# progress:  k = 4 j =  0  :  1539 / 2500
# progress:  k = 4 j =  0  :  1540 / 2500
# progress:  k = 4 j =  0  :  1541 / 2500
# progress:  k = 4 j =  0  :  1542 / 2500
# progress:  k = 4 j =  0  :  1543 / 2500
# progress:  k = 4 j =  0  :  1544 / 2500
# progress:  k = 4 j =  0  :  1545 / 2500
# progress:  k = 4 j =  0  :  1546 / 2500
# progress:  k = 4 j =  0  :  1547 / 2500
# progress:  k = 4 j =  0  :  1548 / 2500
# progress:  k = 4 j =  0  :  1549 / 2500
# progress:  k = 4 j =  0  :  1550 / 2500
# progress:  k = 4 j =  0  :  1551 / 2500
# progress:  k = 4 j =  0  :  1552 / 2500
# progress:  k = 4 j =  0  :  1553 / 2500
# progress:  k = 4 j =  0  :  1554 / 2500
# progress:  k = 4 j =  0  :  1555 / 2500
# progress:  k = 4 j =  0  :  1556 / 2500
# progress:  k = 4 j =  0  :  1557 / 2500
# progress:  k = 4 j =  0  :  1558 / 2500
# progress:  k = 4 j =  0  :  1559 / 2500
# progress:  k = 4 j =  0  :  1560 / 2500
# progress:  k = 4 j =  0  :  1561 / 2500
# progress:  k = 4 j =  0  :  1562 / 2500
# progress:  k = 4 j =  0  :  1563 / 2500
# progress:  k = 4 j =  0  :  1564 / 2500
# progress:  k = 4 j =  0  :  1565 / 2500
# progress:  k = 4 j =  0  :  1566 / 2500
# progress:  k = 4 j =  0  :  1567 / 2500
# progress:  k = 4 j =  0  :  1568 / 2500
# progress:  k = 4 j =  0  :  1569 / 2500
# progress:  k = 4 j =  0  :  1570 / 2500
# progress:  k = 4 j =  0  :  1571 / 2500
# progress:  k = 4 j =  0  :  1572 / 2500
# progress:  k = 4 j =  0  :  1573 / 2500
# progress:  k = 4 j =  0  :  1574 / 2500
# progress:  k = 4 j =  0  :  1575 / 2500
# progress:  k = 4 j =  0  :  1576 / 2500
# progress:  k = 4 j =  0  :  1577 / 2500
# progress:  k = 4 j =  0  :  1578 / 2500
# progress:  k = 4 j =  0  :  1579 / 2500
# progress:  k = 4 j =  0  :  1580 / 2500
# progress:  k = 4 j =  0  :  1581 / 2500
# progress:  k = 4 j =  0  :  1582 / 2500
# progress:  k = 4 j =  0  :  1583 / 2500
# progress:  k = 4 j =  0  :  1584 / 2500
# progress:  k = 4 j =  0  :  1585 / 2500
# progress:  k = 4 j =  0  :  1586 / 2500
# progress:  k = 4 j =  0  :  1587 / 2500
# progress:  k = 4 j =  0  :  1588 / 2500
# progress:  k = 4 j =  0  :  1589 / 2500
# progress:  k = 4 j =  0  :  1590 / 2500
# progress:  k = 4 j =  0  :  1591 / 2500
# progress:  k = 4 j =  0  :  1592 / 2500
# progress:  k = 4 j =  0  :  1593 / 2500
# progress:  k = 4 j =  0  :  1594 / 2500
# progress:  k = 4 j =  0  :  1595 / 2500
# progress:  k = 4 j =  0  :  1596 / 2500
# progress:  k = 4 j =  0  :  1597 / 2500
# progress:  k = 4 j =  0  :  1598 / 2500
# progress:  k = 4 j =  0  :  1599 / 2500
# progress:  k = 4 j =  0  :  1600 / 2500
# progress:  k = 4 j =  0  :  1601 / 2500
# progress:  k = 4 j =  0  :  1602 / 2500
# progress:  k = 4 j =  0  :  1603 / 2500
# progress:  k = 4 j =  0  :  1604 / 2500
# progress:  k = 4 j =  0  :  1605 / 2500
# progress:  k = 4 j =  0  :  1606 / 2500
# progress:  k = 4 j =  0  :  1607 / 2500
# progress:  k = 4 j =  0  :  1608 / 2500
# progress:  k = 4 j =  0  :  1609 / 2500
# progress:  k = 4 j =  0  :  1610 / 2500
# progress:  k = 4 j =  0  :  1611 / 2500
# progress:  k = 4 j =  0  :  1612 / 2500
# progress:  k = 4 j =  0  :  1613 / 2500
# progress:  k = 4 j =  0  :  1614 / 2500
# progress:  k = 4 j =  0  :  1615 / 2500
# progress:  k = 4 j =  0  :  1616 / 2500
# progress:  k = 4 j =  0  :  1617 / 2500
# progress:  k = 4 j =  0  :  1618 / 2500
# progress:  k = 4 j =  0  :  1619 / 2500
# progress:  k = 4 j =  0  :  1620 / 2500
# progress:  k = 4 j =  0  :  1621 / 2500
# progress:  k = 4 j =  0  :  1622 / 2500
# progress:  k = 4 j =  0  :  1623 / 2500
# progress:  k = 4 j =  0  :  1624 / 2500
# progress:  k = 4 j =  0  :  1625 / 2500
# progress:  k = 4 j =  0  :  1626 / 2500
# progress:  k = 4 j =  0  :  1627 / 2500
# progress:  k = 4 j =  0  :  1628 / 2500
# progress:  k = 4 j =  0  :  1629 / 2500
# progress:  k = 4 j =  0  :  1630 / 2500
# progress:  k = 4 j =  0  :  1631 / 2500
# progress:  k = 4 j =  0  :  1632 / 2500
# progress:  k = 4 j =  0  :  1633 / 2500
# progress:  k = 4 j =  0  :  1634 / 2500
# progress:  k = 4 j =  0  :  1635 / 2500
# progress:  k = 4 j =  0  :  1636 / 2500
# progress:  k = 4 j =  0  :  1637 / 2500
# progress:  k = 4 j =  0  :  1638 / 2500
# progress:  k = 4 j =  0  :  1639 / 2500
# progress:  k = 4 j =  0  :  1640 / 2500
# progress:  k = 4 j =  0  :  1641 / 2500
# progress:  k = 4 j =  0  :  1642 / 2500
# progress:  k = 4 j =  0  :  1643 / 2500
# progress:  k = 4 j =  0  :  1644 / 2500
# progress:  k = 4 j =  0  :  1645 / 2500
# progress:  k = 4 j =  0  :  1646 / 2500
# progress:  k = 4 j =  0  :  1647 / 2500
# progress:  k = 4 j =  0  :  1648 / 2500
# progress:  k = 4 j =  0  :  1649 / 2500
# progress:  k = 4 j =  0  :  1650 / 2500
# progress:  k = 4 j =  0  :  1651 / 2500
# progress:  k = 4 j =  0  :  1652 / 2500
# progress:  k = 4 j =  0  :  1653 / 2500
# progress:  k = 4 j =  0  :  1654 / 2500
# progress:  k = 4 j =  0  :  1655 / 2500
# progress:  k = 4 j =  0  :  1656 / 2500
# progress:  k = 4 j =  0  :  1657 / 2500
# progress:  k = 4 j =  0  :  1658 / 2500
# progress:  k = 4 j =  0  :  1659 / 2500
# progress:  k = 4 j =  0  :  1660 / 2500
# progress:  k = 4 j =  0  :  1661 / 2500
# progress:  k = 4 j =  0  :  1662 / 2500
# progress:  k = 4 j =  0  :  1663 / 2500
# progress:  k = 4 j =  0  :  1664 / 2500
# progress:  k = 4 j =  0  :  1665 / 2500
# progress:  k = 4 j =  0  :  1666 / 2500
# progress:  k = 4 j =  0  :  1667 / 2500
# progress:  k = 4 j =  0  :  1668 / 2500
# progress:  k = 4 j =  0  :  1669 / 2500
# progress:  k = 4 j =  0  :  1670 / 2500
# progress:  k = 4 j =  0  :  1671 / 2500
# progress:  k = 4 j =  0  :  1672 / 2500
# progress:  k = 4 j =  0  :  1673 / 2500
# progress:  k = 4 j =  0  :  1674 / 2500
# progress:  k = 4 j =  0  :  1675 / 2500
# progress:  k = 4 j =  0  :  1676 / 2500
# progress:  k = 4 j =  0  :  1677 / 2500
# progress:  k = 4 j =  0  :  1678 / 2500
# progress:  k = 4 j =  0  :  1679 / 2500
# progress:  k = 4 j =  0  :  1680 / 2500
# progress:  k = 4 j =  0  :  1681 / 2500
# progress:  k = 4 j =  0  :  1682 / 2500
# progress:  k = 4 j =  0  :  1683 / 2500
# progress:  k = 4 j =  0  :  1684 / 2500
# progress:  k = 4 j =  0  :  1685 / 2500
# progress:  k = 4 j =  0  :  1686 / 2500
# progress:  k = 4 j =  0  :  1687 / 2500
# progress:  k = 4 j =  0  :  1688 / 2500
# progress:  k = 4 j =  0  :  1689 / 2500
# progress:  k = 4 j =  0  :  1690 / 2500
# progress:  k = 4 j =  0  :  1691 / 2500
# progress:  k = 4 j =  0  :  1692 / 2500
# progress:  k = 4 j =  0  :  1693 / 2500
# progress:  k = 4 j =  0  :  1694 / 2500
# progress:  k = 4 j =  0  :  1695 / 2500
# progress:  k = 4 j =  0  :  1696 / 2500
# progress:  k = 4 j =  0  :  1697 / 2500
# progress:  k = 4 j =  0  :  1698 / 2500
# progress:  k = 4 j =  0  :  1699 / 2500
# progress:  k = 4 j =  0  :  1700 / 2500
# progress:  k = 4 j =  0  :  1701 / 2500
# progress:  k = 4 j =  0  :  1702 / 2500
# progress:  k = 4 j =  0  :  1703 / 2500
# progress:  k = 4 j =  0  :  1704 / 2500
# progress:  k = 4 j =  0  :  1705 / 2500
# progress:  k = 4 j =  0  :  1706 / 2500
# progress:  k = 4 j =  0  :  1707 / 2500
# progress:  k = 4 j =  0  :  1708 / 2500
# progress:  k = 4 j =  0  :  1709 / 2500
# progress:  k = 4 j =  0  :  1710 / 2500
# progress:  k = 4 j =  0  :  1711 / 2500
# progress:  k = 4 j =  0  :  1712 / 2500
# Error on  1713  and set lengths at random
# progress:  k = 4 j =  0  :  1714 / 2500
# progress:  k = 4 j =  0  :  1715 / 2500
# progress:  k = 4 j =  0  :  1716 / 2500
# progress:  k = 4 j =  0  :  1717 / 2500
# progress:  k = 4 j =  0  :  1718 / 2500
# progress:  k = 4 j =  0  :  1719 / 2500
# progress:  k = 4 j =  0  :  1720 / 2500
# progress:  k = 4 j =  0  :  1721 / 2500
# progress:  k = 4 j =  0  :  1722 / 2500
# progress:  k = 4 j =  0  :  1723 / 2500
# progress:  k = 4 j =  0  :  1724 / 2500
# progress:  k = 4 j =  0  :  1725 / 2500
# progress:  k = 4 j =  0  :  1726 / 2500
# progress:  k = 4 j =  0  :  1727 / 2500
# progress:  k = 4 j =  0  :  1728 / 2500
# progress:  k = 4 j =  0  :  1729 / 2500
# progress:  k = 4 j =  0  :  1730 / 2500
# progress:  k = 4 j =  0  :  1731 / 2500
# progress:  k = 4 j =  0  :  1732 / 2500
# progress:  k = 4 j =  0  :  1733 / 2500
# progress:  k = 4 j =  0  :  1734 / 2500
# progress:  k = 4 j =  0  :  1735 / 2500
# progress:  k = 4 j =  0  :  1736 / 2500
# progress:  k = 4 j =  0  :  1737 / 2500
# progress:  k = 4 j =  0  :  1738 / 2500
# progress:  k = 4 j =  0  :  1739 / 2500
# progress:  k = 4 j =  0  :  1740 / 2500
# progress:  k = 4 j =  0  :  1741 / 2500
# progress:  k = 4 j =  0  :  1742 / 2500
# progress:  k = 4 j =  0  :  1743 / 2500
# progress:  k = 4 j =  0  :  1744 / 2500
# progress:  k = 4 j =  0  :  1745 / 2500
# progress:  k = 4 j =  0  :  1746 / 2500
# progress:  k = 4 j =  0  :  1747 / 2500
# progress:  k = 4 j =  0  :  1748 / 2500
# progress:  k = 4 j =  0  :  1749 / 2500
# progress:  k = 4 j =  0  :  1750 / 2500
# progress:  k = 4 j =  0  :  1751 / 2500
# progress:  k = 4 j =  0  :  1752 / 2500
# progress:  k = 4 j =  0  :  1753 / 2500
# progress:  k = 4 j =  0  :  1754 / 2500
# progress:  k = 4 j =  0  :  1755 / 2500
# progress:  k = 4 j =  0  :  1756 / 2500
# progress:  k = 4 j =  0  :  1757 / 2500
# progress:  k = 4 j =  0  :  1758 / 2500
# progress:  k = 4 j =  0  :  1759 / 2500
# progress:  k = 4 j =  0  :  1760 / 2500
# progress:  k = 4 j =  0  :  1761 / 2500
# progress:  k = 4 j =  0  :  1762 / 2500
# progress:  k = 4 j =  0  :  1763 / 2500
# progress:  k = 4 j =  0  :  1764 / 2500
# progress:  k = 4 j =  0  :  1765 / 2500
# progress:  k = 4 j =  0  :  1766 / 2500
# progress:  k = 4 j =  0  :  1767 / 2500
# progress:  k = 4 j =  0  :  1768 / 2500
# progress:  k = 4 j =  0  :  1769 / 2500
# progress:  k = 4 j =  0  :  1770 / 2500
# progress:  k = 4 j =  0  :  1771 / 2500
# progress:  k = 4 j =  0  :  1772 / 2500
# progress:  k = 4 j =  0  :  1773 / 2500
# progress:  k = 4 j =  0  :  1774 / 2500
# progress:  k = 4 j =  0  :  1775 / 2500
# progress:  k = 4 j =  0  :  1776 / 2500
# progress:  k = 4 j =  0  :  1777 / 2500
# progress:  k = 4 j =  0  :  1778 / 2500
# progress:  k = 4 j =  0  :  1779 / 2500
# progress:  k = 4 j =  0  :  1780 / 2500
# progress:  k = 4 j =  0  :  1781 / 2500
# progress:  k = 4 j =  0  :  1782 / 2500
# progress:  k = 4 j =  0  :  1783 / 2500
# progress:  k = 4 j =  0  :  1784 / 2500
# progress:  k = 4 j =  0  :  1785 / 2500
# progress:  k = 4 j =  0  :  1786 / 2500
# progress:  k = 4 j =  0  :  1787 / 2500
# progress:  k = 4 j =  0  :  1788 / 2500
# progress:  k = 4 j =  0  :  1789 / 2500
# progress:  k = 4 j =  0  :  1790 / 2500
# progress:  k = 4 j =  0  :  1791 / 2500
# progress:  k = 4 j =  0  :  1792 / 2500
# progress:  k = 4 j =  0  :  1793 / 2500
# progress:  k = 4 j =  0  :  1794 / 2500
# progress:  k = 4 j =  0  :  1795 / 2500
# progress:  k = 4 j =  0  :  1796 / 2500
# progress:  k = 4 j =  0  :  1797 / 2500
# progress:  k = 4 j =  0  :  1798 / 2500
# progress:  k = 4 j =  0  :  1799 / 2500
# progress:  k = 4 j =  0  :  1800 / 2500
# progress:  k = 4 j =  0  :  1801 / 2500
# progress:  k = 4 j =  0  :  1802 / 2500
# progress:  k = 4 j =  0  :  1803 / 2500
# progress:  k = 4 j =  0  :  1804 / 2500
# progress:  k = 4 j =  0  :  1805 / 2500
# Error on  1806  and set lengths at random
# progress:  k = 4 j =  0  :  1807 / 2500
# progress:  k = 4 j =  0  :  1808 / 2500
# progress:  k = 4 j =  0  :  1809 / 2500
# progress:  k = 4 j =  0  :  1810 / 2500
# progress:  k = 4 j =  0  :  1811 / 2500
# progress:  k = 4 j =  0  :  1812 / 2500
# progress:  k = 4 j =  0  :  1813 / 2500
# progress:  k = 4 j =  0  :  1814 / 2500
# progress:  k = 4 j =  0  :  1815 / 2500
# progress:  k = 4 j =  0  :  1816 / 2500
# progress:  k = 4 j =  0  :  1817 / 2500
# progress:  k = 4 j =  0  :  1818 / 2500
# progress:  k = 4 j =  0  :  1819 / 2500
# progress:  k = 4 j =  0  :  1820 / 2500
# progress:  k = 4 j =  0  :  1821 / 2500
# progress:  k = 4 j =  0  :  1822 / 2500
# progress:  k = 4 j =  0  :  1823 / 2500
# progress:  k = 4 j =  0  :  1824 / 2500
# progress:  k = 4 j =  0  :  1825 / 2500
# progress:  k = 4 j =  0  :  1826 / 2500
# progress:  k = 4 j =  0  :  1827 / 2500
# progress:  k = 4 j =  0  :  1828 / 2500
# progress:  k = 4 j =  0  :  1829 / 2500
# progress:  k = 4 j =  0  :  1830 / 2500
# progress:  k = 4 j =  0  :  1831 / 2500
# progress:  k = 4 j =  0  :  1832 / 2500
# progress:  k = 4 j =  0  :  1833 / 2500
# progress:  k = 4 j =  0  :  1834 / 2500
# progress:  k = 4 j =  0  :  1835 / 2500
# progress:  k = 4 j =  0  :  1836 / 2500
# progress:  k = 4 j =  0  :  1837 / 2500
# progress:  k = 4 j =  0  :  1838 / 2500
# progress:  k = 4 j =  0  :  1839 / 2500
# progress:  k = 4 j =  0  :  1840 / 2500
# progress:  k = 4 j =  0  :  1841 / 2500
# progress:  k = 4 j =  0  :  1842 / 2500
# progress:  k = 4 j =  0  :  1843 / 2500
# progress:  k = 4 j =  0  :  1844 / 2500
# progress:  k = 4 j =  0  :  1845 / 2500
# progress:  k = 4 j =  0  :  1846 / 2500
# progress:  k = 4 j =  0  :  1847 / 2500
# progress:  k = 4 j =  0  :  1848 / 2500
# progress:  k = 4 j =  0  :  1849 / 2500
# progress:  k = 4 j =  0  :  1850 / 2500
# progress:  k = 4 j =  0  :  1851 / 2500
# progress:  k = 4 j =  0  :  1852 / 2500
# progress:  k = 4 j =  0  :  1853 / 2500
# progress:  k = 4 j =  0  :  1854 / 2500
# progress:  k = 4 j =  0  :  1855 / 2500
# progress:  k = 4 j =  0  :  1856 / 2500
# progress:  k = 4 j =  0  :  1857 / 2500
# progress:  k = 4 j =  0  :  1858 / 2500
# progress:  k = 4 j =  0  :  1859 / 2500
# progress:  k = 4 j =  0  :  1860 / 2500
# progress:  k = 4 j =  0  :  1861 / 2500
# progress:  k = 4 j =  0  :  1862 / 2500
# progress:  k = 4 j =  0  :  1863 / 2500
# progress:  k = 4 j =  0  :  1864 / 2500
# progress:  k = 4 j =  0  :  1865 / 2500
# progress:  k = 4 j =  0  :  1866 / 2500
# progress:  k = 4 j =  0  :  1867 / 2500
# progress:  k = 4 j =  0  :  1868 / 2500
# progress:  k = 4 j =  0  :  1869 / 2500
# progress:  k = 4 j =  0  :  1870 / 2500
# progress:  k = 4 j =  0  :  1871 / 2500
# progress:  k = 4 j =  0  :  1872 / 2500
# progress:  k = 4 j =  0  :  1873 / 2500
# progress:  k = 4 j =  0  :  1874 / 2500
# progress:  k = 4 j =  0  :  1875 / 2500
# progress:  k = 4 j =  0  :  1876 / 2500
# progress:  k = 4 j =  0  :  1877 / 2500
# progress:  k = 4 j =  0  :  1878 / 2500
# progress:  k = 4 j =  0  :  1879 / 2500
# progress:  k = 4 j =  0  :  1880 / 2500
# progress:  k = 4 j =  0  :  1881 / 2500
# progress:  k = 4 j =  0  :  1882 / 2500
# progress:  k = 4 j =  0  :  1883 / 2500
# progress:  k = 4 j =  0  :  1884 / 2500
# progress:  k = 4 j =  0  :  1885 / 2500
# progress:  k = 4 j =  0  :  1886 / 2500
# progress:  k = 4 j =  0  :  1887 / 2500
# progress:  k = 4 j =  0  :  1888 / 2500
# progress:  k = 4 j =  0  :  1889 / 2500
# progress:  k = 4 j =  0  :  1890 / 2500
# progress:  k = 4 j =  0  :  1891 / 2500
# progress:  k = 4 j =  0  :  1892 / 2500
# Error on  1893  and set lengths at random
# progress:  k = 4 j =  0  :  1894 / 2500
# progress:  k = 4 j =  0  :  1895 / 2500
# progress:  k = 4 j =  0  :  1896 / 2500
# progress:  k = 4 j =  0  :  1897 / 2500
# progress:  k = 4 j =  0  :  1898 / 2500
# progress:  k = 4 j =  0  :  1899 / 2500
# progress:  k = 4 j =  0  :  1900 / 2500
# progress:  k = 4 j =  0  :  1901 / 2500
# progress:  k = 4 j =  0  :  1902 / 2500
# progress:  k = 4 j =  0  :  1903 / 2500
# progress:  k = 4 j =  0  :  1904 / 2500
# progress:  k = 4 j =  0  :  1905 / 2500
# progress:  k = 4 j =  0  :  1906 / 2500
# progress:  k = 4 j =  0  :  1907 / 2500
# progress:  k = 4 j =  0  :  1908 / 2500
# progress:  k = 4 j =  0  :  1909 / 2500
# progress:  k = 4 j =  0  :  1910 / 2500
# progress:  k = 4 j =  0  :  1911 / 2500
# progress:  k = 4 j =  0  :  1912 / 2500
# progress:  k = 4 j =  0  :  1913 / 2500
# progress:  k = 4 j =  0  :  1914 / 2500
# progress:  k = 4 j =  0  :  1915 / 2500
# progress:  k = 4 j =  0  :  1916 / 2500
# progress:  k = 4 j =  0  :  1917 / 2500
# progress:  k = 4 j =  0  :  1918 / 2500
# progress:  k = 4 j =  0  :  1919 / 2500
# progress:  k = 4 j =  0  :  1920 / 2500
# progress:  k = 4 j =  0  :  1921 / 2500
# progress:  k = 4 j =  0  :  1922 / 2500
# progress:  k = 4 j =  0  :  1923 / 2500
# progress:  k = 4 j =  0  :  1924 / 2500
# progress:  k = 4 j =  0  :  1925 / 2500
# progress:  k = 4 j =  0  :  1926 / 2500
# progress:  k = 4 j =  0  :  1927 / 2500
# progress:  k = 4 j =  0  :  1928 / 2500
# progress:  k = 4 j =  0  :  1929 / 2500
# progress:  k = 4 j =  0  :  1930 / 2500
# progress:  k = 4 j =  0  :  1931 / 2500
# progress:  k = 4 j =  0  :  1932 / 2500
# progress:  k = 4 j =  0  :  1933 / 2500
# progress:  k = 4 j =  0  :  1934 / 2500
# progress:  k = 4 j =  0  :  1935 / 2500
# progress:  k = 4 j =  0  :  1936 / 2500
# progress:  k = 4 j =  0  :  1937 / 2500
# progress:  k = 4 j =  0  :  1938 / 2500
# progress:  k = 4 j =  0  :  1939 / 2500
# progress:  k = 4 j =  0  :  1940 / 2500
# progress:  k = 4 j =  0  :  1941 / 2500
# progress:  k = 4 j =  0  :  1942 / 2500
# progress:  k = 4 j =  0  :  1943 / 2500
# progress:  k = 4 j =  0  :  1944 / 2500
# progress:  k = 4 j =  0  :  1945 / 2500
# progress:  k = 4 j =  0  :  1946 / 2500
# progress:  k = 4 j =  0  :  1947 / 2500
# progress:  k = 4 j =  0  :  1948 / 2500
# progress:  k = 4 j =  0  :  1949 / 2500
# progress:  k = 4 j =  0  :  1950 / 2500
# progress:  k = 4 j =  0  :  1951 / 2500
# progress:  k = 4 j =  0  :  1952 / 2500
# progress:  k = 4 j =  0  :  1953 / 2500
# progress:  k = 4 j =  0  :  1954 / 2500
# progress:  k = 4 j =  0  :  1955 / 2500
# progress:  k = 4 j =  0  :  1956 / 2500
# progress:  k = 4 j =  0  :  1957 / 2500
# progress:  k = 4 j =  0  :  1958 / 2500
# progress:  k = 4 j =  0  :  1959 / 2500
# progress:  k = 4 j =  0  :  1960 / 2500
# progress:  k = 4 j =  0  :  1961 / 2500
# progress:  k = 4 j =  0  :  1962 / 2500
# progress:  k = 4 j =  0  :  1963 / 2500
# progress:  k = 4 j =  0  :  1964 / 2500
# progress:  k = 4 j =  0  :  1965 / 2500
# progress:  k = 4 j =  0  :  1966 / 2500
# progress:  k = 4 j =  0  :  1967 / 2500
# progress:  k = 4 j =  0  :  1968 / 2500
# progress:  k = 4 j =  0  :  1969 / 2500
# progress:  k = 4 j =  0  :  1970 / 2500
# progress:  k = 4 j =  0  :  1971 / 2500
# progress:  k = 4 j =  0  :  1972 / 2500
# progress:  k = 4 j =  0  :  1973 / 2500
# progress:  k = 4 j =  0  :  1974 / 2500
# progress:  k = 4 j =  0  :  1975 / 2500
# progress:  k = 4 j =  0  :  1976 / 2500
# progress:  k = 4 j =  0  :  1977 / 2500
# progress:  k = 4 j =  0  :  1978 / 2500
# progress:  k = 4 j =  0  :  1979 / 2500
# progress:  k = 4 j =  0  :  1980 / 2500
# progress:  k = 4 j =  0  :  1981 / 2500
# progress:  k = 4 j =  0  :  1982 / 2500
# progress:  k = 4 j =  0  :  1983 / 2500
# progress:  k = 4 j =  0  :  1984 / 2500
# progress:  k = 4 j =  0  :  1985 / 2500
# progress:  k = 4 j =  0  :  1986 / 2500
# progress:  k = 4 j =  0  :  1987 / 2500
# progress:  k = 4 j =  0  :  1988 / 2500
# progress:  k = 4 j =  0  :  1989 / 2500
# progress:  k = 4 j =  0  :  1990 / 2500
# progress:  k = 4 j =  0  :  1991 / 2500
# progress:  k = 4 j =  0  :  1992 / 2500
# progress:  k = 4 j =  0  :  1993 / 2500
# progress:  k = 4 j =  0  :  1994 / 2500
# progress:  k = 4 j =  0  :  1995 / 2500
# Error on  1996  and set lengths at random
# progress:  k = 4 j =  0  :  1997 / 2500
# progress:  k = 4 j =  0  :  1998 / 2500
# progress:  k = 4 j =  0  :  1999 / 2500
# progress:  k = 4 j =  0  :  2000 / 2500
# progress:  k = 4 j =  0  :  2001 / 2500
# progress:  k = 4 j =  0  :  2002 / 2500
# progress:  k = 4 j =  0  :  2003 / 2500
# progress:  k = 4 j =  0  :  2004 / 2500
# progress:  k = 4 j =  0  :  2005 / 2500
# progress:  k = 4 j =  0  :  2006 / 2500
# progress:  k = 4 j =  0  :  2007 / 2500
# progress:  k = 4 j =  0  :  2008 / 2500
# progress:  k = 4 j =  0  :  2009 / 2500
# progress:  k = 4 j =  0  :  2010 / 2500
# progress:  k = 4 j =  0  :  2011 / 2500
# Error on  2012  and set lengths at random
# progress:  k = 4 j =  0  :  2013 / 2500
# progress:  k = 4 j =  0  :  2014 / 2500
# progress:  k = 4 j =  0  :  2015 / 2500
# progress:  k = 4 j =  0  :  2016 / 2500
# progress:  k = 4 j =  0  :  2017 / 2500
# progress:  k = 4 j =  0  :  2018 / 2500
# progress:  k = 4 j =  0  :  2019 / 2500
# progress:  k = 4 j =  0  :  2020 / 2500
# progress:  k = 4 j =  0  :  2021 / 2500
# progress:  k = 4 j =  0  :  2022 / 2500
# progress:  k = 4 j =  0  :  2023 / 2500
# progress:  k = 4 j =  0  :  2024 / 2500
# progress:  k = 4 j =  0  :  2025 / 2500
# progress:  k = 4 j =  0  :  2026 / 2500
# progress:  k = 4 j =  0  :  2027 / 2500
# progress:  k = 4 j =  0  :  2028 / 2500
# progress:  k = 4 j =  0  :  2029 / 2500
# progress:  k = 4 j =  0  :  2030 / 2500
# progress:  k = 4 j =  0  :  2031 / 2500
# progress:  k = 4 j =  0  :  2032 / 2500
# progress:  k = 4 j =  0  :  2033 / 2500
# progress:  k = 4 j =  0  :  2034 / 2500
# progress:  k = 4 j =  0  :  2035 / 2500
# progress:  k = 4 j =  0  :  2036 / 2500
# progress:  k = 4 j =  0  :  2037 / 2500
# progress:  k = 4 j =  0  :  2038 / 2500
# progress:  k = 4 j =  0  :  2039 / 2500
# progress:  k = 4 j =  0  :  2040 / 2500
# progress:  k = 4 j =  0  :  2041 / 2500
# progress:  k = 4 j =  0  :  2042 / 2500
# progress:  k = 4 j =  0  :  2043 / 2500
# progress:  k = 4 j =  0  :  2044 / 2500
# progress:  k = 4 j =  0  :  2045 / 2500
# progress:  k = 4 j =  0  :  2046 / 2500
# progress:  k = 4 j =  0  :  2047 / 2500
# progress:  k = 4 j =  0  :  2048 / 2500
# progress:  k = 4 j =  0  :  2049 / 2500
# progress:  k = 4 j =  0  :  2050 / 2500
# progress:  k = 4 j =  0  :  2051 / 2500
# progress:  k = 4 j =  0  :  2052 / 2500
# progress:  k = 4 j =  0  :  2053 / 2500
# progress:  k = 4 j =  0  :  2054 / 2500
# progress:  k = 4 j =  0  :  2055 / 2500
# progress:  k = 4 j =  0  :  2056 / 2500
# progress:  k = 4 j =  0  :  2057 / 2500
# progress:  k = 4 j =  0  :  2058 / 2500
# progress:  k = 4 j =  0  :  2059 / 2500
# progress:  k = 4 j =  0  :  2060 / 2500
# progress:  k = 4 j =  0  :  2061 / 2500
# progress:  k = 4 j =  0  :  2062 / 2500
# progress:  k = 4 j =  0  :  2063 / 2500
# progress:  k = 4 j =  0  :  2064 / 2500
# progress:  k = 4 j =  0  :  2065 / 2500
# progress:  k = 4 j =  0  :  2066 / 2500
# progress:  k = 4 j =  0  :  2067 / 2500
# progress:  k = 4 j =  0  :  2068 / 2500
# progress:  k = 4 j =  0  :  2069 / 2500
# progress:  k = 4 j =  0  :  2070 / 2500
# progress:  k = 4 j =  0  :  2071 / 2500
# progress:  k = 4 j =  0  :  2072 / 2500
# progress:  k = 4 j =  0  :  2073 / 2500
# progress:  k = 4 j =  0  :  2074 / 2500
# progress:  k = 4 j =  0  :  2075 / 2500
# progress:  k = 4 j =  0  :  2076 / 2500
# progress:  k = 4 j =  0  :  2077 / 2500
# progress:  k = 4 j =  0  :  2078 / 2500
# progress:  k = 4 j =  0  :  2079 / 2500
# progress:  k = 4 j =  0  :  2080 / 2500
# progress:  k = 4 j =  0  :  2081 / 2500
# progress:  k = 4 j =  0  :  2082 / 2500
# progress:  k = 4 j =  0  :  2083 / 2500
# progress:  k = 4 j =  0  :  2084 / 2500
# progress:  k = 4 j =  0  :  2085 / 2500
# progress:  k = 4 j =  0  :  2086 / 2500
# progress:  k = 4 j =  0  :  2087 / 2500
# progress:  k = 4 j =  0  :  2088 / 2500
# progress:  k = 4 j =  0  :  2089 / 2500
# progress:  k = 4 j =  0  :  2090 / 2500
# progress:  k = 4 j =  0  :  2091 / 2500
# progress:  k = 4 j =  0  :  2092 / 2500
# progress:  k = 4 j =  0  :  2093 / 2500
# progress:  k = 4 j =  0  :  2094 / 2500
# progress:  k = 4 j =  0  :  2095 / 2500
# progress:  k = 4 j =  0  :  2096 / 2500
# progress:  k = 4 j =  0  :  2097 / 2500
# progress:  k = 4 j =  0  :  2098 / 2500
# progress:  k = 4 j =  0  :  2099 / 2500
# progress:  k = 4 j =  0  :  2100 / 2500
# progress:  k = 4 j =  0  :  2101 / 2500
# progress:  k = 4 j =  0  :  2102 / 2500
# progress:  k = 4 j =  0  :  2103 / 2500
# progress:  k = 4 j =  0  :  2104 / 2500
# progress:  k = 4 j =  0  :  2105 / 2500
# progress:  k = 4 j =  0  :  2106 / 2500
# progress:  k = 4 j =  0  :  2107 / 2500
# progress:  k = 4 j =  0  :  2108 / 2500
# progress:  k = 4 j =  0  :  2109 / 2500
# progress:  k = 4 j =  0  :  2110 / 2500
# progress:  k = 4 j =  0  :  2111 / 2500
# progress:  k = 4 j =  0  :  2112 / 2500
# progress:  k = 4 j =  0  :  2113 / 2500
# progress:  k = 4 j =  0  :  2114 / 2500
# progress:  k = 4 j =  0  :  2115 / 2500
# progress:  k = 4 j =  0  :  2116 / 2500
# progress:  k = 4 j =  0  :  2117 / 2500
# progress:  k = 4 j =  0  :  2118 / 2500
# progress:  k = 4 j =  0  :  2119 / 2500
# progress:  k = 4 j =  0  :  2120 / 2500
# progress:  k = 4 j =  0  :  2121 / 2500
# progress:  k = 4 j =  0  :  2122 / 2500
# progress:  k = 4 j =  0  :  2123 / 2500
# progress:  k = 4 j =  0  :  2124 / 2500
# progress:  k = 4 j =  0  :  2125 / 2500
# progress:  k = 4 j =  0  :  2126 / 2500
# progress:  k = 4 j =  0  :  2127 / 2500
# progress:  k = 4 j =  0  :  2128 / 2500
# progress:  k = 4 j =  0  :  2129 / 2500
# Error on  2130  and set lengths at random
# progress:  k = 4 j =  0  :  2131 / 2500
# progress:  k = 4 j =  0  :  2132 / 2500
# progress:  k = 4 j =  0  :  2133 / 2500
# progress:  k = 4 j =  0  :  2134 / 2500
# progress:  k = 4 j =  0  :  2135 / 2500
# progress:  k = 4 j =  0  :  2136 / 2500
# progress:  k = 4 j =  0  :  2137 / 2500
# progress:  k = 4 j =  0  :  2138 / 2500
# progress:  k = 4 j =  0  :  2139 / 2500
# progress:  k = 4 j =  0  :  2140 / 2500
# progress:  k = 4 j =  0  :  2141 / 2500
# progress:  k = 4 j =  0  :  2142 / 2500
# progress:  k = 4 j =  0  :  2143 / 2500
# progress:  k = 4 j =  0  :  2144 / 2500
# progress:  k = 4 j =  0  :  2145 / 2500
# progress:  k = 4 j =  0  :  2146 / 2500
# progress:  k = 4 j =  0  :  2147 / 2500
# progress:  k = 4 j =  0  :  2148 / 2500
# progress:  k = 4 j =  0  :  2149 / 2500
# progress:  k = 4 j =  0  :  2150 / 2500
# progress:  k = 4 j =  0  :  2151 / 2500
# progress:  k = 4 j =  0  :  2152 / 2500
# progress:  k = 4 j =  0  :  2153 / 2500
# progress:  k = 4 j =  0  :  2154 / 2500
# progress:  k = 4 j =  0  :  2155 / 2500
# progress:  k = 4 j =  0  :  2156 / 2500
# progress:  k = 4 j =  0  :  2157 / 2500
# progress:  k = 4 j =  0  :  2158 / 2500
# progress:  k = 4 j =  0  :  2159 / 2500
# progress:  k = 4 j =  0  :  2160 / 2500
# progress:  k = 4 j =  0  :  2161 / 2500
# progress:  k = 4 j =  0  :  2162 / 2500
# progress:  k = 4 j =  0  :  2163 / 2500
# progress:  k = 4 j =  0  :  2164 / 2500
# progress:  k = 4 j =  0  :  2165 / 2500
# progress:  k = 4 j =  0  :  2166 / 2500
# progress:  k = 4 j =  0  :  2167 / 2500
# progress:  k = 4 j =  0  :  2168 / 2500
# progress:  k = 4 j =  0  :  2169 / 2500
# progress:  k = 4 j =  0  :  2170 / 2500
# progress:  k = 4 j =  0  :  2171 / 2500
# progress:  k = 4 j =  0  :  2172 / 2500
# progress:  k = 4 j =  0  :  2173 / 2500
# progress:  k = 4 j =  0  :  2174 / 2500
# progress:  k = 4 j =  0  :  2175 / 2500
# progress:  k = 4 j =  0  :  2176 / 2500
# progress:  k = 4 j =  0  :  2177 / 2500
# progress:  k = 4 j =  0  :  2178 / 2500
# progress:  k = 4 j =  0  :  2179 / 2500
# progress:  k = 4 j =  0  :  2180 / 2500
# progress:  k = 4 j =  0  :  2181 / 2500
# progress:  k = 4 j =  0  :  2182 / 2500
# progress:  k = 4 j =  0  :  2183 / 2500
# progress:  k = 4 j =  0  :  2184 / 2500
# progress:  k = 4 j =  0  :  2185 / 2500
# progress:  k = 4 j =  0  :  2186 / 2500
# progress:  k = 4 j =  0  :  2187 / 2500
# progress:  k = 4 j =  0  :  2188 / 2500
# progress:  k = 4 j =  0  :  2189 / 2500
# progress:  k = 4 j =  0  :  2190 / 2500
# progress:  k = 4 j =  0  :  2191 / 2500
# progress:  k = 4 j =  0  :  2192 / 2500
# progress:  k = 4 j =  0  :  2193 / 2500
# progress:  k = 4 j =  0  :  2194 / 2500
# progress:  k = 4 j =  0  :  2195 / 2500
# progress:  k = 4 j =  0  :  2196 / 2500
# progress:  k = 4 j =  0  :  2197 / 2500
# progress:  k = 4 j =  0  :  2198 / 2500
# progress:  k = 4 j =  0  :  2199 / 2500
# progress:  k = 4 j =  0  :  2200 / 2500
# progress:  k = 4 j =  0  :  2201 / 2500
# progress:  k = 4 j =  0  :  2202 / 2500
# progress:  k = 4 j =  0  :  2203 / 2500
# progress:  k = 4 j =  0  :  2204 / 2500
# progress:  k = 4 j =  0  :  2205 / 2500
# progress:  k = 4 j =  0  :  2206 / 2500
# progress:  k = 4 j =  0  :  2207 / 2500
# progress:  k = 4 j =  0  :  2208 / 2500
# progress:  k = 4 j =  0  :  2209 / 2500
# progress:  k = 4 j =  0  :  2210 / 2500
# Error on  2211  and set lengths at random
# progress:  k = 4 j =  0  :  2212 / 2500
# progress:  k = 4 j =  0  :  2213 / 2500
# progress:  k = 4 j =  0  :  2214 / 2500
# progress:  k = 4 j =  0  :  2215 / 2500
# progress:  k = 4 j =  0  :  2216 / 2500
# progress:  k = 4 j =  0  :  2217 / 2500
# progress:  k = 4 j =  0  :  2218 / 2500
# progress:  k = 4 j =  0  :  2219 / 2500
# progress:  k = 4 j =  0  :  2220 / 2500
# ...
# progress:  k = 4 j =  2  :  329 / 2500
# progress:  k = 4 j =  2  :  330 / 2500
# progress:  k = 4 j =  2  :  331 / 2500
# progress:  k = 4 j =  2  :  332 / 2500
# progress:  k = 4 j =  2  :  333 / 2500
# progress:  k = 4 j =  2  :  334 / 2500
# progress:  k = 4 j =  2  :  335 / 2500
# progress:  k = 4 j =  2  :  336 / 2500
# progress:  k = 4 j =  2  :  337 / 2500
# progress:  k = 4 j =  2  :  338 / 2500
# progress:  k = 4 j =  2  :  339 / 2500
# progress:  k = 4 j =  2  :  340 / 2500
# progress:  k = 4 j =  2  :  341 / 2500
# progress:  k = 4 j =  2  :  342 / 2500
# progress:  k = 4 j =  2  :  343 / 2500
# progress:  k = 4 j =  2  :  344 / 2500
# progress:  k = 4 j =  2  :  345 / 2500
# progress:  k = 4 j =  2  :  346 / 2500
# progress:  k = 4 j =  2  :  347 / 2500
# progress:  k = 4 j =  2  :  348 / 2500
# progress:  k = 4 j =  2  :  349 / 2500
# progress:  k = 4 j =  2  :  350 / 2500
# progress:  k = 4 j =  2  :  351 / 2500
# progress:  k = 4 j =  2  :  352 / 2500
# progress:  k = 4 j =  2  :  353 / 2500
# progress:  k = 4 j =  2  :  354 / 2500
# progress:  k = 4 j =  2  :  355 / 2500
# Error on  356  and set lengths at random
# progress:  k = 4 j =  2  :  357 / 2500
# progress:  k = 4 j =  2  :  358 / 2500
# progress:  k = 4 j =  2  :  359 / 2500
# progress:  k = 4 j =  2  :  360 / 2500
# progress:  k = 4 j =  2  :  361 / 2500
# progress:  k = 4 j =  2  :  362 / 2500
# progress:  k = 4 j =  2  :  363 / 2500
# progress:  k = 4 j =  2  :  364 / 2500
# progress:  k = 4 j =  2  :  365 / 2500
# progress:  k = 4 j =  2  :  366 / 2500
# progress:  k = 4 j =  2  :  367 / 2500
# progress:  k = 4 j =  2  :  368 / 2500
# progress:  k = 4 j =  2  :  369 / 2500
# progress:  k = 4 j =  2  :  370 / 2500
# progress:  k = 4 j =  2  :  371 / 2500
# progress:  k = 4 j =  2  :  372 / 2500
# progress:  k = 4 j =  2  :  373 / 2500
# progress:  k = 4 j =  2  :  374 / 2500
# progress:  k = 4 j =  2  :  375 / 2500
# progress:  k = 4 j =  2  :  376 / 2500
# progress:  k = 4 j =  2  :  377 / 2500
# progress:  k = 4 j =  2  :  378 / 2500
# progress:  k = 4 j =  2  :  379 / 2500
# progress:  k = 4 j =  2  :  380 / 2500
# progress:  k = 4 j =  2  :  381 / 2500
# progress:  k = 4 j =  2  :  382 / 2500
# progress:  k = 4 j =  2  :  383 / 2500
# progress:  k = 4 j =  2  :  384 / 2500
# progress:  k = 4 j =  2  :  385 / 2500
# progress:  k = 4 j =  2  :  386 / 2500
# progress:  k = 4 j =  2  :  387 / 2500
# progress:  k = 4 j =  2  :  388 / 2500
# progress:  k = 4 j =  2  :  389 / 2500
# progress:  k = 4 j =  2  :  390 / 2500
# progress:  k = 4 j =  2  :  391 / 2500
# progress:  k = 4 j =  2  :  392 / 2500
# progress:  k = 4 j =  2  :  393 / 2500
# progress:  k = 4 j =  2  :  394 / 2500
# progress:  k = 4 j =  2  :  395 / 2500
# progress:  k = 4 j =  2  :  396 / 2500
# progress:  k = 4 j =  2  :  397 / 2500
# progress:  k = 4 j =  2  :  398 / 2500
# progress:  k = 4 j =  2  :  399 / 2500
# progress:  k = 4 j =  2  :  400 / 2500
# progress:  k = 4 j =  2  :  401 / 2500
# progress:  k = 4 j =  2  :  402 / 2500
# progress:  k = 4 j =  2  :  403 / 2500
# progress:  k = 4 j =  2  :  404 / 2500
# progress:  k = 4 j =  2  :  405 / 2500
# progress:  k = 4 j =  2  :  406 / 2500
# progress:  k = 4 j =  2  :  407 / 2500
# progress:  k = 4 j =  2  :  408 / 2500
# progress:  k = 4 j =  2  :  409 / 2500
# progress:  k = 4 j =  2  :  410 / 2500
# progress:  k = 4 j =  2  :  411 / 2500
# progress:  k = 4 j =  2  :  412 / 2500
# progress:  k = 4 j =  2  :  413 / 2500
# progress:  k = 4 j =  2  :  414 / 2500
# progress:  k = 4 j =  2  :  415 / 2500
# progress:  k = 4 j =  2  :  416 / 2500
# progress:  k = 4 j =  2  :  417 / 2500
# progress:  k = 4 j =  2  :  418 / 2500
# progress:  k = 4 j =  2  :  419 / 2500
# progress:  k = 4 j =  2  :  420 / 2500
# progress:  k = 4 j =  2  :  421 / 2500
# progress:  k = 4 j =  2  :  422 / 2500
# progress:  k = 4 j =  2  :  423 / 2500
# progress:  k = 4 j =  2  :  424 / 2500
# progress:  k = 4 j =  2  :  425 / 2500
# progress:  k = 4 j =  2  :  426 / 2500
# progress:  k = 4 j =  2  :  427 / 2500
# progress:  k = 4 j =  2  :  428 / 2500
# progress:  k = 4 j =  2  :  429 / 2500
# progress:  k = 4 j =  2  :  430 / 2500
# progress:  k = 4 j =  2  :  431 / 2500
# progress:  k = 4 j =  2  :  432 / 2500
# progress:  k = 4 j =  2  :  433 / 2500
# progress:  k = 4 j =  2  :  434 / 2500
# progress:  k = 4 j =  2  :  435 / 2500
# progress:  k = 4 j =  2  :  436 / 2500
# progress:  k = 4 j =  2  :  437 / 2500
# progress:  k = 4 j =  2  :  438 / 2500
# progress:  k = 4 j =  2  :  439 / 2500
# progress:  k = 4 j =  2  :  440 / 2500
# progress:  k = 4 j =  2  :  441 / 2500
# progress:  k = 4 j =  2  :  442 / 2500
# progress:  k = 4 j =  2  :  443 / 2500
# progress:  k = 4 j =  2  :  444 / 2500
# progress:  k = 4 j =  2  :  445 / 2500
# progress:  k = 4 j =  2  :  446 / 2500
# progress:  k = 4 j =  2  :  447 / 2500
# progress:  k = 4 j =  2  :  448 / 2500
# progress:  k = 4 j =  2  :  449 / 2500
# progress:  k = 4 j =  2  :  450 / 2500
# progress:  k = 4 j =  2  :  451 / 2500
# progress:  k = 4 j =  2  :  452 / 2500
# progress:  k = 4 j =  2  :  453 / 2500
# progress:  k = 4 j =  2  :  454 / 2500
# progress:  k = 4 j =  2  :  455 / 2500
# progress:  k = 4 j =  2  :  456 / 2500
# progress:  k = 4 j =  2  :  457 / 2500
# progress:  k = 4 j =  2  :  458 / 2500
# progress:  k = 4 j =  2  :  459 / 2500
# progress:  k = 4 j =  2  :  460 / 2500
# progress:  k = 4 j =  2  :  461 / 2500
# progress:  k = 4 j =  2  :  462 / 2500
# progress:  k = 4 j =  2  :  463 / 2500
# progress:  k = 4 j =  2  :  464 / 2500
# progress:  k = 4 j =  2  :  465 / 2500
# progress:  k = 4 j =  2  :  466 / 2500
# progress:  k = 4 j =  2  :  467 / 2500
# progress:  k = 4 j =  2  :  468 / 2500
# progress:  k = 4 j =  2  :  469 / 2500
# progress:  k = 4 j =  2  :  470 / 2500
# progress:  k = 4 j =  2  :  471 / 2500
# progress:  k = 4 j =  2  :  472 / 2500
# progress:  k = 4 j =  2  :  473 / 2500
# progress:  k = 4 j =  2  :  474 / 2500
# progress:  k = 4 j =  2  :  475 / 2500
# progress:  k = 4 j =  2  :  476 / 2500
# progress:  k = 4 j =  2  :  477 / 2500
# progress:  k = 4 j =  2  :  478 / 2500
# progress:  k = 4 j =  2  :  479 / 2500
# progress:  k = 4 j =  2  :  480 / 2500
# progress:  k = 4 j =  2  :  481 / 2500
# progress:  k = 4 j =  2  :  482 / 2500
# progress:  k = 4 j =  2  :  483 / 2500
# progress:  k = 4 j =  2  :  484 / 2500
# progress:  k = 4 j =  2  :  485 / 2500
# progress:  k = 4 j =  2  :  486 / 2500
# progress:  k = 4 j =  2  :  487 / 2500
# progress:  k = 4 j =  2  :  488 / 2500
# Error on  489  and set lengths at random
# progress:  k = 4 j =  2  :  490 / 2500
# progress:  k = 4 j =  2  :  491 / 2500
# progress:  k = 4 j =  2  :  492 / 2500
# progress:  k = 4 j =  2  :  493 / 2500
# progress:  k = 4 j =  2  :  494 / 2500
# progress:  k = 4 j =  2  :  495 / 2500
# progress:  k = 4 j =  2  :  496 / 2500
# progress:  k = 4 j =  2  :  497 / 2500
# progress:  k = 4 j =  2  :  498 / 2500
# progress:  k = 4 j =  2  :  499 / 2500
# progress:  k = 4 j =  2  :  500 / 2500
# progress:  k = 4 j =  2  :  501 / 2500
# progress:  k = 4 j =  2  :  502 / 2500
# progress:  k = 4 j =  2  :  503 / 2500
# progress:  k = 4 j =  2  :  504 / 2500
# progress:  k = 4 j =  2  :  505 / 2500
# progress:  k = 4 j =  2  :  506 / 2500
# progress:  k = 4 j =  2  :  507 / 2500
# progress:  k = 4 j =  2  :  508 / 2500
# progress:  k = 4 j =  2  :  509 / 2500
# progress:  k = 4 j =  2  :  510 / 2500
# progress:  k = 4 j =  2  :  511 / 2500
# progress:  k = 4 j =  2  :  512 / 2500
# progress:  k = 4 j =  2  :  513 / 2500
# progress:  k = 4 j =  2  :  514 / 2500
# progress:  k = 4 j =  2  :  515 / 2500
# progress:  k = 4 j =  2  :  516 / 2500
# progress:  k = 4 j =  2  :  517 / 2500
# progress:  k = 4 j =  2  :  518 / 2500
# progress:  k = 4 j =  2  :  519 / 2500
# progress:  k = 4 j =  2  :  520 / 2500
# progress:  k = 4 j =  2  :  521 / 2500
# progress:  k = 4 j =  2  :  522 / 2500
# progress:  k = 4 j =  2  :  523 / 2500
# progress:  k = 4 j =  2  :  524 / 2500
# progress:  k = 4 j =  2  :  525 / 2500
# progress:  k = 4 j =  2  :  526 / 2500
# progress:  k = 4 j =  2  :  527 / 2500
# progress:  k = 4 j =  2  :  528 / 2500
# progress:  k = 4 j =  2  :  529 / 2500
# progress:  k = 4 j =  2  :  530 / 2500
# progress:  k = 4 j =  2  :  531 / 2500
# progress:  k = 4 j =  2  :  532 / 2500
# progress:  k = 4 j =  2  :  533 / 2500
# progress:  k = 4 j =  2  :  534 / 2500
# progress:  k = 4 j =  2  :  535 / 2500
# progress:  k = 4 j =  2  :  536 / 2500
# progress:  k = 4 j =  2  :  537 / 2500
# progress:  k = 4 j =  2  :  538 / 2500
# progress:  k = 4 j =  2  :  539 / 2500
# progress:  k = 4 j =  2  :  540 / 2500
# progress:  k = 4 j =  2  :  541 / 2500
# progress:  k = 4 j =  2  :  542 / 2500
# progress:  k = 4 j =  2  :  543 / 2500
# progress:  k = 4 j =  2  :  544 / 2500
# progress:  k = 4 j =  2  :  545 / 2500
# progress:  k = 4 j =  2  :  546 / 2500
# progress:  k = 4 j =  2  :  547 / 2500
# progress:  k = 4 j =  2  :  548 / 2500
# progress:  k = 4 j =  2  :  549 / 2500
# progress:  k = 4 j =  2  :  550 / 2500
# progress:  k = 4 j =  2  :  551 / 2500
# progress:  k = 4 j =  2  :  552 / 2500
# progress:  k = 4 j =  2  :  553 / 2500
# progress:  k = 4 j =  2  :  554 / 2500
# progress:  k = 4 j =  2  :  555 / 2500
# progress:  k = 4 j =  2  :  556 / 2500
# progress:  k = 4 j =  2  :  557 / 2500
# progress:  k = 4 j =  2  :  558 / 2500
# progress:  k = 4 j =  2  :  559 / 2500
# progress:  k = 4 j =  2  :  560 / 2500
# progress:  k = 4 j =  2  :  561 / 2500
# progress:  k = 4 j =  2  :  562 / 2500
# progress:  k = 4 j =  2  :  563 / 2500
# progress:  k = 4 j =  2  :  564 / 2500
# progress:  k = 4 j =  2  :  565 / 2500
# progress:  k = 4 j =  2  :  566 / 2500
# progress:  k = 4 j =  2  :  567 / 2500
# progress:  k = 4 j =  2  :  568 / 2500
# progress:  k = 4 j =  2  :  569 / 2500
# progress:  k = 4 j =  2  :  570 / 2500
# progress:  k = 4 j =  2  :  571 / 2500
# progress:  k = 4 j =  2  :  572 / 2500
# progress:  k = 4 j =  2  :  573 / 2500
# progress:  k = 4 j =  2  :  574 / 2500
# progress:  k = 4 j =  2  :  575 / 2500
# progress:  k = 4 j =  2  :  576 / 2500
# progress:  k = 4 j =  2  :  577 / 2500
# progress:  k = 4 j =  2  :  578 / 2500
# progress:  k = 4 j =  2  :  579 / 2500
# progress:  k = 4 j =  2  :  580 / 2500
# progress:  k = 4 j =  2  :  581 / 2500
# progress:  k = 4 j =  2  :  582 / 2500
# progress:  k = 4 j =  2  :  583 / 2500
# progress:  k = 4 j =  2  :  584 / 2500
# progress:  k = 4 j =  2  :  585 / 2500
# progress:  k = 4 j =  2  :  586 / 2500
# progress:  k = 4 j =  2  :  587 / 2500
# progress:  k = 4 j =  2  :  588 / 2500
# progress:  k = 4 j =  2  :  589 / 2500
# progress:  k = 4 j =  2  :  590 / 2500
# progress:  k = 4 j =  2  :  591 / 2500
# progress:  k = 4 j =  2  :  592 / 2500
# progress:  k = 4 j =  2  :  593 / 2500
# progress:  k = 4 j =  2  :  594 / 2500
# progress:  k = 4 j =  2  :  595 / 2500
# progress:  k = 4 j =  2  :  596 / 2500
# progress:  k = 4 j =  2  :  597 / 2500
# progress:  k = 4 j =  2  :  598 / 2500
# progress:  k = 4 j =  2  :  599 / 2500
# progress:  k = 4 j =  2  :  600 / 2500
# progress:  k = 4 j =  2  :  601 / 2500
# progress:  k = 4 j =  2  :  602 / 2500
# progress:  k = 4 j =  2  :  603 / 2500
# progress:  k = 4 j =  2  :  604 / 2500
# progress:  k = 4 j =  2  :  605 / 2500
# progress:  k = 4 j =  2  :  606 / 2500
# progress:  k = 4 j =  2  :  607 / 2500
# progress:  k = 4 j =  2  :  608 / 2500
# progress:  k = 4 j =  2  :  609 / 2500
# progress:  k = 4 j =  2  :  610 / 2500
# progress:  k = 4 j =  2  :  611 / 2500
# progress:  k = 4 j =  2  :  612 / 2500
# progress:  k = 4 j =  2  :  613 / 2500
# progress:  k = 4 j =  2  :  614 / 2500
# progress:  k = 4 j =  2  :  615 / 2500
# progress:  k = 4 j =  2  :  616 / 2500
# progress:  k = 4 j =  2  :  617 / 2500
# progress:  k = 4 j =  2  :  618 / 2500
# progress:  k = 4 j =  2  :  619 / 2500
# progress:  k = 4 j =  2  :  620 / 2500
# progress:  k = 4 j =  2  :  621 / 2500
# progress:  k = 4 j =  2  :  622 / 2500
# progress:  k = 4 j =  2  :  623 / 2500
# progress:  k = 4 j =  2  :  624 / 2500
# progress:  k = 4 j =  2  :  625 / 2500
# progress:  k = 4 j =  2  :  626 / 2500
# progress:  k = 4 j =  2  :  627 / 2500
# progress:  k = 4 j =  2  :  628 / 2500
# progress:  k = 4 j =  2  :  629 / 2500
# progress:  k = 4 j =  2  :  630 / 2500
# progress:  k = 4 j =  2  :  631 / 2500
# progress:  k = 4 j =  2  :  632 / 2500
# progress:  k = 4 j =  2  :  633 / 2500
# progress:  k = 4 j =  2  :  634 / 2500
# progress:  k = 4 j =  2  :  635 / 2500
# progress:  k = 4 j =  2  :  636 / 2500
# progress:  k = 4 j =  2  :  637 / 2500
# progress:  k = 4 j =  2  :  638 / 2500
# progress:  k = 4 j =  2  :  639 / 2500
# progress:  k = 4 j =  2  :  640 / 2500
# progress:  k = 4 j =  2  :  641 / 2500
# progress:  k = 4 j =  2  :  642 / 2500
# progress:  k = 4 j =  2  :  643 / 2500
# progress:  k = 4 j =  2  :  644 / 2500
# progress:  k = 4 j =  2  :  645 / 2500
# progress:  k = 4 j =  2  :  646 / 2500
# progress:  k = 4 j =  2  :  647 / 2500
# progress:  k = 4 j =  2  :  648 / 2500
# progress:  k = 4 j =  2  :  649 / 2500
# progress:  k = 4 j =  2  :  650 / 2500
# progress:  k = 4 j =  2  :  651 / 2500
# progress:  k = 4 j =  2  :  652 / 2500
# progress:  k = 4 j =  2  :  653 / 2500
# progress:  k = 4 j =  2  :  654 / 2500
# progress:  k = 4 j =  2  :  655 / 2500
# progress:  k = 4 j =  2  :  656 / 2500
# Error on  657  and set lengths at random
# progress:  k = 4 j =  2  :  658 / 2500
# progress:  k = 4 j =  2  :  659 / 2500
# progress:  k = 4 j =  2  :  660 / 2500
# progress:  k = 4 j =  2  :  661 / 2500
# progress:  k = 4 j =  2  :  662 / 2500
# progress:  k = 4 j =  2  :  663 / 2500
# progress:  k = 4 j =  2  :  664 / 2500
# progress:  k = 4 j =  2  :  665 / 2500
# progress:  k = 4 j =  2  :  666 / 2500
# progress:  k = 4 j =  2  :  667 / 2500
# progress:  k = 4 j =  2  :  668 / 2500
# progress:  k = 4 j =  2  :  669 / 2500
# progress:  k = 4 j =  2  :  670 / 2500
# progress:  k = 4 j =  2  :  671 / 2500
# progress:  k = 4 j =  2  :  672 / 2500
# progress:  k = 4 j =  2  :  673 / 2500
# progress:  k = 4 j =  2  :  674 / 2500
# progress:  k = 4 j =  2  :  675 / 2500
# progress:  k = 4 j =  2  :  676 / 2500
# progress:  k = 4 j =  2  :  677 / 2500
# progress:  k = 4 j =  2  :  678 / 2500
# progress:  k = 4 j =  2  :  679 / 2500
# progress:  k = 4 j =  2  :  680 / 2500
# progress:  k = 4 j =  2  :  681 / 2500
# progress:  k = 4 j =  2  :  682 / 2500
# progress:  k = 4 j =  2  :  683 / 2500
# progress:  k = 4 j =  2  :  684 / 2500
# progress:  k = 4 j =  2  :  685 / 2500
# progress:  k = 4 j =  2  :  686 / 2500
# progress:  k = 4 j =  2  :  687 / 2500
# progress:  k = 4 j =  2  :  688 / 2500
# progress:  k = 4 j =  2  :  689 / 2500
# progress:  k = 4 j =  2  :  690 / 2500
# progress:  k = 4 j =  2  :  691 / 2500
# progress:  k = 4 j =  2  :  692 / 2500
# progress:  k = 4 j =  2  :  693 / 2500
# progress:  k = 4 j =  2  :  694 / 2500
# progress:  k = 4 j =  2  :  695 / 2500
# progress:  k = 4 j =  2  :  696 / 2500
# progress:  k = 4 j =  2  :  697 / 2500
# progress:  k = 4 j =  2  :  698 / 2500
# progress:  k = 4 j =  2  :  699 / 2500
# progress:  k = 4 j =  2  :  700 / 2500
# progress:  k = 4 j =  2  :  701 / 2500
# progress:  k = 4 j =  2  :  702 / 2500
# progress:  k = 4 j =  2  :  703 / 2500
# progress:  k = 4 j =  2  :  704 / 2500
# progress:  k = 4 j =  2  :  705 / 2500
# progress:  k = 4 j =  2  :  706 / 2500
# progress:  k = 4 j =  2  :  707 / 2500
# progress:  k = 4 j =  2  :  708 / 2500
# progress:  k = 4 j =  2  :  709 / 2500
# progress:  k = 4 j =  2  :  710 / 2500
# progress:  k = 4 j =  2  :  711 / 2500
# progress:  k = 4 j =  2  :  712 / 2500
# progress:  k = 4 j =  2  :  713 / 2500
# progress:  k = 4 j =  2  :  714 / 2500
# progress:  k = 4 j =  2  :  715 / 2500
# progress:  k = 4 j =  2  :  716 / 2500
# progress:  k = 4 j =  2  :  717 / 2500
# progress:  k = 4 j =  2  :  718 / 2500
# progress:  k = 4 j =  2  :  719 / 2500
# progress:  k = 4 j =  2  :  720 / 2500
# progress:  k = 4 j =  2  :  721 / 2500
# progress:  k = 4 j =  2  :  722 / 2500
# progress:  k = 4 j =  2  :  723 / 2500
# progress:  k = 4 j =  2  :  724 / 2500
# progress:  k = 4 j =  2  :  725 / 2500
# progress:  k = 4 j =  2  :  726 / 2500
# progress:  k = 4 j =  2  :  727 / 2500
# progress:  k = 4 j =  2  :  728 / 2500
# progress:  k = 4 j =  2  :  729 / 2500
# progress:  k = 4 j =  2  :  730 / 2500
# progress:  k = 4 j =  2  :  731 / 2500
# progress:  k = 4 j =  2  :  732 / 2500
# progress:  k = 4 j =  2  :  733 / 2500
# progress:  k = 4 j =  2  :  734 / 2500
# progress:  k = 4 j =  2  :  735 / 2500
# progress:  k = 4 j =  2  :  736 / 2500
# progress:  k = 4 j =  2  :  737 / 2500
# progress:

# %%
question_file_path = '/Users/MK/GitHub/the_answer_is/data/validation_set.tsv'
wiki_folder_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_stemmed_all_merged'
result = run_w2v_for_questions( question_file_path, wiki_folder_path  )
