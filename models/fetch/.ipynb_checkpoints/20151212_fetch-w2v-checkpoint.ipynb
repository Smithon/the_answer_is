# %%
import gensim
import logging
import os
import pandas as pd
import numpy as np
from scipy import spatial
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from gensim import corpora

class MyDocument(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            with open(os.path.join(self.dirname, fname)) as content_file:
                content = content_file.read()  
                content = unicode(content, encoding='utf-8', errors='replace')
                yield content.lower().split()

class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                line = unicode(line, encoding='utf-8', errors='replace')
                yield line.lower().split()

def get_dictionary(path):
    dictionary = corpora.Dictionary( MySentences(path) )
    stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
    dictionary.filter_tokens(stop_ids) # remove stop words and words that appear only once
    dictionary.compactify() # remove gaps in id sequence after words that were removed
    return dictionary

def get_document_tuple( path, dictionary ):
    vector = pd.Series()
    doclist = MyDocument(path) 
    for i,content in enumerate(doclist):
        vector = vector.set_value(i,dictionary.doc2bow(content))
    return list(vector)

def transform_tuple_into_vector(document_tuple,dictionary):
    vector = pd.Series(np.zeros(len(dictionary.token2id)))        #0 array for storing wiki document vectors.
    if not document_tuple == []:
        for onetuple in document_tuple: 
            vector[onetuple[0]] = onetuple[1]
        vector = vector / np.linalg.norm(vector, ord = 1)                       #normalize vector     
        return vector 
    else:
        return vector

def transform_tuples_into_dataframe(document_tuples, dictionary):
    length = len(document_tuples) 
    vector_initialization = pd.Series(np.zeros(len(dictionary.token2id)))  #0 array for storing wiki document vectors. 
    df_vector = pd.DataFrame(vector_initialization)  #initialize dataframe. all vectors will be stored. 
    for i in xrange(len(document_tuples)):           
        #for each wiki documents, we will transform wiki vectors in tuple form into
        #vectors in ususal form. 
        vector = transform_tuple_into_vector( document_tuples[i], dictionary )
        df_vector[i]= pd.DataFrame(vector)
    return df_vector

def get_close_documents(string, dataframe, dictionary, topn, path):
    #string = unicode(string, encoding='utf-8', errors='replace').lower()
    #print string
    string = string_stemmer(string)
    first_vector = transform_tuple_into_vector(dictionary.doc2bow(string.split()), dictionary )
    #print first_vector
    lengthlist = pd.Series()
    for j in xrange(len(dataframe.columns)):
        lengthlist = lengthlist.set_value( j, spatial.distance.cosine(first_vector, dataframe[j]))
        lengthlist = lengthlist.sort_values().head(topn)
        #now we have a topn index of the close documents. 

    namelist = pd.DataFrame(columns = ['name', 'content'])
    namelist['distance'] = lengthlist
    for i in lengthlist.index:
        name, text = get_document_by_index(path,i)
        namelist.set_value(i, 'name', name )
        namelist.set_value(i, 'content', text)
           
    return namelist


def get_document_by_index(path,index):
    # this gets the filename and content of the document in a directory by index. 
    i= 0
    for fname in os.listdir(path):
        if i == index:
            with open(os.path.join(path, fname)) as content_file:
                content = content_file.read()  
                content = unicode(content, encoding='utf-8', errors='replace')
                return fname, content
        i= i + 1
    return None



def string_stemmer(line):
    import re
    from nltk.corpus import stopwords
    from nltk.stem.snowball import SnowballStemmer
    stemmer = SnowballStemmer("english")
    line = re.sub(r'[^a-zA-Z ]',r'',line)
    line = line.split()
    line = [word for word in line if word not in stopwords.words('english')]  # remove the stop words. 
    output = []
    for word in line:
        output.append(stemmer.stem(word))     #stem all words 
    output = ' '.join(output)           # join the list to make a string
    return output






stoplist = [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours',
             u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', 
             u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', 
             u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', 
             u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', 
             u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', 
             u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', 
             u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', 
             u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', 
             u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', 
             u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', 
             u'should', u'now']

# %%
#get close document names for each question. 

#setup
wiki_folder_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_stemmed_all_merged'
train_file_path = '/Users/MK/GitHub/the_answer_is/data/training_set.tsv'
dictionary_folder_path = '/Users/MK/GitHub/the_answer_is/data/temporary2'  #this folder contains one file which is stemmed. 

def initialize_run_close_document(wiki_folder_path, dictionary_folder_path):
    dictionary = get_dictionary(dictionary_folder_path)
    wiki_tuple = get_document_tuple( wiki_folder_path, dictionary )
    df_wiki_vector = transform_tuples_into_dataframe(wiki_tuple,dictionary) 
    return dictionary, df_wiki_vector

def run_close_document( main_text , wiki_folder_path, dictionary, df_wiki_vector, topn):
    close_document =  get_close_documents(main_text, df_wiki_vector, dictionary, topn, wiki_folder_path)
    return close_document

dictionary, df_wiki_vector = initialize_run_close_document(wiki_folder_path, dictionary_folder_path)

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()

#train the model using wikipdeida data                
sentences = MySentences('/Users/MK/GitHub/the_answer_is/data/wikipedia_from_all_ck_words_stemmed') # a memory-friendly iterator
model = gensim.models.Word2Vec(sentences,size=300, window=5, min_count=1, workers=4)
#procedure needed for deleting words not in the training set. 
def only_the_words_in_index( list, index ):
    output = []
    for a, s in enumerate(list):
        if s in index:
            output.append(list[a])
    return output

def string_stemmer(line):
    import re
    from nltk.corpus import stopwords
    from nltk.stem.snowball import SnowballStemmer
    stemmer = SnowballStemmer("english")
    line = re.sub(r'[^a-zA-Z ]',r'',line)
    line = line.split()
    line = [word for word in line if word not in stopwords.words('english')]  # remove the stop words. 
    output = []
    for word in line:
        output.append(stemmer.stem(word))     #stem all words 
    output = ' '.join(output)           # join the list to make a string
    return output

def split_result(df):
    split = []
    for sentence in df['content'].iloc[0].split('\n'):
        split = split + sentence.split()
    return split

# %%
train = pd.read_table('/Users/MK/GitHub/the_answer_is/data/training_set_which.tsv',sep = '\t')
i = 3
close = run_close_document( train.ix[i][1] , wiki_folder_path, dictionary, df_wiki_vector, 1)
print train.ix[i][1]
close
# Out:
# Some areas of the world are experiencing more desert-like conditions. This change most favors survival of species with the ability to do which of the following?
#                                                    name  \
# 6660  snapdragon.txt_to_unicode_remove_stopwords_and...
#
#                                                 content  distance
# 6660  antirrhinum genus plant common known dragon fl...  0.695487

# %%
train = pd.read_table('/Users/MK/GitHub/the_answer_is/data/training_set_which.tsv',sep = '\t')
myanswer_list = []
myanswer_distance = pd.DataFrame(np.zeros(4).reshape(1,4), columns = ['A','B','C','D'])    #initialize dataframe to store my answers distance
correct = 0
length = len(train)
for i in xrange(len(train)):
    close = run_close_document( train.ix[i][1] , wiki_folder_path, dictionary, df_wiki_vector, 1)
    close = only_the_words_in_index( split_result(close), model.index2word)
    
    q = train.ix[i][1]
    a1 = train.ix[i][3]
    a2 = train.ix[i][4]
    a3 = train.ix[i][5]
    a4 = train.ix[i][6]

    q = string_stemmer(q)
    a1 = string_stemmer(a1)
    a2 = string_stemmer(a2)
    a3 = string_stemmer(a3)
    a4 = string_stemmer(a4)

    q  = q.split()
    a1 = a1.split()
    a2 = a2.split()
    a3 = a3.split()
    a4 = a4.split()

    q =  only_the_words_in_index( q, model.index2word)
    a1 = only_the_words_in_index( a1, model.index2word)
    a2 = only_the_words_in_index( a2, model.index2word)
    a3 = only_the_words_in_index( a3, model.index2word)
    a4 = only_the_words_in_index( a4, model.index2word)
    
    a1 = q + a1
    a2 = q + a2
    a3 = q + a3
    a4 = q + a4
    
    answer_similarity = np.array([['A',model.n_similarity(close, a1)],['B',model.n_similarity(close, a2)],
                                  ['C',model.n_similarity(close, a3)],['D',model.n_similarity(close, a4)]])
    
    myanswer_distance.set_value(i, 'A', answer_similarity[0,1] )    #write down distance for each choice
    myanswer_distance.set_value(i, 'B', answer_similarity[1,1] )
    myanswer_distance.set_value(i, 'C', answer_similarity[2,1] )
    myanswer_distance.set_value(i, 'D', answer_similarity[3,1] )
    
    #myanswer_index = answer_similarity[:,1].argsort()[-2]
    myanswer_index = answer_similarity[:,1].argmax()          #get the maximum similarity 
    myanswer = answer_similarity[myanswer_index][0]
    myanswer_list.append(myanswer)
    print 'question: ',q
    print 'answer: ','A: ', train.ix[i][3],' B:',  train.ix[i][4], ' C: ' ,train.ix[i][5], 'D:',  train.ix[i][6]
    print 'correct answer: ', train.ix[i][2]
    print 'my answer: ', myanswer
    if train.ix[i][2] == myanswer:
        correct = correct +1.0
    print 'percent correct: ', correct / (i+1) 
    print 'progress: ', i, '/', length 
#for printing out the distance
# myanswer_distance.to_csv('/Users/MK/GitHub/the_answer_is/data/answer/pure_ck12_word2vec_distance.csv', encoding='utf-8')    

#train['ck_12_word2vec_answer'] = myanswer_list
# Out:
# question:  [u'achromatopsia', u'genet', u'disord', u'suffer', u'color', u'vision', u'achromatopsia', u'most', u'like', u'affect', u'follow', u'structur', u'eye']
# answer:  A:  rod cells  B: cone cells  C:  lens D: iris
# correct answer:  B
# my answer:  B
# percent correct:  1.0
# progress:  0 / 307
# question:  [u'brain', u'spinal', u'cord', u'nerv', u'organ', u'perform', u'primari', u'function']
# answer:  A:  supporting the body and enabling it to move  B: transporting oxygen, wastes, and nutrients throughout the body  C:  producing male and female gametes D: conducting messages to coordinate body functions
# correct answer:  D
# my answer:  A
# percent correct:  0.5
# progress:  1 / 307
# question:  [u'research', u'team', u'want', u'produc', u'smaller', u'varieti', u'german', u'shepherd', u'dog', u'mate', u'smallest', u'dog', u'differ', u'litter', u'sever', u'generat', u'exampl', u'concept']
# answer:  A:  extinction  B: mutation  C:  selective breeding D: natural selection
# correct answer:  C
# my answer:  A
# percent correct:  0.333333333333
# progress:  2 / 307
# question:  [u'area', u'world', u'experienc', u'desertlik', u'condit', u'chang', u'favor', u'surviv', u'speci', u'abil', u'follow']
# answer:  A:  consume large amounts of food  B: become dormant for long periods  C:  sense infrared and ultraviolet light D: transpire water through the skin to the atmosphere
# correct answer:  B
# my answer:  A
# percent correct:  0.25
# progress:  3 / 307
# question:  [u'with', u'climat', u'transfer', u'energi', u'heat', u'three', u'mechan', u'transfer', u'energi', u'earth', u'surfac', u'atmospher']
# answer:  A:  conduction, convection, radiation  B: reflection, retention, radiation  C:  convection, nuclear, reflection D: conduction, solar, nuclear
# correct answer:  A
# my answer:  D
# percent correct:  0.2
# progress:  4 / 307
# question:  [u'famili', u'own', u'vacat', u'cabin', u'locat', u'hillsid', u'gas', u'station', u'leak', u'gasolin', u'storag', u'tank', u'in', u'situat', u'drink', u'water', u'cabin', u'like', u'contamin']
# answer:  A:  Water is pumped to the cabin from a distant reservoir.  B: The family brings several gallons of bottled spring water.  C:  Groundwater is drawn up in buckets from a private well. D: The family collects water in rain barrels left in the open air.
# correct answer:  C
# my answer:  A
# percent correct:  0.166666666667
# progress:  5 / 307
# question:  [u'plant', u'arabidopsi', u'thaliana', u'gene', u'found', u'show', u'unusu', u'high', u'rate', u'mutat', u'which', u'conclus', u'best', u'support', u'observ']
# answer:  A:  The gene codes for flower color in the plant.  B: The gene is controlled by environment and not heredity.  C:  Traits associated with this gene are beneficial to the species. D: Traits associated with this gene may vary greatly in the species.
# correct answer:  D
# my answer:  A
# percent correct:  0.142857142857
# progress:  6 / 307
# question:  [u'tree', u'like', u'chang', u'environ', u'locat']
# answer:  A:  releasing nitrogen in the soil.  B: crowding out non-native species.  C:  adding carbon dioxide to the atmosphere. D: removing water from the soil and returning it to the atmosphere.
# correct answer:  D
# my answer:  B
# percent correct:  0.125
# progress:  7 / 307
# question:  [u'blood', u'pressur', u'often', u'use', u'indic', u'cardiovascular', u'health', u'blood', u'pressur', u'most', u'often', u'measur', u'follow', u'unit']
# answer:  A:  cmHg  B: mmHg  C:  g/cm^3 D: g/mm^3
# correct answer:  B
# my answer:  B
# percent correct:  0.222222222222
# progress:  8 / 307
# question:  [u'frost', u'wedg', u'occur', u'rock', u'broken', u'smaller', u'piec', u'water', u'freez', u'expand', u'crack', u'rock', u'frost', u'wedg', u'consid', u'part', u'step', u'rock', u'cycl']
# answer:  A:  weathering  B: transportation  C:  deposition D: lithification
# correct answer:  A
# my answer:  C
# percent correct:  0.2
# progress:  9 / 307
# question:  [u'atom', u'neutral', u'charg', u'particl', u'within', u'atom', u'equal', u'number']
# answer:  A:  electrons and neutrons  B: protons and electrons  C:  neutrons and protons D: ions and neutrons
# correct answer:  B
# my answer:  A
# percent correct:  0.181818181818
# progress:  10 / 307
# question:  [u'flower', u'petal', u'hydrangea', u'plant', u'chang', u'color', u'acid', u'soil', u'chang', u'color', u'chang', u'direct', u'relat', u'factor']
# answer:  A:  gravitropism  B: photosynthesis  C:  geographic location D: environmental conditions
# correct answer:  D
# my answer:  D
# percent correct:  0.25
# progress:  11 / 307
# question:  [u'central', u'vacuol', u'largest', u'plant', u'organell', u'use', u'store', u'wast', u'caus', u'plant', u'tast', u'bitter', u'anim', u'tri', u'eat', u'plant', u'central', u'vacuol', u'found', u'specif', u'within', u'organ']
# answer:  A:  tissues.  B: cells.  C:  organ systems. D: organs.
# correct answer:  B
# my answer:  C
# percent correct:  0.230769230769
# progress:  12 / 307
# question:  [u'methan', u'burn', u'oxygen', u'carbon', u'dioxid', u'water', u'vapor', u'product', u'sinc', u'reactant', u'product', u'gase', u'invis', u'follow', u'clue', u'tell', u'chemic', u'reaction', u'taken', u'place']
# answer:  A:  new elements are rearranged  B: new elements are produced  C:  heat is absorbed D: heat is produced
# correct answer:  D
# my answer:  B
# percent correct:  0.214285714286
# progress:  13 / 307
# question:  [u'short', u'plant', u'thick', u'fleshi', u'stem', u'extens', u'root', u'short', u'bloom', u'period', u'would', u'like', u'found', u'follow', u'environ']
# answer:  A:  prairie  B: desert  C:  coniferous forest D: deciduous forest
# correct answer:  B
# my answer:  C
# percent correct:  0.2
# progress:  14 / 307
# question:  [u'half', u'volcan', u'rock', u'format', u'seen', u'pinnacl', u'nation', u'park', u'california', u'one', u'side', u'san', u'andrea', u'fault', u'half', u'mile', u'southeast', u'park', u'side', u'fault', u'line', u'evid', u'follow', u'theori']
# answer:  A:  that earthquakes are the result of volcanic activity  B: that Earth's crust is made of rocky plates that shift over time  C:  that rock formations may move hundreds of miles in an earthquake D: that Earth's current landforms were created when Earth's surface cooled
# correct answer:  B
# my answer:  B
# percent correct:  0.25
# progress:  15 / 307
# question:  [u'if', u'two', u'organ', u'classifi', u'differ', u'order', u'class', u'statement', u'true']
# answer:  A:  The organisms have the same genus.  B: The organisms are in the same phylum.  C:  The organisms are in different kingdoms. D: The organisms are members of the same species.
# correct answer:  B
# my answer:  D
# percent correct:  0.235294117647
# progress:  16 / 307
# question:  [u'ribosom', u'site', u'follow', u'process']
# answer:  A:  nucleotide synthesis  B: transcription  C:  lipid synthesis D: translation
# correct answer:  D
# my answer:  A
# percent correct:  0.222222222222
# progress:  17 / 307
# question:  [u'process', u'organ', u'favor', u'variat', u'reproduc', u'higher', u'rate', u'without', u'variat']
# answer:  A:  disruptive selection.  B: natural selection.  C:  sexual selection. D: directional selection.
# correct answer:  B
# my answer:  C
# percent correct:  0.210526315789
# progress:  18 / 307
# question:  [u'volcan', u'island', u'arc', u'found', u'type', u'plate', u'boundari']
# answer:  A:  divergent oceanic-oceanic  B: convergent oceanic-oceanic  C:  divergent continental-oceanic D: convergent continental-oceanic
# correct answer:  B
# my answer:  C
# percent correct:  0.2
# progress:  19 / 307
# question:  [u'garrett', u'collect', u'larg', u'rock', u'stream', u'near', u'home', u'measur', u'rock', u'balanc', u'record', u'mass', u'rock', u'unit', u'garrett', u'use']
# answer:  A:  pounds  B: kilograms  C:  fluid ounces D: cubic centimeters
# correct answer:  B
# my answer:  C
# percent correct:  0.190476190476
# progress:  20 / 307
# question:  [u'prior', u'process', u'fossil', u'format', u'unknown', u'robert', u'hook', u'observ', u'fossil', u'microscop', u'saw', u'characterist', u'fossil', u'plant', u'similar', u'live', u'plant', u'observ', u'conclud', u'plant', u'fossil', u'mineralrich', u'water', u'deposit', u'cell', u'plant', u'inform', u'would', u'best', u'support', u'conclus']
# answer:  A:  Robert Hooke's discovery delayed advancements in science.  B: New evidence about fossils can change existing theories.  C:  Prior to 1700, fossils were much more common. D: Plants are more likely to form fossils.
# correct answer:  B
# my answer:  D
# percent correct:  0.181818181818
# progress:  21 / 307
# question:  [u'initi', u'format', u'planetesim', u'must', u'occur', u'solar', u'nebula']
# answer:  A:  Matter must become unevenly distributed to create a region of increased gravity.  B: Particles must fuse into larger particles to increase the particle nuclei mass.  C:  Gases must decrease in temperature enough to condense into a solid phase. D: Materials must be exposed to a strong magnetic field to generate a magnetosphere.
# correct answer:  A
# my answer:  D
# percent correct:  0.173913043478
# progress:  22 / 307
# question:  [u'newton', u'work', u'physic', u'help', u'provid', u'mathemat', u'explan', u'earlier', u'conclus', u'scientist']
# answer:  A:  Ptolemy  B: Aristotle  C:  Nicolas Copernicus D: Dmitri Mendeleev
# correct answer:  C
# my answer:  D
# percent correct:  0.166666666667
# progress:  23 / 307
# question:  [u'signal', u'brain', u'muscl', u'arm', u'transmit', u'structur']
# answer:  A:  sensory neurons  B: interneurons  C:  motor neurons D: mechanoreceptor neurons
# correct answer:  B
# my answer:  D
# percent correct:  0.16
# progress:  24 / 307
# question:  [u'in', u'structur', u'sun', u'locat']
# answer:  A:  Milky Way Galaxy  B: Andromeda Galaxy  C:  Cat's Eye Nebula D: Horseshoe Nebula
# correct answer:  A
# my answer:  A
# percent correct:  0.192307692308
# progress:  25 / 307
# question:  [u'shoulder', u'joint', u'similar', u'type', u'mechan', u'devic']
# answer:  A:  sliding joint  B: ball and socket  C:  hinge D: antagonistic
# correct answer:  B
# my answer:  C
# percent correct:  0.185185185185
# progress:  26 / 307
# question:  [u'perpetu', u'motion', u'machin', u'theoret', u'devic', u'start', u'continu', u'oper', u'without', u'addit', u'input', u'energi', u'which', u'statement', u'describ', u'perpetu', u'motion', u'machin', u'imposs', u'design']
# answer:  A:  Energy can be converted into mass.  B: Friction reduces the efficiency in a system.  C:  The amount of energy in a system remains constant. D: Potential energy can be converted into kinetic energy.
# correct answer:  B
# my answer:  B
# percent correct:  0.214285714286
# progress:  27 / 307
# question:  [u'in', u'plan', u'conduct', u'scientif', u'investig', u'research', u'start', u'point', u'follow']
# answer:  A:  formulating a conclusion  B: formulating a hypothesis  C:  analyzing experimental data D: making experimental measurements
# correct answer:  B
# my answer:  C
# percent correct:  0.206896551724
# progress:  28 / 307
# question:  [u'vein', u'deposit', u'gold', u'silver', u'often', u'form', u'area', u'experienc', u'geolog', u'process']
# answer:  A:  igneous intrusion  B: transport by water  C:  chemical weathering D: compaction by pressure
# correct answer:  A
# my answer:  C
# percent correct:  0.2
# progress:  29 / 307
# question:  [u'kt', u'boundari', u'geolog', u'stratum', u'separ', u'cretac', u'period', u'end', u'sixtyf', u'million', u'year', u'ago', u'extinct', u'dinosaur', u'tertiari', u'period', u'student', u'read', u'follow', u'fact', u'iridium', u'much', u'less', u'abund', u'earth', u'gold', u'clay', u'locat', u'kt', u'boundari', u'contain', u'least', u'twice', u'much', u'iridium', u'statement', u'support', u'theori', u'asteroid', u'impact', u'earth', u'sixtyf', u'million', u'year', u'ago']
# answer:  A:  by supporting the hypothesis that an asteroid impact would change Earth's climate  B: by providing evidence that the iridium was toxic to the species on Earth at that time  C:  by providing evidence that the iridium came from a source outside the Earth system D: by supporting the hypothesis that an asteroid impact would alter Earth's landmass
# correct answer:  C
# my answer:  B
# percent correct:  0.193548387097
# progress:  30 / 307
# question:  [u'concept', u'continent', u'drift', u'contin', u'drift', u'ocean', u'floor', u'propos', u'alfr', u'wegner', u'concept', u'replac', u'theori', u'plate', u'tecton', u'chang', u'continent', u'drift', u'concept', u'plate', u'tecton', u'theori', u'requir', u'follow']
# answer:  A:  strong earthquakes occurring along fault zones  B: data and ideas being shared among scientists  C:  a scientific law being passed by Congress D: teachers beginning to teach the newer theory
# correct answer:  B
# my answer:  B
# percent correct:  0.21875
# progress:  31 / 307
# question:  [u'compar', u'current', u'averag', u'condit', u'term', u'would', u'best', u'describ', u'condit', u'earth', u'lower', u'atmospher', u'greenhous', u'gase', u'absent']
# answer:  A:  denser  B: cooler  C:  wetter D: cloudier
# correct answer:  B
# my answer:  B
# percent correct:  0.242424242424
# progress:  32 / 307
# question:  [u'if', u'know', u'veloc', u'object', u'move', u'two', u'thing', u'know', u'object', u'motion']
# answer:  A:  direction and time  B: distance and speed  C:  speed and direction D: time and distance
# correct answer:  C
# my answer:  B
# percent correct:  0.235294117647
# progress:  33 / 307
# question:  [u'cell', u'membran', u'describ', u'select', u'permeabl', u'four', u'student', u'ask', u'explain', u'mean', u'provid', u'answer', u'given', u'cell', u'membran', u'prevent', u'materi', u'enter', u'cell', u'membran', u'provid', u'structur', u'support', u'cell', u'membran', u'regul', u'substanc', u'enter', u'exit', u'cell', u'membran', u'allow', u'water', u'watersolubl', u'substanc', u'enter', u'student', u'correct', u'identifi', u'function', u'select', u'permeabl', u'membran']
# answer:  A:  Student 1  B: Student 2  C:  Student 3 D: Student 4
# correct answer:  C
# my answer:  A
# percent correct:  0.228571428571
# progress:  34 / 307
# question:  [u'ionic', u'bond', u'coval', u'bond', u'use', u'form', u'compound', u'these', u'bond', u'form', u'base', u'upon', u'follow', u'reason']
# answer:  A:  the number of electrons present in the outer shell of the atoms  B: whether the original elements are solid, liquids or gases  C:  the atomic mass of the atoms involved D: the number of neutrons in the nucleus of the atom
# correct answer:  A
# my answer:  C
# percent correct:  0.222222222222
# progress:  35 / 307
# question:  [u'near', u'earth', u'equat', u'water', u'general', u'exist', u'natur', u'liquid', u'gas', u'state', u'in', u'part', u'earth', u'water', u'usual', u'found', u'natur', u'two', u'state']
# answer:  A:  Indian Ocean  B: interior of Africa  C:  South Pole D: Tropic of Cancer
# correct answer:  C
# my answer:  A
# percent correct:  0.216216216216
# progress:  36 / 307
# question:  [u'prokaryot', u'larg', u'degre', u'evolutionari', u'related', u'similar', u'form', u'reproduct', u'origin', u'cell', u'divid', u'two', u'genet', u'exact', u'copi', u'form', u'reproduct', u'known']
# answer:  A:  viral reproduction.  B: mitotic reproduction.  C:  asexual reproduction. D: sexual reproduction.
# correct answer:  C
# my answer:  C
# percent correct:  0.236842105263
# progress:  37 / 307
# question:  [u'windstorm', u'niko', u'call', u'electr', u'compani', u'report', u'electr', u'phone', u'call', u'exampl', u'follow', u'element', u'univers', u'system', u'model']
# answer:  A:  designing a process  B: generating output  C:  giving feedback D: setting a goal
# correct answer:  C
# my answer:  B
# percent correct:  0.230769230769
# progress:  38 / 307
# question:  [u'estuari', u'florida', u'often', u'mangrov', u'tree', u'grow', u'root', u'mangrov', u'tree', u'slow', u'flow', u'water', u'allow', u'soil', u'particl', u'settl', u'if', u'peopl', u'allow', u'remov', u'mangrov', u'tree', u'would', u'estuari', u'environ', u'like', u'affect']
# answer:  A:  The amounts of nutrients in the water would decrease.  B: More habitats for fish would be established.  C:  Populations of grasses would increase. D: The risk of erosion would be reduced.
# correct answer:  A
# my answer:  B
# percent correct:  0.225
# progress:  39 / 307
# question:  [u'joint', u'like', u'one', u'skull', u'vertebr', u'column', u'project', u'one', u'bone', u'fit', u'notch', u'anoth', u'bone', u'classifi']
# answer:  A:  ball-and-socket joint  B: hinge joint  C:  pivot joint D: sliding joint
# correct answer:  C
# my answer:  A
# percent correct:  0.219512195122
# progress:  40 / 307
# question:  [u'scientist', u'collect', u'month', u'popul', u'count', u'three', u'anim', u'speci', u'forest', u'five', u'year', u'display', u'data', u'scientist', u'use', u'follow']
# answer:  A:  a table  B: a pie chart  C:  a line graph D: a scatterplot
# correct answer:  C
# my answer:  B
# percent correct:  0.214285714286
# progress:  41 / 307
# question:  [u'gasolin', u'car', u'produc', u'fossil', u'fuel', u'use', u'gasolin', u'like', u'lead', u'environment', u'problem']
# answer:  A:  soil erosion  B: water pollution  C:  wildlife extinction D: global warming
# correct answer:  D
# my answer:  B
# percent correct:  0.209302325581
# progress:  42 / 307
# question:  [u'carbon', u'earth', u'found', u'live', u'nonliv', u'matter', u'in', u'order', u'carbon', u'continu', u'avail', u'must', u'recycl', u'process', u'carbon', u'made', u'avail', u'atmospher']
# answer:  A:  formation of fossil fuels  B: layering of soil  C:  plant photosynthesis D: forest fires
# correct answer:  D
# my answer:  B
# percent correct:  0.204545454545
# progress:  43 / 307
# question:  [u'gold', u'atom', u'identifi', u'base', u'number', u'subatom', u'particl']
# answer:  A:  neutrons  B: electrons  C:  nuclei D: protons
# correct answer:  D
# my answer:  A
# percent correct:  0.2
# progress:  44 / 307
# question:  [u'base', u'locat', u'period', u'tabl', u'element', u'chemic', u'properti', u'similar', u'calcium', u'ca']
# answer:  A:  beryllium, Be  B: potassium, K  C:  titanium, Ti D: yttrium, Y
# correct answer:  A
# my answer:  A
# percent correct:  0.217391304348
# progress:  45 / 307
# question:  [u'light', u'inform', u'transfer', u'electr', u'inform', u'follow', u'structur', u'eye']
# answer:  A:  lens  B: retina  C:  rods and cones D: optic nerve
# correct answer:  C
# my answer:  B
# percent correct:  0.212765957447
# progress:  46 / 307
# question:  [u'if', u'marci', u'want', u'find', u'averag', u'length', u'th', u'grade', u'student', u'foot', u'follow', u'would', u'lead', u'accur', u'result']
# answer:  A:  Marcy has five people cut string that is approximately 12 inches long and has them measure the feet of 100 8th grade students.  B: Marcy has five people measure the feet of their five best friends.  C:  Marcy measures the feet of the first 500 people she sees on the school campus. D: Marcy gives one person a 12-inch ruler and has that person measure the feet of 100 8th grade students.
# correct answer:  D
# my answer:  A
# percent correct:  0.208333333333
# progress:  47 / 307
# question:  [u'most', u'concentr', u'gas', u'result', u'activ', u'produc', u'organ']
# answer:  A:  nitrogen  B: oxygen  C:  water vapor D: carbon dioxide
# correct answer:  B
# my answer:  C
# percent correct:  0.204081632653
# progress:  48 / 307
# question:  [u'which', u'follow', u'greatest', u'effect', u'speed', u'sound', u'travel', u'gas']
# answer:  A:  the ability of electrons to travel through a medium  B: the frequency of the wave  C:  the amplitude of the wave D: the proximity of the molecules of the medium
# correct answer:  D
# my answer:  B
# percent correct:  0.2
# progress:  49 / 307
# question:  [u'fossil', u'record', u'show', u'first', u'organ', u'earth', u'anaerob', u'anaerob', u'defin', u'follow', u'statement']
# answer:  A:  must use oxygen to breathe  B: does not use oxygen to breathe  C:  must use carbon dioxide to breathe D: does not use nitrogen to breathe
# correct answer:  B
# my answer:  B
# percent correct:  0.21568627451
# progress:  50 / 307
# question:  [u'team', u'surveyor', u'take', u'measur', u'ground', u'altitud', u'horizont', u'interv', u'meter', u'squar', u'meter', u'area', u'these', u'measur', u'best', u'use', u'produc', u'represent', u'area']
# answer:  A:  a topographical map  B: a map of wind currents  C:  a plate tectonic diagram D: a chart of sedimentary layers
# correct answer:  A
# my answer:  A
# percent correct:  0.230769230769
# progress:  51 / 307
# question:  [u'activ', u'light', u'like', u'refract']
# answer:  A:  placing a scarf over the shade of a lamp  B: viewing objects using the side mirror of a car  C:  looking at pebbles through the water in a stream D: using a flashlight to light up a forest path at night
# correct answer:  C
# my answer:  B
# percent correct:  0.22641509434
# progress:  52 / 307
# question:  [u'complet', u'remov', u'decompos', u'ecosystem', u'greatest', u'effect', u'follow']
# answer:  A:  the spread of disease  B: the availability of water  C:  the recycling of nutrients D: the distribution of organisms
# correct answer:  C
# my answer:  B
# percent correct:  0.222222222222
# progress:  53 / 307
# /Users/MK/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:20: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-2377d5452a2e> in <module>()
#       5 length = len(train)
#       6 for i in xrange(len(train)):
# ----> 7     close = run_close_document( train.ix[i][1] , wiki_folder_path, dictionary, df_wiki_vector, 1)
#       8     close = only_the_words_in_index( split_result(close), model.index2word)
#       9
#
# <ipython-input-4-ea7c4b980b00> in run_close_document(main_text, wiki_folder_path, dictionary, df_wiki_vector, topn)
#      13
#      14 def run_close_document( main_text , wiki_folder_path, dictionary, df_wiki_vector, topn):
# ---> 15     close_document =  get_close_documents(main_text, df_wiki_vector, dictionary, topn, wiki_folder_path)
#      16     return close_document
#      17
#
# <ipython-input-2-0dbe945268e4> in get_close_documents(string, dataframe, dictionary, topn, path)
#      72     lengthlist = pd.Series()
#      73     for j in xrange(len(dataframe.columns)):
# ---> 74         lengthlist = lengthlist.set_value( j, spatial.distance.cosine(first_vector, dataframe[j]))
#      75         lengthlist = lengthlist.sort_values().head(topn)
#      76         #now we have a topn index of the close documents.
#
# /Users/MK/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.pyc in cosine(u, v)
#     294     u = _validate_vector(u)
#     295     v = _validate_vector(v)
# --> 296     dist = 1.0 - np.dot(u, v) / (norm(u) * norm(v))
#     297     return dist
#     298
#
# /Users/MK/anaconda/lib/python2.7/site-packages/scipy/linalg/misc.pyc in norm(a, ord)
#     117         if ord in (None, 2) and (a.ndim == 1):
#     118             # use blas for fast and stable euclidean norm
# --> 119             nrm2 = get_blas_funcs('nrm2', dtype=a.dtype)
#     120             return nrm2(a)
#     121
#
# /Users/MK/anaconda/lib/python2.7/site-packages/scipy/linalg/blas.pyc in get_blas_funcs(names, arrays, dtype)
#     305     return _get_funcs(names, arrays, dtype,
#     306                       "BLAS", _fblas, _cblas, "fblas", "cblas",
# --> 307                       _blas_alias)
#
# /Users/MK/anaconda/lib/python2.7/site-packages/scipy/linalg/blas.pyc in _get_funcs(names, arrays, dtype, lib_name, fmodule, cmodule, fmodule_name, cmodule_name, alias)
#     243         module1, module2 = module2, module1
#     244
# --> 245     for i, name in enumerate(names):
#     246         func_name = prefix + name
#     247         func_name = alias.get(func_name, func_name)
#
# KeyboardInterrupt:

# %%
answer_similarity = np.array([['A',model.n_similarity(q, a1)],['B',model.n_similarity(q, a2)],
                              ['C',model.n_similarity(q, a3)],['D',model.n_similarity(q, a4)]])
answer_similarity
# Out:
# array([['A', '0.163910336443'],
#        ['B', '0.301012949472'],
#        ['C', '0.100897692365'],
#        ['D', '0.218709438074']],
#       dtype='|S14')

# %%
train
# Out:
#      100005  \
# 0    100015
# 1    100024
# 2    100037
# 3    100039
# 4    100043
# 5    100051
# 6    100056
# 7    100064
# 8    100066
# 9    100068
# 10   100075
# 11   100089
# 12   100091
# 13   100095
# 14   100097
# 15   100100
# 16   100104
# 17   100124
# 18   100129
# 19   100132
# 20   100174
# 21   100187
# 22   100191
# 23   100198
# 24   100200
# 25   100201
# 26   100216
# 27   100232
# 28   100238
# 29   100240
# ..      ...
# 277  102239
# 278  102269
# 279  102284
# 280  102290
# 281  102291
# 282  102292
# 283  102301
# 284  102320
# 285  102327
# 286  102337
# 287  102365
# 288  102398
# 289  102402
# 290  102414
# 291  102421
# 292  102422
# 293  102423
# 294  102428
# 295  102432
# 296  102441
# 297  102442
# 298  102449
# 299  102466
# 300  102467
# 301  102470
# 302  102483
# 303  102488
# 304  102496
# 305  102497
# 306  102499
#
#     In which way is the orbit of a comet different from the orbit of Earth?  \
# 0    Achromatopsia is a genetic disorder in which s...
# 1    The brain, spinal cord, and nerves are organs ...
# 2    A research team wanted to produce a smaller va...
# 3    Some areas of the world are experiencing more ...
# 4    With climate and the transfer of energy as hea...
# 5    A family owns a vacation cabin located on a hi...
# 6    The plant, Arabidopsis thaliana, has a gene wh...
# 7    Trees most likely change the environment in wh...
# 8    Blood pressure is often used as an indicator o...
# 9    Frost wedging occurs when rocks are broken int...
# 10   When an atom has a neutral charge, which parti...
# 11   The flower petals of a hydrangea plant change ...
# 12   The central vacuole (the largest plant organel...
# 13   When methane is burned in oxygen, carbon dioxi...
# 14   A short plant with a thick, fleshy stem, exten...
# 15   Half of a volcanic rock formation can be seen ...
# 16   If two organisms are classified in different o...
# 17   Ribosomes are the sites for which of the follo...
# 18   The process by which organisms with favorable ...
# 19   A volcanic island arc can be found at which ty...
# 20   Garrett collected some large rocks from a stre...
# 21   Prior to 1700, the process of fossil formation...
# 22   To initiate the formation of a planetesimal, w...
# 23   Newton's work in physics helped to provide mat...
# 24   A signal from the brain to a muscle in the arm...
# 25              In which structure is the Sun located?
# 26   The shoulder joint is similar to which type of...
# 27   A perpetual motion machine is a theoretical de...
# 28   In the planning and conducting of a scientific...
# 29   Vein deposits of gold and silver are often for...
# ..                                                 ...
# 277  Decomposers increase the fertility of the soil...
# 278  Rolanda is growing tomato plants in her garden...
# 279  Phobos is one of two large objects that orbit ...
# 280  The brain and spinal cord are parts of which b...
# 281  The sediments found in a riverbed are most lik...
# 282  A modern theory of the origin of the universe ...
# 283  According to the Big Bang Theory, which elemen...
# 284  After the formation of the Sun but before the ...
# 285  The orbit of Earth is almost circular and has ...
# 286  Earth's magnetic field helps to produce the au...
# 287  In which organelle does cellular respiration o...
# 288  Some plant species are more tolerant of acidic...
# 289  In which of the following types of cells does ...
# 290  Mount St. Helens was a cone-shaped mountain th...
# 291  A species lives in a region that changes over ...
# 292  Plate movement can form different features on ...
# 293  In gym class a student kicks a soccer ball hig...
# 294  Atoms of which of these elements are part of m...
# 295  An investigation is performed to determine how...
# 296  Pat has two kinds of plant food,"Quickgrow" an...
# 297  The reaction that releases energy for use by t...
# 298  When a cold front moves over a land region tha...
# 299  Electron transport in mitochondria results in ...
# 300  The sound, light, and heat that a firecracker ...
# 301  The mixing of cold Arctic Ocean water with war...
# 302  Nuclear fusion is the source of energy for sta...
# 303  In which taxonomic group are organisms found t...
# 304  An element with which property would be best t...
# 305  Pollen grains are cells that are specialized f...
# 306  Cellular respiration is the process by which o...
#
#      B The orbit of Earth is less circular than the orbit of a comet.  \
# 0    B                                          rod cells
# 1    D        supporting the body and enabling it to move
# 2    C                                         extinction
# 3    B                      consume large amounts of food
# 4    A                  conduction, convection, radiation
# 5    C  Water is pumped to the cabin from a distant re...
# 6    D      The gene codes for flower color in the plant.
# 7    D                    releasing nitrogen in the soil.
# 8    B                                               cmHg
# 9    A                                         weathering
# 10   B                             electrons and neutrons
# 11   D                                       gravitropism
# 12   B                                           tissues.
# 13   D                        new elements are rearranged
# 14   B                                            prairie
# 15   B  that earthquakes are the result of volcanic ac...
# 16   B                 The organisms have the same genus.
# 17   D                               nucleotide synthesis
# 18   B                              disruptive selection.
# 19   B                          divergent oceanic-oceanic
# 20   B                                             pounds
# 21   B  Robert Hooke's discovery delayed advancements ...
# 22   A  Matter must become unevenly distributed to cre...
# 23   C                                            Ptolemy
# 24   B                                    sensory neurons
# 25   A                                   Milky Way Galaxy
# 26   B                                      sliding joint
# 27   B                 Energy can be converted into mass.
# 28   B                           formulating a conclusion
# 29   A                                  igneous intrusion
# ..  ..                                                ...
# 277  B                                   by adding carbon
# 278  D                                          producers
# 279  B                                           asteroid
# 280  A                                            nervous
# 281  D                                               heat
# 282  D                                               iron
# 283  B                                     carbon dioxide
# 284  B           the formation of new elements in the Sun
# 285  C                                          asteroids
# 286  C                            adding to their charges
# 287  D                                        the nucleus
# 288  A                     mixing of pollutants with rain
# 289  C                                   plant cells only
# 290  C                                         hurricanes
# 291  B                     reduce the energy requirements
# 292  D                                         convergent
# 293  C                                     kinetic energy
# 294  C                                            calcium
# 295  A  releasing the ball from the same position in e...
# 296  C  Put some Quickgrow on a plant in the living ro...
# 297  D                                    Golgi apparatus
# 298  D             Ozone in the atmosphere will decrease.
# 299  C                                                ADP
# 300  B                                     nuclear energy
# 301  A        sinking of water as it circulates southwest
# 302  A                                             helium
# 303  A                                           bacteria
# 304  B                                          insulator
# 305  B                                              genes
# 306  B                                           products
#
#     The orbit of a comet is more elliptical than the orbit of Earth.  \
# 0                                           cone cells
# 1    transporting oxygen, wastes, and nutrients thr...
# 2                                             mutation
# 3                      become dormant for long periods
# 4                     reflection, retention, radiation
# 5    The family brings several gallons of bottled s...
# 6    The gene is controlled by environment and not ...
# 7                     crowding out non-native species.
# 8                                                 mmHg
# 9                                       transportation
# 10                               protons and electrons
# 11                                      photosynthesis
# 12                                              cells.
# 13                           new elements are produced
# 14                                              desert
# 15   that Earth's crust is made of rocky plates tha...
# 16               The organisms are in the same phylum.
# 17                                       transcription
# 18                                  natural selection.
# 19                          convergent oceanic-oceanic
# 20                                           kilograms
# 21   New evidence about fossils can change existing...
# 22   Particles must fuse into larger particles to i...
# 23                                           Aristotle
# 24                                        interneurons
# 25                                    Andromeda Galaxy
# 26                                     ball and socket
# 27        Friction reduces the efficiency in a system.
# 28                            formulating a hypothesis
# 29                                  transport by water
# ..                                                 ...
# 277                                 by adding nitrogen
# 278                                          consumers
# 279                                               moon
# 280                                          excretory
# 281                                           faulting
# 282                                             carbon
# 283                                           hydrogen
# 284     the distribution of elements in a solar nebula
# 285                                         meteorites
# 286                             adding to their masses
# 287                          the endoplasmic reticulum
# 288                 erosion of topsoil by clearcutting
# 289                                  animal cells only
# 290                                        earthquakes
# 291                 adapt to exploit changed resources
# 292                                         subduction
# 293                                     thermal energy
# 294                                          magnesium
# 295  keeping the ramp at the same height for all tr...
# 296  Find out how much each kind of plant food cost...
# 297                              endoplasmic reticulum
# 298    Less ultraviolet radiation will reach the land.
# 299                                                ATP
# 300                                    chemical energy
# 301  reversal of current direction back toward the ...
# 302                                           nitrogen
# 303                                              fungi
# 304                                          conductor
# 305                                              sperm
# 306                                          reactants
#
#     The orbital period of Earth is much longer than the orbital period of a comet.  \
# 0                                                 lens
# 1                    producing male and female gametes
# 2                                   selective breeding
# 3                 sense infrared and ultraviolet light
# 4                      convection, nuclear, reflection
# 5    Groundwater is drawn up in buckets from a priv...
# 6    Traits associated with this gene are beneficia...
# 7             adding carbon dioxide to the atmosphere.
# 8                                               g/cm^3
# 9                                           deposition
# 10                                neutrons and protons
# 11                                 geographic location
# 12                                      organ systems.
# 13                                    heat is absorbed
# 14                                   coniferous forest
# 15   that rock formations may move hundreds of mile...
# 16            The organisms are in different kingdoms.
# 17                                     lipid synthesis
# 18                                   sexual selection.
# 19                       divergent continental-oceanic
# 20                                        fluid ounces
# 21       Prior to 1700, fossils were much more common.
# 22   Gases must decrease in temperature enough to c...
# 23                                  Nicolas Copernicus
# 24                                       motor neurons
# 25                                    Cat's Eye Nebula
# 26                                               hinge
# 27   The amount of energy in a system remains const...
# 28                         analyzing experimental data
# 29                                 chemical weathering
# ..                                                 ...
# 277                           by removing excess water
# 278                                         scavengers
# 279                                              comet
# 280                                          endocrine
# 281                                           pressure
# 282                                             helium
# 283                                             oxygen
# 284  the supernova of the star previously found whe...
# 285                                             comets
# 286  providing a pathway to focus their collisions ...
# 287                                    the chloroplast
# 288               runoff of fertilizer used in farming
# 289                        both plant and animal cells
# 290                                 volcanic eruptions
# 291         interbreed with similar tropical organisms
# 292                                          transform
# 293                                   potential energy
# 294                                             oxygen
# 295  keeping the ramp facing the same direction for...
# 296  Put some Quickgrow on a few plants, put the sa...
# 297                               cytoplasmic membrane
# 298   More water will be absorbed from the area lakes.
# 299                                            protons
# 300                                  electrical energy
# 301  rise in water salinity and upwelling of affect...
# 302                                             oxygen
# 303                                             plants
# 304                                          malleable
# 305                                             testes
# 306                                     waste products
#
#     The orbital period of a comet is more predictable than the orbital period of Earth.
# 0                                                 iris
# 1     conducting messages to coordinate body functions
# 2                                    natural selection
# 3    transpire water through the skin to the atmosp...
# 4                           conduction, solar, nuclear
# 5    The family collects water in rain barrels left...
# 6    Traits associated with this gene may vary grea...
# 7    removing water from the soil and returning it ...
# 8                                               g/mm^3
# 9                                        lithification
# 10                                   ions and neutrons
# 11                            environmental conditions
# 12                                             organs.
# 13                                    heat is produced
# 14                                    deciduous forest
# 15   that Earth's current landforms were created wh...
# 16      The organisms are members of the same species.
# 17                                         translation
# 18                              directional selection.
# 19                      convergent continental-oceanic
# 20                                   cubic centimeters
# 21             Plants are more likely to form fossils.
# 22   Materials must be exposed to a strong magnetic...
# 23                                    Dmitri Mendeleev
# 24                             mechanoreceptor neurons
# 25                                    Horseshoe Nebula
# 26                                        antagonistic
# 27   Potential energy can be converted into kinetic...
# 28                    making experimental measurements
# 29                              compaction by pressure
# ..                                                 ...
# 277                        by removing excess minerals
# 278                                        decomposers
# 279                                             meteor
# 280                                        respiratory
# 281                                         weathering
# 282                                           hydrogen
# 283                                           nitrogen
# 284  the chemical reactions of hydrogen in nebular-...
# 285                                              moons
# 286  providing energy to start their chemical react...
# 287                                  the mitochondrion
# 288            thinning of the atmospheric ozone layer
# 289                      neither plant nor animal cell
# 290                               sediment depositions
# 291             emigrate before the change is complete
# 292                                          divergent
# 293                                  mechanical energy
# 294                                            silicon
# 295  measuring the length of the ramp before each t...
# 296  Look at the advertisements for Quickgrow, look...
# 297                             mitochondrial membrane
# 298  Water in the atmosphere will undergo a phase c...
# 299                                           neutrons
# 300                                  mechanical energy
# 301  rapid evaporation and acceleration of currents...
# 302                                            uranium
# 303                                            animals
# 304                                             porous
# 305                                               eggs
# 306                                              gases
#
# [307 rows x 7 columns]
