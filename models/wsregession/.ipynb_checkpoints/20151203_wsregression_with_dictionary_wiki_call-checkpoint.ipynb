# %%
import gensim
import logging
import os
import pandas as pd
import numpy as np
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from gensim import corpora

class MyDocument(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            with open(os.path.join(self.dirname, fname)) as content_file:
                content = content_file.read()  
                content = unicode(content, encoding='utf-8', errors='replace')
                yield content.lower().split()

class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                line = unicode(line, encoding='utf-8', errors='replace')
                yield line.lower().split()

def get_dictionary(path):
    dictionary = corpora.Dictionary( MySentences('/Users/MK/GitHub/the_answer_is/data/temporary2') )
    stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
    dictionary.filter_tokens(stop_ids) # remove stop words and words that appear only once
    dictionary.compactify() # remove gaps in id sequence after words that were removed
    return dictionary

def get_document_tuple( path, dictionary ):
    vector = pd.Series()
    doclist = MyDocument(path) 
    for i,content in enumerate(doclist):
        vector = vector.set_value(i,dictionary.doc2bow(content))
    return list(vector)

def transform_tuple_into_vector(document_tuple,dictionary):
    vector = pd.Series(np.zeros(len(dictionary.token2id)))        #0 array for storing wiki document vectors.
    for onetuple in document_tuple: 
        vector[onetuple[0]] = onetuple[1]
    vector = vector / np.linalg.norm(vector, ord = 1)                       #normalize vector     
    return vector 

def transform_tuples_into_dataframe(document_tuples, dictionary):
    length = len(document_tuples) 
    vector_initialization = pd.Series(np.zeros(len(dictionary.token2id)))  #0 array for storing wiki document vectors. 
    df_vector = pd.DataFrame(vector_initialization)  #initialize dataframe. all vectors will be stored. 
    for i in xrange(len(document_tuples)):           
        #for each wiki documents, we will transform wiki vectors in tuple form into
        #vectors in ususal form. 
        vector = transform_tuple_into_vector( document_tuples[i], dictionary )
        df_vector[i]= pd.DataFrame(vector)
    return df_vector

def get_close_documents(string, dataframe, dictionary, topn):
    string = unicode(string, encoding='utf-8', errors='replace')
    first_vector = transform_tuple_into_vector(dictionary.doc2bow(string.split()), dictionary )
    lengthlist = pd.Series()
    for i in xrange(len(dataframe.columns)):
        lengthlist = lengthlist.set_value(i, np.linalg.norm(first_vector-dataframe[i]) )
    return lengthlist.sort_values().head(topn)

def get_document_by_index(path,index):
    # this gets the filename and content of the document in a directory by index. 
    i= 0
    for fname in os.listdir(path):
        if i == index:
            with open(os.path.join(path, fname)) as content_file:
                content = content_file.read()  
                content = unicode(content, encoding='utf-8', errors='replace')
                return fname, content
        i= i + 1
    return None

def print_names_of_close_documents(path, close_documents_list, outputpath):
    file = open(outputpath + '/close_documents.txt', 'w+')
    for i in close_documents_list.index:
        name, text = get_document_by_index(path,i)
        print name
        file.write(text + '\n' + '\n' + '\n' + '\n')        
    print 'text saved as txt'

stoplist = [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours',
             u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', 
             u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', 
             u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', 
             u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', 
             u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', 
             u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', 
             u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', 
             u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', 
             u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', 
             u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', 
             u'should', u'now']

# %%
dictionary_path = '/Users/MK/GitHub/the_answer_is/data/temporary2'  # question text from training data
dictionary = get_dictionary(dictionary_path)
print (dictionary.token2id)
# Out:
# {u'xylem': 0, u'limited': 1, u'similarity': 2, u'phenotypical': 3, u'alleles': 4, u'magnetic': 5, u'saves': 6, u'desirable': 7, u'crumpled': 145, u'yellow': 9, u'chaos': 4364, u'four': 11, u'tensile': 12, u'heliocentric': 13, u'controversial': 14, u'consists': 15, u'oldest': 17, u'worked': 18, u'aggression': 19, u'poorly': 20, u'relationships': 21, u'whose': 22, u'fronts': 23, u'pedro': 24, u'calculate': 26, u'plumes': 3447, u'electricity': 27, u'powdery': 28, u'metamorphic': 29, u'seriously': 1711, u'supported': 4579, u'list': 2608, u'strawberries': 5157, u'investigation': 1712, u'swap': 33, u'caused': 2544, u'recycle': 35, u'herbicide': 36, u'shepherd': 4174, u'quartzite': 37, u'divergent': 38, u'humerus': 39, u'hormone': 40, u'risk': 41, u'downstream': 42, u'geology': 43, u'barium': 44, u'void': 45, u'oceans': 46, u'connects': 47, u'pigment': 49, u'replication': 50, u'every': 51, u'jack': 52, u'peripheral': 53, u'formula': 1715, u'overcomes': 55, u'vastly': 334, u'incubated': 3051, u'vast': 59, u'anemia': 60, u'blackcoated': 61, u'rainfalls': 62, u'school': 63, u'baking': 64, u'parrot': 65, u'investigator': 66, u'crops': 67, u'cause': 4373, u'solution': 69, u'humidity': 70, u'solid': 3465, u'fossilized': 5178, u'red': 4374, u'succession': 73, u'divides': 4327, u'venus': 75, u'chemically': 1719, u'reliable': 3467, u'methane': 78, u'chloroplast': 79, u'originate': 80, u'force': 81, u'cooperative': 2552, u'concise': 83, u'miller': 84, u'consistent': 85, u'bubbling': 86, u'feathers': 87, u'direct': 88, u'tires': 89, u'surrounding': 90, u'likely': 91, u'street': 92, u'chen': 94, u'arms': 95, u'estimated': 96, u'machines': 97, u'shining': 98, u'blue': 99, u'established': 100, u'settlement': 2557, u'previously': 5105, u'organisms': 102, u'nonfunctioning': 103, u'panama': 104, u'bicarbonate': 1724, u'contributed': 106, u'lizard': 107, u'malleable': 108, u'lights': 109, u'glands': 599, u'fallow': 110, u'localized': 111, u'establishes': 112, u'designing': 113, u'new': 114, u'net': 115, u'increasing': 116, u'ever': 117, u'consisting': 118, u'told': 119, u'evolving': 120, u'barometer': 122, u'sinks': 123, u'lithosphere': 124, u'mechanisms': 1727, u'hydrangea': 126, u'never': 127, u'drew': 128, u'atoms': 129, u'met': 130, u'feeding': 131, u'songbirds': 132, u'cart': 1728, u'ethanol': 134, u'represented': 135, u'watersoluble': 136, u'entire': 3960, u'cardboard': 137, u'interpret': 139, u'contraction': 140, u'obtained': 141, u'substance': 142, u'daughter': 143, u'uplifting': 144, u'items': 146, u'study': 147, u'changed': 148, u'reports': 149, u'tolerance': 4648, u'jogging': 150, u'ethane': 151, u'launched': 152, u'smoke': 153, u'browsing': 154, u'calculators': 155, u'military': 156, u'melaleuca': 157, u'suitable': 158, u'settled': 159, u'pairings': 161, u'diameter': 162, u'topography': 163, u'projection': 164, u'classification': 165, u'explained': 166, u'kiloliters': 167, u'seven': 168, u'highly': 169, u'neutrons': 170, u'visible': 171, u'pyramid': 173, u'prokaryotes': 176, u'counts': 177, u'total': 178, u'unit': 179, u'redflowered': 180, u'dna': 182, u'spoke': 183, u'would': 184, u'alligator': 185, u'marine': 1735, u'sweater': 187, u'chooses': 188, u'diaphragm': 190, u'call': 191, u'bedrock': 192, u'recommend': 193, u'strike': 194, u'survive': 195, u'retriever': 4393, u'type': 196, u'tell': 197, u'lightyear': 198, u'elias': 2574, u'separated': 200, u'females': 202, u'lungs': 203, u'populations': 204, u'composite': 205, u'expose': 206, u'pancreatic': 4979, u'meteorologist': 208, u'disruption': 209, u'warm': 210, u'adult': 211, u'separates': 212, u'containerswhich': 1271, u'organic': 4397, u'hole': 215, u'hold': 216, u'outdated': 217, u'must': 218, u'abundance': 219, u'intake': 220, u'word': 221, u'room': 222, u'equilibrium': 4614, u'player': 223, u'ml': 224, u'setup': 225, u'work': 226, u'eclipse': 227, u'worm': 228, u'roof': 1355, u'theories': 230, u'talked': 4048, u'iridium': 231, u'trilobites': 232, u'temperatures': 234, u'ms': 235, u' ...

# %%
wiki_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_without_stopwords'
wiki_tuple = get_document_tuple( wiki_path, dictionary )
wiki_tuple[3]

#this wiki_vector is in a condensed form. We need to transform it into a long form for getting distance.
# Out:
# [(11, 2),
#  (114, 1),
#  (316, 1),
#  (371, 1),
#  (691, 2),
#  (713, 1),
#  (862, 1),
#  (865, 1),
#  (1231, 1),
#  (1256, 1),
#  (1291, 1),
#  (1396, 1),
#  (1557, 1),
#  (1701, 1),
#  (1702, 1),
#  (1798, 1),
#  (1836, 1),
#  (1876, 1),
#  (1886, 1),
#  (1913, 1),
#  (2101, 1),
#  (2216, 1),
#  (2348, 2),
#  (2375, 1),
#  (2385, 1),
#  (2410, 1),
#  (2522, 1),
#  (2542, 1),
#  (2643, 1),
#  (2717, 1),
#  (2735, 1),
#  (2756, 1),
#  (2825, 8),
#  (2876, 1),
#  (2940, 1),
#  (2944, 1),
#  (2954, 1),
#  (2980, 1),
#  (3073, 1),
#  (3091, 1),
#  (3150, 1),
#  (3203, 1),
#  (3226, 1),
#  (3317, 1),
#  (3370, 1),
#  (3458, 2),
#  (3465, 2),
#  (3484, 1),
#  (3570, 1),
#  (3664, 1),
#  (3715, 2),
#  (3810, 1),
#  (3844, 1),
#  (3866, 1),
#  (4111, 1),
#  (4175, 1),
#  (4281, 1),
#  (4285, 1),
#  (4360, 1),
#  (4386, 1),
#  (4506, 1),
#  (4592, 1),
#  (4636, 1),
#  (4667, 1),
#  (4704, 1),
#  (4790, 4),
#  (4844, 4),
#  (5067, 1),
#  (5127, 1),
#  (5136, 1),
#  (5168, 1)]

# %%
print 'dictionary dimension is', len(dictionary.token2id)
# Out:
# dictionary dimension is 5287

# %%
df_wiki_vector = transform_tuples_into_dataframe(wiki_vector,dictionary)

# %%
df_wiki_vector.head(15)
# this is each column representing one wikipedia page
# Out:
#     0         1     2         3         4         5     6     7     8     \
# 0      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 1      0  0.000000     0  0.000000  0.000000  0.000536     0     0     0
# 2      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 3      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 4      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 5      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 6      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 7      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 8      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 9      0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 10     0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 11     0  0.017544     0  0.022222  0.000695  0.000000     0     0     0
# 12     0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 13     0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
# 14     0  0.000000     0  0.000000  0.000000  0.000000     0     0     0
#
#     9       ...         2131      2132      2133     2134  2135  2136  \
# 0      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 1      0    ...     0.000000  0.000611  0.001134  0.00000     0     0
# 2      0    ...     0.000000  0.000000  0.000567  0.00000     0     0
# 3      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 4      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 5      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 6      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 7      0    ...     0.000263  0.000000  0.000000  0.00062     0     0
# 8      0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 9      0    ...     0.000000  0.000000  0.005105  0.00000     0     0
# 10     0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 11     0    ...     0.000000  0.000000  0.001134  0.00000     0     0
# 12     0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 13     0    ...     0.000000  0.000000  0.000000  0.00000     0     0
# 14     0    ...     0.000263  0.000000  0.000000  0.00000     0     0
#
#         2137  2138      2139      2140
# 0   0.000000     0  0.000000  0.000000
# 1   0.002725     0  0.000805  0.000000
# 2   0.000000     0  0.000000  0.000000
# 3   0.000000     0  0.000000  0.000000
# 4   0.000000     0  0.000000  0.000000
# 5   0.000000     0  0.000000  0.000000
# 6   0.000000     0  0.000000  0.000000
# 7   0.000000     0  0.000000  0.000000
# 8   0.000000     0  0.000403  0.000000
# 9   0.000000     0  0.000000  0.000000
# 10  0.000000     0  0.000000  0.000000
# 11  0.001817     0  0.000000  0.000697
# 12  0.000000     0  0.000000  0.000000
# 13  0.000000     0  0.000000  0.000000
# 14  0.000000     0  0.000000  0.000000
#
# [15 rows x 2141 columns]

# %%
import pandas as pd
import os
path = '/Users/MK/GitHub/the_answer_is/data'
os.chdir(path)
train = pd.read_table('training_set.tsv',sep = '\t')
train.head(20)
# Out:
#         id                                           question correctAnswer  \
# 0   100001  When athletes begin to exercise, their heart r...             C
# 1   100002  Which example describes a learned behavior in ...             C
# 2   100003  When two nuclei are combined into one nucleus,...             D
# 3   100004  Which is a distinction between an epidemic and...             B
# 4   100005  In which way is the orbit of a comet different...             B
# 5   100006  A teacher builds a model of a hydrogen atom. A...             B
# 6   100007  Which substance should a student apply to the ...             A
# 7   100008  What is the main source of energy for the wate...             A
# 8   100009  Which has the greatest effect on aiding the mo...             D
# 9   100010  Over time, non-volcanic mountains can form due...             C
# 10  100011  The human body has an average, normal temperat...             D
# 11  100012  Which is the best explanation of the term ecol...             D
# 12  100013  A farmer sprayed his orange trees with a pesti...             A
# 13  100014  Researchers work in teams to make cars more fu...             C
# 14  100015  Achromatopsia is a genetic disorder in which s...             B
# 15  100016  Which of these elements is likely to be found ...             B
# 16  100017  Which statement describes a principle scientis...             C
# 17  100018  A scientist looks at a graph that shows the pe...             A
# 18  100019  Robots can perform tasks that are dangerous fo...             B
# 19  100020  A student investigated the percentage of energ...             B
#
#                                               answerA  \
# 0                                 at the tissue level
# 1                          smelling the air for odors
# 2                                          conversion
# 3                         the symptoms of the disease
# 4   The orbit of Earth is less circular than the o...
# 5                                 number of particles
# 6                                               water
# 7                                             the Sun
# 8                                             tension
# 9        oceanic plates colliding with oceanic plates
# 10                decrease sugar levels in the blood.
# 11  the study of the nonliving parts of the enviro...
# 12                                  natural selection
# 13       The research is more likely to be published.
# 14                                          rod cells
# 15                                             helium
# 16              Solid materials absorb seismic waves.
# 17                                          bar graph
# 18            The assembly pieces must be very small.
# 19                                            a table
#
#                                               answerB  \
# 0                                  at the organ level
# 1                              barking when disturbed
# 2                                            reaction
# 3                      the geographical area affected
# 4   The orbit of a comet is more elliptical than t...
# 5                          relative mass of particles
# 6                                             vinegar
# 7                                        fossil fuels
# 8                                            friction
# 9       oceanic plates separating from oceanic plates
# 10                increase sugar levels in the blood.
# 11   the study of the living parts of the environment
# 12                                 selective breeding
# 13                The research costs less to perform.
# 14                                         cone cells
# 15                                           hydrogen
# 16             Magnetic fields deflect seismic waves.
# 17                                        scatterplot
# 18  The assembly process must remain exactly the s...
# 19                                        a pie chart
#
#                                               answerC  \
# 0                                 at the system level
# 1                                  sitting on command
# 2                                             fission
# 3                   the species of organisms infected
# 4   The orbital period of Earth is much longer tha...
# 5                          types of particles present
# 6                                                salt
# 7                                              clouds
# 8                                             density
# 9   continental plates colliding with continental ...
# 10                   decrease blood flow to the skin.
# 11  the study of the protection and renewal of nat...
# 12                                aerobic respiration
# 13             The researchers can share their ideas.
# 14                                               lens
# 15                                            mercury
# 16  The density of a material affects the speed of...
# 17                                       circle graph
# 18                Robots require regular maintenance.
# 19                                        a bar graph
#
#                                               answerD
# 0                               at the cellular level
# 1                                     digging in soil
# 2                                              fusion
# 3             the season in which the disease spreads
# 4   The orbital period of a comet is more predicta...
# 5                        charges of particles present
# 6                                        formaldehyde
# 7                                           the ocean
# 8                                             gravity
# 9   continental plates separating from continental...
# 10                   increase blood flow to the skin.
# 11  the study of organisms and their interactions ...
# 12                                sexual reproduction
# 13   The researchers have more time to complete work.
# 14                                               iris
# 15                                                tin
# 16  The physical state of a material determines th...
# 17                                         pictograph
# 18          Robots must be provided with electricity.
# 19                                       a line graph

# %%
q = train.ix[2][1]
print q
# Out:
# When two nuclei are combined into one nucleus, there is a slight change in mass and the release of a large amount of energy. What is this process called?

# %%
close_documents = get_close_documents(q, df_wiki_vector, dictionary,50)
print close_documents
# Out:
# 1178    0.289175
# 211     0.292844
# 406     0.294458
# 1177    0.294606
# 1256    0.294959
# 1280    0.295250
# 1282    0.295251
# 230     0.295251
# 409     0.295251
# 1257    0.295750
# 1797    0.295750
# 900     0.295750
# 1082    0.296075
# 343     0.296567
# 666     0.296780
# 1366    0.296808
# 431     0.296808
# 108     0.296845
# 640     0.296887
# 408     0.297185
# 404     0.297185
# 491     0.297445
# 1173    0.297445
# 1430    0.297445
# 1464    0.297445
# 1176    0.297445
# 2098    0.297445
# 1894    0.297445
# 819     0.297445
# 159     0.297805
# 157     0.297805
# 327     0.297899
# 106     0.297977
# 1723    0.297977
# 1334    0.297977
# 109     0.297977
# 1686    0.297977
# 125     0.297977
# 422     0.297977
# 984     0.297977
# 1524    0.297977
# 1904    0.297977
# 113     0.297977
# 114     0.297977
# 727     0.297977
# 112     0.297977
# 754     0.298265
# 736     0.298601
# 1051    0.298629
# 1557    0.298635
# dtype: float64

# %%
wiki_path = '/Users/MK/GitHub/the_answer_is/data/wikipedia_without_stopwords'
outputpath = '/Users/MK/GitHub/the_answer_is/data'
print_names_of_close_documents(wiki_path, close_documents,outputpath)
# Out:
# mass_vs_weight_in_physical_science.txt_to_unicode_remove_stopwords.txt
# calculating_atomic_mass.txt_to_unicode_remove_stopwords.txt
# conservation_of_mass_in_chemical_reactions.txt_to_unicode_remove_stopwords.txt
# mass_vs_weight.txt_to_unicode_remove_stopwords.txt
# molality.txt_to_unicode_remove_stopwords.txt
# momentum.txt_to_unicode_remove_stopwords.txt
# momentum_in_physical_science.txt_to_unicode_remove_stopwords.txt
# cancer_in_life_science.txt_to_unicode_remove_stopwords.txt
# conservation_of_momentum_in_one_dimension.txt_to_unicode_remove_stopwords.txt
# molar_mass.txt_to_unicode_remove_stopwords.txt
# si_mass_and_weight_units.txt_to_unicode_remove_stopwords.txt
# heats_of_vaporization_and_condensation.txt_to_unicode_remove_stopwords.txt
# large_intestine.txt_to_unicode_remove_stopwords.txt
# CK12original_text.txt_to_unicode_remove_stopwords.txt
# enthalpy.txt_to_unicode_remove_stopwords.txt
# nuclear_fusion_in_physical_science.txt_to_unicode_remove_stopwords.txt
# cooling_systems_in_physical_science.txt_to_unicode_remove_stopwords.txt
# atomic_nucleus.txt_to_unicode_remove_stopwords.txt
# electroplating.txt_to_unicode_remove_stopwords.txt
# conservation_of_mass_in_physical_science.txt_to_unicode_remove_stopwords.txt
# conservation_of_mass.txt_to_unicode_remove_stopwords.txt
# diabetes_in_life_science.txt_to_unicode_remove_stopwords.txt
# mass_mole_stoichiometry.txt_to_unicode_remove_stopwords.txt
# pathogens_in_life_science.txt_to_unicode_remove_stopwords.txt
# photosynthesis_reactions.txt_to_unicode_remove_stopwords.txt
# mass_volume_stoichiometry.txt_to_unicode_remove_stopwords.txt
# volume_volume_stoichiometry.txt_to_unicode_remove_stopwords.txt
# stoichiometry.txt_to_unicode_remove_stopwords.txt
# gas_stoichiometry.txt_to_unicode_remove_stopwords.txt
# biochemical_reactions.txt_to_unicode_remove_stopwords.txt
# biochemical_properties_of_water.txt_to_unicode_remove_stopwords.txt
# chemistry_of_life.txt_to_unicode_remove_stopwords.txt
# atomic_forces_in_physical_science.txt_to_unicode_remove_stopwords.txt
# rutherfords_atomic_model_in_physical_science.txt_to_unicode_remove_stopwords.txt
# neutrons_in_physical_science.txt_to_unicode_remove_stopwords.txt
# atomic_nucleus_in_physical_science.txt_to_unicode_remove_stopwords.txt
# resistor_circuits.txt_to_unicode_remove_stopwords.txt
# avogadros_hypothesis_and_molar_volume.txt_to_unicode_remove_stopwords.txt
# conversion_between_moles_and_atoms.txt_to_unicode_remove_stopwords.txt
# importance_of_mammals_in_life_science.txt_to_unicode_remove_stopwords.txt
# power.txt_to_unicode_remove_stopwords.txt
# structure_of_the_nuclear_atom.txt_to_unicode_remove_stopwords.txt
# atoms.txt_to_unicode_remove_stopwords.txt
# atoms_in_physical_science.txt_to_unicode_remove_stopwords.txt
# features_of_populations_in_life_science.txt_to_unicode_remove_stopwords.txt
# atomic_structure.txt_to_unicode_remove_stopwords.txt
# flatworms.txt_to_unicode_remove_stopwords.txt
# fertilization.txt_to_unicode_remove_stopwords.txt
# isomers.txt_to_unicode_remove_stopwords.txt
# probability_and_inheritance.txt_to_unicode_remove_stopwords.txt
# text saved as txt
