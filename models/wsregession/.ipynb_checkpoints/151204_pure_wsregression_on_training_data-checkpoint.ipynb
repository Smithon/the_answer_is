# %%
__author__ = 'MK'

import nltk
import csv
import numpy as np
import pandas as pd
import time

from nltk.corpus import wordnet

def getdef(word):
    '''
    :param word: input is a word in a string format
    :return: returns a string that combines 3 definitions. 
    '''
    addef = word            #the word itself goes into the definition.

    for synset in wordnet.synsets(word)[:1]:
        addef = addef + ' ' + synset.definition()

    return addef


def doc_to_def(doc):
    ''' 
    :param doc: input is a document in a string format. Ex: "I have an apple" 
    :return: returns a list of definitions. The length of the list is the number of words in a string.   
    '''
    definition = []
    tokens = nltk.word_tokenize(doc)

    length = len(tokens)    # for printing out the progress
    print 'doc_to_def progress:  0 / ', length
    progress = 0

    for element in tokens:
        temp = getdef(element)
        definition.append(temp)

        progress = progress + 1
        print 'doc_to_def progress: ', progress, ' / ', length

    return definition


def list_to_def(list):
    ''' 
    :param list: input is a document in a list format. Ex: "['I', 'have', 'an', 'apple', '.']"
    :return: returns a list of definitions. The length of the list is the number of words in a list.  
    '''
    length = len(list)  # for printing out the progress
    print 'list_to_def progress:  0 / ', length
    progress = 0

    definition = []

    for element in list:
        temp = getdef(element)
        definition.append(temp)

        progress = progress + 1
        print 'list_to_def progress: ', progress, ' / ', length

    return definition


def def_to_beta(definition,wordspace):
    ''' 
    :param definition: input is a list of definitions.  
    :param wordspace: list of words. This is the wordspace. Note that if the wordspace does not contain the words in the input (definition), it will give an error. 
    Use get_wordspace( [input1, input2,..] ) as your wordspace. 
    :return: returns a pandas series of a beta of one document.
    '''

    deflength = len(definition)
    print 'progress:  0 / ', deflength  # for printing out the progress
    progress = 0

    beta = pd.Series(np.zeros(len(wordspace)), index = wordspace)

    for element in definition:
        token = nltk.word_tokenize(element)
        for word in token:
            beta[word] = beta[word]  + 1

        progress = progress + 1
        print 'progress: ', progress, ' / ', deflength

    return beta

def run_beta( text, wordspace ):
    ''' 
    :param text:  One document. it could be a "string" or a "list of strings"
    :param wordspace: list of words. Must contain all the words in the definition of the input words. 
    Use get_wordspace( [input1, input2,..] ) as your wordspace. 
    :return: returns a pandas series of a beta of one document. 
    '''


    if type(text) == str:
        text = doc_to_def(text)
    else:
        text = list_to_def(text)


    beta = def_to_beta(text, wordspace)

    beta = beta / np.linalg.norm(beta)

    return beta

def beta_to_matrix(keybeta, searchbeta):
    ''' 
    :param keybeta: a list of beta values of the key documents. 
    :param searchbeta: a list of the beta values of the search documents. 
    :return: returns the matrix of the Euclidean distance between two betas. 
    '''
    
    matrix = np.zeros(len(keybeta) * len(searchbeta) ).reshape(len(searchbeta),len(keybeta))
    i = 0
    while i < len(searchbeta):
        j = 0
        while j < len(keybeta):
            matrix[i,j] = np.linalg.norm(keybeta[j]-searchbeta[i])
            j = j + 1

        i = i + 1

    return matrix

def run_wsregression( keydoc, searchdoc, wordspace):
    '''
    :param keydoc: a list of key documents (documents are in list or string format)
    :param searchdoc: a list of search documents.
    :param wordspace: list of words that you want to use as wordspace. Use get_wordspace( keydoc + searchdoc )
    :return: matrix in pandas DataFrame format.
    '''

    keybeta = []
    for text in keydoc:
        keybeta.append(run_beta( text, wordspace ))

    searchbeta = []
    for text in searchdoc:
        searchbeta.append(run_beta( text, wordspace ))

    matrix = beta_to_matrix(keybeta, searchbeta)

    matrix = pd.DataFrame(matrix)
    columnnames = []
    rownames = []
    i= 0
    j=0
    while i < matrix.shape[1]:
        columnnames.append('KeyDoc' + str(i+1))
        i = i +1
    while j < matrix.shape[0]:
        rownames.append('SearchDoc' + str(j+1))
        j = j +1

    matrix.columns = [columnnames]
    matrix.index = [rownames]

    return matrix


def get_wordspace( inputdoclist ):
    '''
    :param inputdoclist: list of documents that are used in the wsregression.
    :return: list of all words that show up in the definition of all words in the documents.
    '''

    wordspace = []
    for text in inputdoclist:

        if type(text) == str:
            text = nltk.word_tokenize(text)

        length = len(text)    # for printing out the progress
        print 'get_wordspace progress:  0 / ', length
        progress = 0

        setindex = 0

        for element in text:
            temp = getdef(element)
            wordspace = wordspace +  nltk.word_tokenize(temp)
            progress = progress + 1
            print 'get_wordspace progress: ', progress, ' / ', length

            if (setindex > 3000):
                wordspace = list(set(wordspace))
                setindex = 0

            setindex = setindex + 1

    return list(set(wordspace))



def time_execution(code):
    start = time.clock()
    result = eval(code)
    run_time = time.clock() - start
    return result, run_time



# this procedure searches for sublist in the list. 
def _search(forward, source, target, start=0, end=None):
    """Naive search for target in source."""
    m = len(source)
    n = len(target)
    if end is None:
        end = m
    else:
        end = min(end, m)
    if n == 0 or (end-start) < n:
        # target is empty, or longer than source, so obviously can't be found.
        return None
    if forward:
        x = range(start, end-n+1)
    else:
        x = range(end-n, start-1, -1)
    for i in x:
        if source[i:i+n] == target:
            return i
    return None

import functools
search = functools.partial(_search, True)
rsearch = functools.partial(_search, False)


_doc = """%(name)s(sequence, subsequence [, start [, end]]) -> int or None

Search a sequence[start:end] for a subsequence starting from the %(dir)s,
returning the offset if it is found, otherwise None.

>>> %(name)s([1, 2, "z", 2, "a", 3, 2, "a"], [2, "a"])
%(value)d

If not given, start and end default to the beginning and end of the sequence.
"""

search.__doc__ = _doc % {'name': 'search', 'value': 3, 'dir': 'left'}
rsearch.__doc__ = _doc % {'name': 'rsearch', 'value': 6, 'dir': 'right'}
search.__name__ = 'search'
rsearch.__name__ = 'rsearch'
del _doc, _search

# %%
#call the training data.
train = pd.read_table('/Users/MK/GitHub/the_answer_is/data/training_set.tsv', sep = '\t')

# %%
import pprint
pprint.pprint(train)
# Out:
#           id                                           question correctAnswer  \
# 0     100001  When athletes begin to exercise, their heart r...             C
# 1     100002  Which example describes a learned behavior in ...             C
# 2     100003  When two nuclei are combined into one nucleus,...             D
# 3     100004  Which is a distinction between an epidemic and...             B
# 4     100005  In which way is the orbit of a comet different...             B
# 5     100006  A teacher builds a model of a hydrogen atom. A...             B
# 6     100007  Which substance should a student apply to the ...             A
# 7     100008  What is the main source of energy for the wate...             A
# 8     100009  Which has the greatest effect on aiding the mo...             D
# 9     100010  Over time, non-volcanic mountains can form due...             C
# 10    100011  The human body has an average, normal temperat...             D
# 11    100012  Which is the best explanation of the term ecol...             D
# 12    100013  A farmer sprayed his orange trees with a pesti...             A
# 13    100014  Researchers work in teams to make cars more fu...             C
# 14    100015  Achromatopsia is a genetic disorder in which s...             B
# 15    100016  Which of these elements is likely to be found ...             B
# 16    100017  Which statement describes a principle scientis...             C
# 17    100018  A scientist looks at a graph that shows the pe...             A
# 18    100019  Robots can perform tasks that are dangerous fo...             B
# 19    100020  A student investigated the percentage of energ...             B
# 20    100021  The Voyager II space probe was launched in 197...             C
# 21    100022  Which cellular structure allows nutrients to p...             C
# 22    100023  Which behavior can help animals establish a te...             C
# 23    100024  The brain, spinal cord, and nerves are organs ...             D
# 24    100025    Which statement best describes a liquid sample?             A
# 25    100026  A condition in bees called "colony collapse di...             B
# 26    100027  Which set contains kingdoms that contain only ...             D
# 27    100028  When light passes through the lens of your eye...             D
# 28    100029  How should researchers share their findings wi...             B
# 29    100030  Some ancient Greeks tried to discover the laws...             B
# ...      ...                                                ...           ...
# 2470  102471  The large, complex molecules found in living o...             B
# 2471  102472  The interior of Earth is made up of several ph...             B
# 2472  102473             The building of a dam will most likely             B
# 2473  102474  On the periodic table, the elements in group 1...             B
# 2474  102475  Which of the following statements best explain...             B
# 2475  102476  Which is an example of an organism that has be...             D
# 2476  102477  A sample in a cylindrical container has a cyli...             B
# 2477  102478  At irregular intervals of three to seven years...             C
# 2478  102479  Two seismographs are placed 500 km from an act...             D
# 2479  102480  A sperm that contains alleles HqT fuses with a...             D
# 2480  102481  Fertilization results from the combination of ...             C
# 2481  102482  Which invention would a culture living above t...             C
# 2482  102483  Nuclear fusion is the source of energy for sta...             A
# 2483  102484  Which of the following statements BEST defines...             C
# 2484  102485  South America and Africa are two continents se...             D
# 2485  102486  Lighting a match and baking a cake are two act...             B
# 2486  102487  The most common way humans contribute to the e...             C
# 2487  102488  In which taxonomic group are organisms found t...             A
# 2488  102489  When do females begin producing their sex cell...             B
# 2489  102490  Which of the following substances cannot pass ...             C
# 2490  102491                   How do surface currents develop?             C
# 2491  102492  A baby kit fox grows to become an adult with a...             B
# 2492  102493  Which of the following is believed to be one c...             A
# 2493  102494  The abundance of a mineral at the surface of E...             B
# 2494  102495  Because of the many environmental changes in E...             A
# 2495  102496  An element with which property would be best t...             B
# 2496  102497  Pollen grains are cells that are specialized f...             B
# 2497  102498         Biodiversity can be altered by __________.             D
# 2498  102499  Cellular respiration is the process by which o...             B
# 2499  102500  A scientist working at a pharmaceutical compan...             D
#
#                                                 answerA  \
# 0                                   at the tissue level
# 1                            smelling the air for odors
# 2                                            conversion
# 3                           the symptoms of the disease
# 4     The orbit of Earth is less circular than the o...
# 5                                   number of particles
# 6                                                 water
# 7                                               the Sun
# 8                                               tension
# 9          oceanic plates colliding with oceanic plates
# 10                  decrease sugar levels in the blood.
# 11    the study of the nonliving parts of the enviro...
# 12                                    natural selection
# 13         The research is more likely to be published.
# 14                                            rod cells
# 15                                               helium
# 16                Solid materials absorb seismic waves.
# 17                                            bar graph
# 18              The assembly pieces must be very small.
# 19                                              a table
# 20                                               meters
# 21                                        mitochondrion
# 22                  A caribou herd migrates seasonally.
# 23          supporting the body and enabling it to move
# 24    It will retain its volume if transferred to a ...
# 25         There would be a decrease in soil thickness.
# 26                                      Protists, Fungi
# 27                                            a smaller
# 28      e-mail the research results to local newspapers
# 29                                             analysis
# ...                                                 ...
# 2470                  water, carbon dioxide, and oxygen
# 2471                                              core.
# 2472                           prevent water pollution.
# 2473                         they are lighter than air.
# 2474  The warm ocean currents flow from the tropics ...
# 2475                                 cats that eat mice
# 2476                                     must be solid.
# 2477                                          hurricane
# 2478                   the pull of gravity on the waves
# 2479                                             HHqqTt
# 2480                                      two egg cells
# 2481                                     ice production
# 2482                                             helium
# 2483  The amount of time it takes light to travel th...
# 2484  The continents were both created through volca...
# 2485                   They change the state of matter.
# 2486                                 rotation of crops.
# 2487                                           bacteria
# 2488                    when they reach sexual maturity
# 2489                                             oxygen
# 2490               friction between the ocean and rocks
# 2491                         the size of the fox's ears
# 2492                 atmospheric rise of carbon dioxide
# 2493                    climate of a particular region.
# 2494                                    are now extinct
# 2495                                          insulator
# 2496                                              genes
# 2497  unexpected changes in the climate of an ecosystem
# 2498                                           products
# 2499         so that other cold medicines can be tested
#
#                                                 answerB  \
# 0                                    at the organ level
# 1                                barking when disturbed
# 2                                              reaction
# 3                        the geographical area affected
# 4     The orbit of a comet is more elliptical than t...
# 5                            relative mass of particles
# 6                                               vinegar
# 7                                          fossil fuels
# 8                                              friction
# 9         oceanic plates separating from oceanic plates
# 10                  increase sugar levels in the blood.
# 11     the study of the living parts of the environment
# 12                                   selective breeding
# 13                  The research costs less to perform.
# 14                                           cone cells
# 15                                             hydrogen
# 16               Magnetic fields deflect seismic waves.
# 17                                          scatterplot
# 18    The assembly process must remain exactly the s...
# 19                                          a pie chart
# 20                                           kilometers
# 21                                              nucleus
# 22           A scent trail leads ants to a food source.
# 23    transporting oxygen, wastes, and nutrients thr...
# 24    It keeps its shape when transferred to a large...
# 25        There would be a decline in fruit production.
# 26                                    Bacteria, Animals
# 27                                             a larger
# 28    publish the research results in a scientific j...
# 29                                           experiment
# ...                                                 ...
# 2470              carbohydrates, fats, proteins and DNA
# 2471                                             crust.
# 2472           destroy habitat for many animal species.
# 2473              they have full outer electron shells.
# 2474  The rays of the Sun strike the Northern Hemisp...
# 2475                           cows that graze on grass
# 2476                   could be either solid or liquid.
# 2477                                            tornado
# 2478                the interaction of light with waves
# 2479                                             HhQqTt
# 2480                                    two sperm cells
# 2481                                   air conditioning
# 2482                                           nitrogen
# 2483  The measure of how bright an object appears in...
# 2484  The fossils were brought to South America by e...
# 2485                        They create new substances.
# 2486                                use of fertilizers.
# 2487                                              fungi
# 2488                               before they are born
# 2489                                             wastes
# 2490                  mixture of minerals and saltwater
# 2491                the conditions of the fox's habitat
# 2492               hot air from air conditioner exhaust
# 2493          types of elements available in the crust.
# 2494                    have evolved into other animals
# 2495                                          conductor
# 2496                                              sperm
# 2497                            a fire in the ecosystem
# 2498                                          reactants
# 2499  so that the medicine can be used to treat othe...
#
#                                                 answerC  \
# 0                                   at the system level
# 1                                    sitting on command
# 2                                               fission
# 3                     the species of organisms infected
# 4     The orbital period of Earth is much longer tha...
# 5                            types of particles present
# 6                                                  salt
# 7                                                clouds
# 8                                               density
# 9     continental plates colliding with continental ...
# 10                     decrease blood flow to the skin.
# 11    the study of the protection and renewal of nat...
# 12                                  aerobic respiration
# 13               The researchers can share their ideas.
# 14                                                 lens
# 15                                              mercury
# 16    The density of a material affects the speed of...
# 17                                         circle graph
# 18                  Robots require regular maintenance.
# 19                                          a bar graph
# 20                                   astronomical units
# 21                                             membrane
# 22    A wolf pack howls to warn other wolves to stay...
# 23                    producing male and female gametes
# 24    Its volume can be greatly reduced by adding pr...
# 25        There would be an increase in plant diseases.
# 26                                        Plants, Fungi
# 27                                           an upright
# 28         publish the results in brochures for doctors
# 29                                           conclusion
# ...                                                 ...
# 2470            carbohydrates, proteins, water and salt
# 2471                                     asthenosphere.
# 2472           allow fish to more easily swim up river.
# 2473               they have excess electrons to share.
# 2474  The greenhouse effect increases in the Norther...
# 2475                         pigs that form large herds
# 2476                                    must be liquid.
# 2477                                            El Niño
# 2478  the differences in the strength of the waves' ...
# 2479                                             Hhqqtt
# 2480                       an egg cell and a sperm cell
# 2481                                 insulated clothing
# 2482                                             oxygen
# 2483    The average distance between the Sun and Earth.
# 2484  The animals crossed a land bridge that once co...
# 2485                                They change volume.
# 2486                            destruction of habitat.
# 2487                                             plants
# 2488                 before engaging in sexual activity
# 2489                                              blood
# 2490            friction between the ocean and the wind
# 2491                the average number of fox offspring
# 2492                methane gas escaping from landfills
# 2493                 thicknesses of nearby rock layers.
# 2494                          were plant-like organisms
# 2495                                          malleable
# 2496                                             testes
# 2497                           a flood in the ecosystem
# 2498                                     waste products
# 2499  so that other scientists can make the same col...
#
#                                                 answerD
# 0                                 at the cellular level
# 1                                       digging in soil
# 2                                                fusion
# 3               the season in which the disease spreads
# 4     The orbital period of a comet is more predicta...
# 5                          charges of particles present
# 6                                          formaldehyde
# 7                                             the ocean
# 8                                               gravity
# 9     continental plates separating from continental...
# 10                     increase blood flow to the skin.
# 11    the study of organisms and their interactions ...
# 12                                  sexual reproduction
# 13     The researchers have more time to complete work.
# 14                                                 iris
# 15                                                  tin
# 16    The physical state of a material determines th...
# 17                                           pictograph
# 18            Robots must be provided with electricity.
# 19                                         a line graph
# 20                                          light years
# 21                                          chloroplast
# 22    A honeybee society divides the work between it...
# 23     conducting messages to coordinate body functions
# 24    Its shape can be changed by increasing its tem...
# 25    There would be an increase in insect pest popu...
# 26                                       Animals, Fungi
# 27                                           an inverse
# 28         discuss the research results on the Internet
# 29                                          observation
# ...                                                 ...
# 2470              hydrogen, carbon, oxygen and nitrogen
# 2471                                        atmosphere.
# 2472                cause people to consume more water.
# 2473             they easily react with other elements.
# 2474  The Northern Hemisphere is closer to the Sun i...
# 2475                       chickens that lay large eggs
# 2476                     could be either liquid or gas.
# 2477                                          Santa Ana
# 2478  the different media through which the waves tr...
# 2479                                             HhqqTt
# 2480                                  two somatic cells
# 2481                                  irrigation canals
# 2482                                            uranium
# 2483  The distance of Earth's revolution around the ...
# 2484  The continents were once attached to each othe...
# 2485                                They create energy.
# 2486                 introduction of competing species.
# 2487                                            animals
# 2488            at the beginning of their monthly cycle
# 2489                                          nutrients
# 2490        mixture between freshwater deltas and rocks
# 2491     the social behaviors within the fox population
# 2492              body heat generated by overpopulation
# 2493       exposure of the elements to the environment.
# 2494                       have been affected by humans
# 2495                                             porous
# 2496                                               eggs
# 2497                                   All of the above
# 2498                                              gases
# 2499  so that the results can be accurately reported...
#
# [2500 rows x 7 columns]

# %%
question = train.ix[2][1]
print question
answer1 = train.ix[2][3]
answer2 = train.ix[2][4]
answer3 = train.ix[2][5]
answer4 = train.ix[2][6] 
print answer1, answer2, answer3, answer4
# Out:
# When two nuclei are combined into one nucleus, there is a slight change in mass and the release of a large amount of energy. What is this process called?
# conversion reaction fission fusion

# %%
def remove_stopwords(string):
    import re
    from nltk.corpus import stopwords
    string = re.sub(r'[^a-zA-Z ]',r'',string)  
    string = string.split()
    string = [word for word in string if word not in stopwords.words('english')]  # remove the stop words. 
    string = ' '.join(string)
    return string

question = remove_stopwords(question)
answer1 = remove_stopwords(answer1)
answer2 = remove_stopwords(answer2)
answer3 = remove_stopwords(answer3)
answer4 = remove_stopwords(answer4)
print question
print answer1, answer2, answer3, answer4
# Out:
# When two nuclei combined one nucleus slight change mass release large amount energy What process called
# conversion reaction fission fusion

# %%
wordspace = get_wordspace([question,answer1,answer2,answer3,answer4]) 
print wordspace
# Out:
# get_wordspace progress:  0 /  16
# get_wordspace progress:  1  /  16
# get_wordspace progress:  2  /  16
# get_wordspace progress:  3  /  16
# get_wordspace progress:  4  /  16
# get_wordspace progress:  5  /  16
# get_wordspace progress:  6  /  16
# get_wordspace progress:  7  /  16
# get_wordspace progress:  8  /  16
# get_wordspace progress:  9  /  16
# get_wordspace progress:  10  /  16
# get_wordspace progress:  11  /  16
# get_wordspace progress:  12  /  16
# get_wordspace progress:  13  /  16
# get_wordspace progress:  14  /  16
# get_wordspace progress:  15  /  16
# get_wordspace progress:  16  /  16
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# ['What', u'less', u'money', u'results', u'course', u'discourteous', u'causes', u'system', u'ergs', u'joules', u'(', u'to', u'production', u'issued', u'transformation', u'achieve', u'do', u'combination', u'showing', u'fusion', u'merchandise', u'possess', u'name', u'public', u'large', u'release', u'organisms', u'occurrence', u'weight', u'garment', u'energy', u'some', u'growth', u'are', u'specified', u'proper', u'event', u'capacity', u'for', u'deliberate', u'sum', u'fission', u'cell', u'state', u'smallest', u'numeral', u';', u'occurs', u'body', u'slight', u'equivalent', u'others', u'by', u'change', u'reaction', u'substances', u'of', u'RNA', u'changed', u'equal', u'amount', u'act', u'usually', u'expression', u'or', u'involves', u'into', 'When', u'number', u'one', u'unicellular', u'another', u'size', u'passes', u'from', u'union', u'two', u'disapproval', u'combined', u'more', u'DNA', u'that', u'part', u'particular', u'representing', u'this', u'gravitational', u'work', u'record', u'reproduction', u'property', u'called', u'result', u'and', u'division', u'process', u'is', u'it', u'an', u'as', u'something', u'have', u'in', u'anger', u'film', u'physical', u'containing', u')', u'responsible', u'when', u'field', u'parts', u'cardinal', u'which', u'units', u'intended', u'thermodynamic', u'conversion', u'action', u'nucleus', u'phase', u'nuclei', u'a', u'especially', u'whole', u'sale', u'assign', u'person', u'mass', u'the', u'chemistry', u'physics', u'quantity']

# %%
result = run_wsregression( [question], [answer1,answer2,answer3,answer4], wordspace)
print result
# Out:
# doc_to_def progress:  0 /  16
# doc_to_def progress:  1  /  16
# doc_to_def progress:  2  /  16
# doc_to_def progress:  3  /  16
# doc_to_def progress:  4  /  16
# doc_to_def progress:  5  /  16
# doc_to_def progress:  6  /  16
# doc_to_def progress:  7  /  16
# doc_to_def progress:  8  /  16
# doc_to_def progress:  9  /  16
# doc_to_def progress:  10  /  16
# doc_to_def progress:  11  /  16
# doc_to_def progress:  12  /  16
# doc_to_def progress:  13  /  16
# doc_to_def progress:  14  /  16
# doc_to_def progress:  15  /  16
# doc_to_def progress:  16  /  16
# progress:  0 /  16
# progress:  1  /  16
# progress:  2  /  16
# progress:  3  /  16
# progress:  4  /  16
# progress:  5  /  16
# progress:  6  /  16
# progress:  7  /  16
# progress:  8  /  16
# progress:  9  /  16
# progress:  10  /  16
# progress:  11  /  16
# progress:  12  /  16
# progress:  13  /  16
# progress:  14  /  16
# progress:  15  /  16
# progress:  16  /  16
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
#              KeyDoc1
# SearchDoc1  1.181938
# SearchDoc2  1.135487
# SearchDoc3  1.174840
# SearchDoc4  1.070520

# %%
print result.idxmin()           #my answer is SearchDocD, which is D.
# Out:
# KeyDoc1    SearchDoc4
# dtype: object

# %%
# %%capture         
#code for suppressing print in std-out.
myanswer = []     # store my answer in list. 
for i in xrange(len(train)):
    question = remove_stopwords(train.ix[i][1])
    answer1 = remove_stopwords(train.ix[i][3])
    answer2 = remove_stopwords(train.ix[i][4])
    answer3 = remove_stopwords(train.ix[i][5])
    answer4 = remove_stopwords(train.ix[i][6])
    wordspace = get_wordspace([question,answer1,answer2,answer3,answer4]) 
    result = run_wsregression( [question], [answer1,answer2,answer3,answer4], wordspace)
    myanswer.append(result.idxmin()[0])

# %%
train['wsregression_answer'] = myanswer
convert_answer = {'SearchDoc1': 'A', 'SearchDoc2': 'B', 'SearchDoc3': 'C', 'SearchDoc4': 'D' }
train['wsregression_answer'] = train['wsregression_answer'].map(convert_answer)

# %%
train
# Out:
#           id                                           question correctAnswer  \
# 0     100001  When athletes begin to exercise, their heart r...             C
# 1     100002  Which example describes a learned behavior in ...             C
# 2     100003  When two nuclei are combined into one nucleus,...             D
# 3     100004  Which is a distinction between an epidemic and...             B
# 4     100005  In which way is the orbit of a comet different...             B
# 5     100006  A teacher builds a model of a hydrogen atom. A...             B
# 6     100007  Which substance should a student apply to the ...             A
# 7     100008  What is the main source of energy for the wate...             A
# 8     100009  Which has the greatest effect on aiding the mo...             D
# 9     100010  Over time, non-volcanic mountains can form due...             C
# 10    100011  The human body has an average, normal temperat...             D
# 11    100012  Which is the best explanation of the term ecol...             D
# 12    100013  A farmer sprayed his orange trees with a pesti...             A
# 13    100014  Researchers work in teams to make cars more fu...             C
# 14    100015  Achromatopsia is a genetic disorder in which s...             B
# 15    100016  Which of these elements is likely to be found ...             B
# 16    100017  Which statement describes a principle scientis...             C
# 17    100018  A scientist looks at a graph that shows the pe...             A
# 18    100019  Robots can perform tasks that are dangerous fo...             B
# 19    100020  A student investigated the percentage of energ...             B
# 20    100021  The Voyager II space probe was launched in 197...             C
# 21    100022  Which cellular structure allows nutrients to p...             C
# 22    100023  Which behavior can help animals establish a te...             C
# 23    100024  The brain, spinal cord, and nerves are organs ...             D
# 24    100025    Which statement best describes a liquid sample?             A
# 25    100026  A condition in bees called "colony collapse di...             B
# 26    100027  Which set contains kingdoms that contain only ...             D
# 27    100028  When light passes through the lens of your eye...             D
# 28    100029  How should researchers share their findings wi...             B
# 29    100030  Some ancient Greeks tried to discover the laws...             B
# ...      ...                                                ...           ...
# 2470  102471  The large, complex molecules found in living o...             B
# 2471  102472  The interior of Earth is made up of several ph...             B
# 2472  102473             The building of a dam will most likely             B
# 2473  102474  On the periodic table, the elements in group 1...             B
# 2474  102475  Which of the following statements best explain...             B
# 2475  102476  Which is an example of an organism that has be...             D
# 2476  102477  A sample in a cylindrical container has a cyli...             B
# 2477  102478  At irregular intervals of three to seven years...             C
# 2478  102479  Two seismographs are placed 500 km from an act...             D
# 2479  102480  A sperm that contains alleles HqT fuses with a...             D
# 2480  102481  Fertilization results from the combination of ...             C
# 2481  102482  Which invention would a culture living above t...             C
# 2482  102483  Nuclear fusion is the source of energy for sta...             A
# 2483  102484  Which of the following statements BEST defines...             C
# 2484  102485  South America and Africa are two continents se...             D
# 2485  102486  Lighting a match and baking a cake are two act...             B
# 2486  102487  The most common way humans contribute to the e...             C
# 2487  102488  In which taxonomic group are organisms found t...             A
# 2488  102489  When do females begin producing their sex cell...             B
# 2489  102490  Which of the following substances cannot pass ...             C
# 2490  102491                   How do surface currents develop?             C
# 2491  102492  A baby kit fox grows to become an adult with a...             B
# 2492  102493  Which of the following is believed to be one c...             A
# 2493  102494  The abundance of a mineral at the surface of E...             B
# 2494  102495  Because of the many environmental changes in E...             A
# 2495  102496  An element with which property would be best t...             B
# 2496  102497  Pollen grains are cells that are specialized f...             B
# 2497  102498         Biodiversity can be altered by __________.             D
# 2498  102499  Cellular respiration is the process by which o...             B
# 2499  102500  A scientist working at a pharmaceutical compan...             D
#
#                                                 answerA  \
# 0                                   at the tissue level
# 1                            smelling the air for odors
# 2                                            conversion
# 3                           the symptoms of the disease
# 4     The orbit of Earth is less circular than the o...
# 5                                   number of particles
# 6                                                 water
# 7                                               the Sun
# 8                                               tension
# 9          oceanic plates colliding with oceanic plates
# 10                  decrease sugar levels in the blood.
# 11    the study of the nonliving parts of the enviro...
# 12                                    natural selection
# 13         The research is more likely to be published.
# 14                                            rod cells
# 15                                               helium
# 16                Solid materials absorb seismic waves.
# 17                                            bar graph
# 18              The assembly pieces must be very small.
# 19                                              a table
# 20                                               meters
# 21                                        mitochondrion
# 22                  A caribou herd migrates seasonally.
# 23          supporting the body and enabling it to move
# 24    It will retain its volume if transferred to a ...
# 25         There would be a decrease in soil thickness.
# 26                                      Protists, Fungi
# 27                                            a smaller
# 28      e-mail the research results to local newspapers
# 29                                             analysis
# ...                                                 ...
# 2470                  water, carbon dioxide, and oxygen
# 2471                                              core.
# 2472                           prevent water pollution.
# 2473                         they are lighter than air.
# 2474  The warm ocean currents flow from the tropics ...
# 2475                                 cats that eat mice
# 2476                                     must be solid.
# 2477                                          hurricane
# 2478                   the pull of gravity on the waves
# 2479                                             HHqqTt
# 2480                                      two egg cells
# 2481                                     ice production
# 2482                                             helium
# 2483  The amount of time it takes light to travel th...
# 2484  The continents were both created through volca...
# 2485                   They change the state of matter.
# 2486                                 rotation of crops.
# 2487                                           bacteria
# 2488                    when they reach sexual maturity
# 2489                                             oxygen
# 2490               friction between the ocean and rocks
# 2491                         the size of the fox's ears
# 2492                 atmospheric rise of carbon dioxide
# 2493                    climate of a particular region.
# 2494                                    are now extinct
# 2495                                          insulator
# 2496                                              genes
# 2497  unexpected changes in the climate of an ecosystem
# 2498                                           products
# 2499         so that other cold medicines can be tested
#
#                                                 answerB  \
# 0                                    at the organ level
# 1                                barking when disturbed
# 2                                              reaction
# 3                        the geographical area affected
# 4     The orbit of a comet is more elliptical than t...
# 5                            relative mass of particles
# 6                                               vinegar
# 7                                          fossil fuels
# 8                                              friction
# 9         oceanic plates separating from oceanic plates
# 10                  increase sugar levels in the blood.
# 11     the study of the living parts of the environment
# 12                                   selective breeding
# 13                  The research costs less to perform.
# 14                                           cone cells
# 15                                             hydrogen
# 16               Magnetic fields deflect seismic waves.
# 17                                          scatterplot
# 18    The assembly process must remain exactly the s...
# 19                                          a pie chart
# 20                                           kilometers
# 21                                              nucleus
# 22           A scent trail leads ants to a food source.
# 23    transporting oxygen, wastes, and nutrients thr...
# 24    It keeps its shape when transferred to a large...
# 25        There would be a decline in fruit production.
# 26                                    Bacteria, Animals
# 27                                             a larger
# 28    publish the research results in a scientific j...
# 29                                           experiment
# ...                                                 ...
# 2470              carbohydrates, fats, proteins and DNA
# 2471                                             crust.
# 2472           destroy habitat for many animal species.
# 2473              they have full outer electron shells.
# 2474  The rays of the Sun strike the Northern Hemisp...
# 2475                           cows that graze on grass
# 2476                   could be either solid or liquid.
# 2477                                            tornado
# 2478                the interaction of light with waves
# 2479                                             HhQqTt
# 2480                                    two sperm cells
# 2481                                   air conditioning
# 2482                                           nitrogen
# 2483  The measure of how bright an object appears in...
# 2484  The fossils were brought to South America by e...
# 2485                        They create new substances.
# 2486                                use of fertilizers.
# 2487                                              fungi
# 2488                               before they are born
# 2489                                             wastes
# 2490                  mixture of minerals and saltwater
# 2491                the conditions of the fox's habitat
# 2492               hot air from air conditioner exhaust
# 2493          types of elements available in the crust.
# 2494                    have evolved into other animals
# 2495                                          conductor
# 2496                                              sperm
# 2497                            a fire in the ecosystem
# 2498                                          reactants
# 2499  so that the medicine can be used to treat othe...
#
#                                                 answerC  \
# 0                                   at the system level
# 1                                    sitting on command
# 2                                               fission
# 3                     the species of organisms infected
# 4     The orbital period of Earth is much longer tha...
# 5                            types of particles present
# 6                                                  salt
# 7                                                clouds
# 8                                               density
# 9     continental plates colliding with continental ...
# 10                     decrease blood flow to the skin.
# 11    the study of the protection and renewal of nat...
# 12                                  aerobic respiration
# 13               The researchers can share their ideas.
# 14                                                 lens
# 15                                              mercury
# 16    The density of a material affects the speed of...
# 17                                         circle graph
# 18                  Robots require regular maintenance.
# 19                                          a bar graph
# 20                                   astronomical units
# 21                                             membrane
# 22    A wolf pack howls to warn other wolves to stay...
# 23                    producing male and female gametes
# 24    Its volume can be greatly reduced by adding pr...
# 25        There would be an increase in plant diseases.
# 26                                        Plants, Fungi
# 27                                           an upright
# 28         publish the results in brochures for doctors
# 29                                           conclusion
# ...                                                 ...
# 2470            carbohydrates, proteins, water and salt
# 2471                                     asthenosphere.
# 2472           allow fish to more easily swim up river.
# 2473               they have excess electrons to share.
# 2474  The greenhouse effect increases in the Norther...
# 2475                         pigs that form large herds
# 2476                                    must be liquid.
# 2477                                            El Niño
# 2478  the differences in the strength of the waves' ...
# 2479                                             Hhqqtt
# 2480                       an egg cell and a sperm cell
# 2481                                 insulated clothing
# 2482                                             oxygen
# 2483    The average distance between the Sun and Earth.
# 2484  The animals crossed a land bridge that once co...
# 2485                                They change volume.
# 2486                            destruction of habitat.
# 2487                                             plants
# 2488                 before engaging in sexual activity
# 2489                                              blood
# 2490            friction between the ocean and the wind
# 2491                the average number of fox offspring
# 2492                methane gas escaping from landfills
# 2493                 thicknesses of nearby rock layers.
# 2494                          were plant-like organisms
# 2495                                          malleable
# 2496                                             testes
# 2497                           a flood in the ecosystem
# 2498                                     waste products
# 2499  so that other scientists can make the same col...
#
#                                                 answerD wsregression_answer  \
# 0                                 at the cellular level                   A
# 1                                       digging in soil                   A
# 2                                                fusion                   D
# 3               the season in which the disease spreads                   A
# 4     The orbital period of a comet is more predicta...                   B
# 5                          charges of particles present                   A
# 6                                          formaldehyde                   C
# 7                                             the ocean                   D
# 8                                               gravity                   D
# 9     continental plates separating from continental...                   D
# 10                     increase blood flow to the skin.                   C
# 11    the study of organisms and their interactions ...                   D
# 12                                  sexual reproduction                   D
# 13     The researchers have more time to complete work.                   D
# 14                                                 iris                   A
# 15                                                  tin                   A
# 16    The physical state of a material determines th...                   D
# 17                                           pictograph                   C
# 18            Robots must be provided with electricity.                   D
# 19                                         a line graph                   D
# 20                                          light years                   C
# 21                                          chloroplast                   C
# 22    A honeybee society divides the work between it...                   A
# 23     conducting messages to coordinate body functions                   D
# 24    Its shape can be changed by increasing its tem...                   D
# 25    There would be an increase in insect pest popu...                   D
# 26                                       Animals, Fungi                   B
# 27                                           an inverse                   C
# 28         discuss the research results on the Internet                   A
# 29                                          observation                   B
# ...                                                 ...                 ...
# 2470              hydrogen, carbon, oxygen and nitrogen                   B
# 2471                                        atmosphere.                   B
# 2472                cause people to consume more water.                   B
# 2473             they easily react with other elements.                   A
# 2474  The Northern Hemisphere is closer to the Sun i...                   B
# 2475                       chickens that lay large eggs                   C
# 2476                     could be either liquid or gas.                   D
# 2477                                          Santa Ana                   C
# 2478  the different media through which the waves tr...                   D
# 2479                                             HhqqTt                   A
# 2480                                  two somatic cells                   A
# 2481                                  irrigation canals                   B
# 2482                                            uranium                   C
# 2483  The distance of Earth's revolution around the ...                   A
# 2484  The continents were once attached to each othe...                   B
# 2485                                They create energy.                   B
# 2486                 introduction of competing species.                   C
# 2487                                            animals                   A
# 2488            at the beginning of their monthly cycle                   B
# 2489                                          nutrients                   A
# 2490        mixture between freshwater deltas and rocks                   A
# 2491     the social behaviors within the fox population                   C
# 2492              body heat generated by overpopulation                   B
# 2493       exposure of the elements to the environment.                   B
# 2494                       have been affected by humans                   C
# 2495                                             porous                   A
# 2496                                               eggs                   A
# 2497                                   All of the above                   C
# 2498                                              gases                   B
# 2499  so that the results can be accurately reported...                   C
#
#      wsregression_correct
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                    True
# 5                   False
# 6                   False
# 7                   False
# 8                    True
# 9                   False
# 10                  False
# 11                   True
# 12                  False
# 13                  False
# 14                  False
# 15                  False
# 16                  False
# 17                  False
# 18                  False
# 19                  False
# 20                   True
# 21                   True
# 22                  False
# 23                   True
# 24                  False
# 25                  False
# 26                  False
# 27                  False
# 28                  False
# 29                   True
# ...                   ...
# 2470                 True
# 2471                 True
# 2472                 True
# 2473                False
# 2474                 True
# 2475                False
# 2476                False
# 2477                 True
# 2478                 True
# 2479                False
# 2480                False
# 2481                False
# 2482                False
# 2483                False
# 2484                False
# 2485                 True
# 2486                 True
# 2487                 True
# 2488                 True
# 2489                False
# 2490                False
# 2491                False
# 2492                False
# 2493                 True
# 2494                False
# 2495                False
# 2496                False
# 2497                False
# 2498                 True
# 2499                False
#
# [2500 rows x 9 columns]

# %%
train['wsregression_correct'] = (train['correctAnswer'] == train['wsregression_answer'])

# %%
print 'the percent correct in 2500 question is '
print train['wsregression_correct'].sum()  / (len(train) + 0.0)
train.to_csv('/Users/MK/GitHub/the_answer_is/data/answer/pure_wsregression.csv', encoding='utf-8')
# Out:
# the percent correct in 2500 question is
# 0.2616

# %%
#lets use another dictionary from the PyDictionary package
# use easy_install -U PyDictionary to install the package
# the problem with using this package in the competition is that it makes a query to thesaurus.com to get synonyms. 
from PyDictionary import PyDictionary
dictionary=PyDictionary()
print dictionary.synonym("fusion")
# Out:
# [u'synthesis', u'blend', u'alloy', u'melting', u'commixture']
# /Users/MK/anaconda/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
for word in dictionary.synonym("fusion"):
    print getdef(word)
# Out:
# synthesis the process of producing a chemical compound (usually by the union of simpler chemical compounds)
# blend an occurrence of thorough mixing
# alloy a mixture containing two or more metallic elements or metallic and nonmetallic elements usually fused together or dissolving into each other when molten
# melting the process whereby heat changes something from a solid to a liquid
# commixture the act of mixing together

# %%
synonyms = dictionary.synonym("fsn")
print " ".join(synonyms)

# %%
# change the getdef procedure to include synonyms from the thesaurus.com 
def getdef(word):
    '''
    :param word: input is a word in a string format
    :return: returns a string that combines 3 definitions. 
    '''
    addef = word            #the word itself goes into the definition.
    synonyms = dictionary.synonym(word)
    if synonyms:
        addef = addef + " ".join(synonyms)
    for synset in wordnet.synsets(word)[:1]:
        addef = addef + ' ' + synset.definition()

    return addef

# %%
#see if adding thesaurus would change the answer significantly. 
#and as you can see, it doesnt't.

question = train.ix[2][1]
answer1 = train.ix[2][3]
answer2 = train.ix[2][4]
answer3 = train.ix[2][5]
answer4 = train.ix[2][6] 

question = remove_stopwords(question)
answer1 = remove_stopwords(answer1)
answer2 = remove_stopwords(answer2)
answer3 = remove_stopwords(answer3)
answer4 = remove_stopwords(answer4)

wordspace = get_wordspace([question,answer1,answer2,answer3,answer4])  

result = run_wsregression( [question], [answer1,answer2,answer3,answer4], wordspace)
print result
# Out:
# get_wordspace progress:  0 /  16
# get_wordspace progress:  1  /  16
# get_wordspace progress:  2  /  16
# get_wordspace progress:  3  /  16
# get_wordspace progress:  4  /  16
# get_wordspace progress:  5  /  16
# get_wordspace progress:  6  /  16
# get_wordspace progress:  7  /  16
# get_wordspace progress:  8  /  16
# get_wordspace progress:  9  /  16
# get_wordspace progress:  10  /  16
# get_wordspace progress:  11  /  16
# get_wordspace progress:  12  /  16
# get_wordspace progress:  13  /  16
# What has no Synonyms in the API
# get_wordspace progress:  14  /  16
# get_wordspace progress:  15  /  16
# get_wordspace progress:  16  /  16
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# get_wordspace progress:  0 /  1
# get_wordspace progress:  1  /  1
# doc_to_def progress:  0 /  16
# doc_to_def progress:  1  /  16
# doc_to_def progress:  2  /  16
# doc_to_def progress:  3  /  16
# doc_to_def progress:  4  /  16
# doc_to_def progress:  5  /  16
# doc_to_def progress:  6  /  16
# doc_to_def progress:  7  /  16
# doc_to_def progress:  8  /  16
# doc_to_def progress:  9  /  16
# doc_to_def progress:  10  /  16
# doc_to_def progress:  11  /  16
# doc_to_def progress:  12  /  16
# doc_to_def progress:  13  /  16
# What has no Synonyms in the API
# doc_to_def progress:  14  /  16
# doc_to_def progress:  15  /  16
# doc_to_def progress:  16  /  16
# progress:  0 /  16
# progress:  1  /  16
# progress:  2  /  16
# progress:  3  /  16
# progress:  4  /  16
# progress:  5  /  16
# progress:  6  /  16
# progress:  7  /  16
# progress:  8  /  16
# progress:  9  /  16
# progress:  10  /  16
# progress:  11  /  16
# progress:  12  /  16
# progress:  13  /  16
# progress:  14  /  16
# progress:  15  /  16
# progress:  16  /  16
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
# doc_to_def progress:  0 /  1
# doc_to_def progress:  1  /  1
# progress:  0 /  1
# progress:  1  /  1
#              KeyDoc1
# SearchDoc1  1.219643
# SearchDoc2  1.191566
# SearchDoc3  1.221130
# SearchDoc4  1.143051
