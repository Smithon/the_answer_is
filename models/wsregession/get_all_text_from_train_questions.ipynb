# %%
import pandas as pd
import os
path = '/Users/MK/GitHub/the_answer_is/data'
os.chdir(path)
train = pd.read_table('training_set.tsv',sep = '\t')
train.head()
# Out:
#        id                                           question correctAnswer  \
# 0  100001  When athletes begin to exercise, their heart r...             C
# 1  100002  Which example describes a learned behavior in ...             C
# 2  100003  When two nuclei are combined into one nucleus,...             D
# 3  100004  Which is a distinction between an epidemic and...             B
# 4  100005  In which way is the orbit of a comet different...             B
#
#                                              answerA  \
# 0                                at the tissue level
# 1                         smelling the air for odors
# 2                                         conversion
# 3                        the symptoms of the disease
# 4  The orbit of Earth is less circular than the o...
#
#                                              answerB  \
# 0                                 at the organ level
# 1                             barking when disturbed
# 2                                           reaction
# 3                     the geographical area affected
# 4  The orbit of a comet is more elliptical than t...
#
#                                              answerC  \
# 0                                at the system level
# 1                                 sitting on command
# 2                                            fission
# 3                  the species of organisms infected
# 4  The orbital period of Earth is much longer tha...
#
#                                              answerD
# 0                              at the cellular level
# 1                                    digging in soil
# 2                                             fusion
# 3            the season in which the disease spreads
# 4  The orbital period of a comet is more predicta...

# %%
question = list(train['question'])
print question[0:5]
# Out:
# ['When athletes begin to exercise, their heart rates and respiration rates increase.  At what level of organization does the human body coordinate these functions?', 'Which example describes a learned behavior in a dog?', 'When two nuclei are combined into one nucleus, there is a slight change in mass and the release of a large amount of energy. What is this process called?', 'Which is a distinction between an epidemic and a pandemic?', 'In which way is the orbit of a comet different from the orbit of Earth?']

# %%
thefile = open('train_question.txt','w')
for item in question:
    thefile.write("%s\n" % item)

# %%
#getting the list of all files in a directory. 
import os
from os import walk

def get_all_file_list(path):
    mypath = path
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
    return f


def stripNonAlphaNum(text):
    import re
    
    return re.sub(r'[^\x00-\x7F]+',' ', text)

def norm_word(word):
    word = word.lower().strip('?').strip('.').strip(',').strip('!').strip(':').strip(';').strip('\"').strip('\'')
    return word

def doc_to_unicode(doc_name, path):
    os.chdir(path)
    byline = open(doc_name).readlines()
    n_total = len(byline)
    file = open(doc_name + '_to_unicode.txt', 'w+')
    for index, line in enumerate(byline):
        line = line.strip('\n').lower()
    
        try:
            line = stripNonAlphaNum(line)   #delete all non-unicode letters.
        except:
            print 'Error', line
        if not line:
            continue
    
        line = ' '.join(map(norm_word, line.split()))  #drop all special characters
        if line:
            file.write(line + '\n')
#            print index, n_total, index * 1.0 / n_total, line
    file.close()

def doc_to_unicode_remove_stopwords(doc_name, path): 
    import re
    from nltk.corpus import stopwords


    os.chdir(path)
    byline = open(doc_name).readlines()
    n_total = len(byline)
    file = open(doc_name + '_to_unicode_remove_stopwords.txt', 'w+')
    for index, line in enumerate(byline):
        line = line.strip('\n').lower()
    
        try:
            line = re.sub(r'[^a-zA-Z ]',r'',line)       #delete all but alphabet 
        except:
            print 'Error', line
        if not line:
            continue

        if line:                              # delete the empty lines. 
            line = line.split()
            #line = nltk.word_tokenize(line)
            line = [word for word in line if word not in stopwords.words('english')]  # remove the stop words. 
            line = ' '.join(line)  #join the list to make a string. 
            if line:
                file.write(line + '\n')
#            print index, n_total, index * 1.0 / n_total, line
    file.close()    

    
def doc_to_unicode_remove_stopwords_and_stem(doc_name, path): 
    import re
    from nltk.corpus import stopwords
    from nltk.stem.snowball import SnowballStemmer
    #or use: from nltk.stem.porter import *
    
    stemmer = SnowballStemmer("english")
    # or use: stemmer = PorterStemmer()
    os.chdir(path)
    byline = open(doc_name).readlines()
    n_total = len(byline)
    file = open(doc_name + '_to_unicode_remove_stopwords_and_stem.txt', 'w+')
    for index, line in enumerate(byline):
        line = line.strip('\n').lower()
    
        try:
            line = re.sub(r'[^a-zA-Z ]',r'',line)       #delete all but alphabet 
        except:
            print 'Error', line
        if not line:
            continue

        if line:                              # delete the empty lines. 
            line = line.split()
            #line = nltk.word_tokenize(line)
            line = [word for word in line if word not in stopwords.words('english')]  # remove the stop words. 
            for i, s in enumerate(line):
                line[i] = stemmer.stem(s)     #stem all words 
            line = ' '.join(line)           # join the list to make a string
            if line:
                file.write(line + '\n')
#            print index, n_total, index * 1.0 / n_total, line
    file.close()

# %%
path = '/Users/MK/GitHub/the_answer_is/data/temporary2'
filelist = ['train_question.txt']   #get_all_file_list(path)
for filename in filelist:
    doc_to_unicode_remove_stopwords_and_stem(filename, path)
